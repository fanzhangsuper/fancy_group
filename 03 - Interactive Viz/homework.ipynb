# %% [markdown]
# # Introduction to folium

# %%
import pandas as pd
import folium
import requests
from bs4 import BeautifulSoup
import numpy as np

# %% [markdown]
# # Processing data

# %%
df = pd.read_csv('P3_GrantExport.csv', delimiter=';',index_col=0)
df.head()
# Out:
#                                                     Project Title  \
# Project Number
# 1               Schlussband (Bd. VI) der Jacob Burckhardt-Biog...
# 4               Batterie de tests à l'usage des enseignants po...
# 5               Kritische Erstausgabe der "Evidentiae contra D...
# 6               Katalog der datierten Handschriften in der Sch...
# 7               Wissenschaftliche Mitarbeit am Thesaurus Lingu...
#
#                Project Title English  \
# Project Number
# 1                                NaN
# 4                                NaN
# 5                                NaN
# 6                                NaN
# 7                                NaN
#
#                                             Responsible Applicant  \
# Project Number
# 1                                                    Kaegi Werner
# 4                                              Massarenti Léonard
# 5               Kommission für das Corpus philosophorum medii ...
# 6                                                  Burckhardt Max
# 7                                    Schweiz. Thesauruskommission
#
#                           Funding Instrument Funding Instrument Hierarchy  \
# Project Number
# 1               Project funding (Div. I-III)              Project funding
# 4               Project funding (Div. I-III)              Project funding
# 5               Project funding (Div. I-III)              Project funding
# 6               Project funding (Div. I-III)              Project funding
# 7               Project funding (Div. I-III)              Project funding
#
#                                                       Institution  \
# Project Number
# 1                                                             NaN
# 4               Faculté de Psychologie et des Sciences de l'Ed...
# 5               Kommission für das Corpus philosophorum medii ...
# 6               Abt. Handschriften und Alte Drucke Bibliothek ...
# 7                                    Schweiz. Thesauruskommission
#
#                                              University  Discipline Number  \
# Project Number
# 1                                  Nicht zuteilbar - NA              10302
# 4                             Université de Genève - GE              10104
# 5               NPO (Biblioth., Museen, Verwalt.) - NPO              10101
# 6                                Universität Basel - BS              10302
# 7               NPO (Biblioth., Museen, Verwalt.) - NPO              10303
#
#                                       Discipline Name  \
# Project Number
# 1                                       Swiss history
# 4                    Educational science and Pedagogy
# 5                                          Philosophy
# 6                                       Swiss history
# 7               Ancient history and Classical studies
#
#                                         Discipline Name Hierarchy  Start Date  \
# Project Number
# 1               Human and Social Sciences;Theology & religious...  01.10.1975
# 4               Human and Social Sciences;Psychology, educatio...  01.10.1975
# 5               Human and Social Sciences;Linguistics and lite...  01.03.1976
# 6               Human and Social Sciences;Theology & religious...  01.10.1975
# 7               Human and Social Sciences;Theology & religious...  01.01.1976
#
#                   End Date Approved Amount Keywords
# Project Number
# 1               30.09.1976        11619.00      NaN
# 4               30.09.1976        41022.00      NaN
# 5               28.02.1985        79732.00      NaN
# 6               30.09.1976        52627.00      NaN
# 7               30.04.1978       120042.00      NaN

# %% [markdown]
# Deal with a special case

# %%
df.loc[101005]
# Out:
# Project Title                            SELECTS 2003: Eidgenössische Wahlen 2003
# Project Title English                        SELECTS 2003: Federal elections 2003
# Responsible Applicant                                            Malaguerra Carlo
# Funding Instrument                               Swiss Priority Programmes (SPPs)
# Funding Instrument Hierarchy                                           Programmes
# Institution                     Schweizerische Akademie der Geistes-und Sozial...
# University                                              Forschungskommission SAGW
# Discipline Number                                                           10202
# Discipline Name                                                 Political science
# Discipline Name Hierarchy       Human and Social Sciences;Sociology, social wo...
# Start Date                                                             01.02.2003
# End Date                                                               31.01.2004
# Approved Amount                                                         100000.00
# Keywords                                                                      NaN
# Name: 101005, dtype: object

# %% [markdown]
# Change from 'Forschungskommission SAGW' to 'Forschungskommission - SAGW'

# %%
df.loc[101005, 'University'] = 'Forschungskommission - SAGW'

# %% [markdown]
# ### Select universities applicable

# %% [markdown]
# Not all of the universities in the columns `university` will be used. Some of the entries are not in Switzerland, and some of them didn't specifiy the universities.
#
# We will drop out some itmes:
#
# - foreign universities where df['University'] is NaN
# - 'Nicht zuteilbar' : not applicable
# - 'NPO (Biblioth., Museen, Verwalt.) - NPO' : the exact places of NPOs are not known
# - 'Weitere Institute - FINST' means other institutions
# - 'Weitere Spitäler - ASPIT' means other universities
# - 'Firmen/Privatwirtschaft - FP' means private/business
# - 'Istituto Svizzero di Roma - ISR' is a Italian university
#
# Besides, we will also negelect projects whose 'Approved Amount' is not given (`'data not included in P3'`).

# %%
foreign_institution = df['University'].isnull()
na                  = df['University'] == 'Nicht zuteilbar - NA'
npo                 = df['University'] == 'NPO (Biblioth., Museen, Verwalt.) - NPO'
other_institution   = df['University'] == 'Weitere Institute - FINST'
other_hospital      = df['University'] == 'Weitere Spitäler - ASPIT'
private             = df['University'] == 'Firmen/Privatwirtschaft - FP'
Italian_unvi        = df['University'] == 'Istituto Svizzero di Roma - ISR'

fund_amount_included = df['Approved Amount'] == 'data not included in P3'

swiss_univ_idx = df.index[(~foreign_institution) & (~npo) & (~fund_amount_included)
                         & (~na) & (~other_institution) & (~other_hospital)
                         & (~private) & (~Italian_unvi)]
swiss_df = df.loc[swiss_univ_idx]

# %% [markdown]
# Conver the money to float number

# %%
swiss_df['Approved Amount'] = swiss_df['Approved Amount'].astype(np.float64)

# %% [markdown]
# #### Group the dataframe by their university

# %%
univ_amount = swiss_df.groupby('University').sum()['Approved Amount']
univ_amount.sort_values(ascending=False).head(10)
# Out:
# University
# Université de Genève - GE       1.838237e+09
# Universität Zürich - ZH         1.826843e+09
# ETH Zürich - ETHZ               1.635597e+09
# Universität Bern - BE           1.519373e+09
# Universität Basel - BS          1.352251e+09
# Université de Lausanne - LA     1.183291e+09
# EPF Lausanne - EPFL             1.175316e+09
# Université de Fribourg - FR     4.575262e+08
# Université de Neuchâtel - NE    3.832046e+08
# Paul Scherrer Institut - PSI    1.152690e+08
# Name: Approved Amount, dtype: float64

# %% [markdown]
# #### Extract universities and their abbreviations

# %%
splited_names = swiss_df.loc[swiss_univ_idx].University.apply(lambda x: x.split(' - '))
univ_name = splited_names.apply(lambda x: x[0])
univ_abb  = splited_names.apply(lambda x: x[1])
univ_name_unique = univ_name.unique()
univ_abb_unqiue  = univ_abb.unique()
name_to_univ = dict(zip(univ_name_unique, swiss_df.loc[swiss_univ_idx].University.unique()))

# %% [markdown]
# # Map university to their Canton
#
# First, we use the api http://www.geonames.org/export/web-services.html to search the universities by their names. But not all of them can be found in this way.
#
# Second, for those universities whose name are not listed in `geonames.com`, we manually substitute them with other keywords which will get a desirable result in `geonames.com`. For instance, we can search the name of university, the abbreviation of university, and even the city(street) of the unviersity.
#
# As soon as we have obtained all the webpage results from `geonames.com`, we will parser the locations of universities.
# There are two kinds of possible results for each request:
#
#     1. results found in database
#     2. results found in wikipedia
#
# Both of them contains `latitude` and `longitude` of a place, but the canton a university located can only be found in `database`. Thus we decide to use `reverse geocoding` to find the name of canton from the `latitude` and `longitude`.
#
# As the number of requests for google maps is limited, we use `http://nominatim.openstreetmap.org/search.php` to for `reverse geocoding`.

# %%
def request_geo_name(univ):
    original_url = 'http://www.geonames.org/search.html?'
    payload = {'q':univ,'country':'CH'}
    get_url = requests.get(original_url, params=payload, timeout=30)
    soup = BeautifulSoup(get_url.text,"lxml")
    return soup

def reverse_geocoding(lat, lng):
    reverse_geocoding_url = 'http://nominatim.openstreetmap.org/search.php'
    payload = {'q':lat+', '+lng}
    get_url = requests.get(reverse_geocoding_url, params=payload, timeout=30)
    soup = BeautifulSoup(get_url.text,"lxml")
    return ((soup.select('div[id=content] span[class=name]')[0].string).split(', ')[-6])

# %% [markdown]
# First, request with university names first

# %%
selectors = dict()
for name in univ_name_unique:
    soup = request_geo_name(name)
    table_selector = soup.select('div table[class=restable]')
    selectors[name] = table_selector

# %%
univ_found_by_name = [name for name in univ_name_unique if (selectors[name] != [])]
not_found_by_name = list(filter(lambda x: x not in univ_found_by_name, univ_name_unique))
print(len(univ_found_by_name))
print(len(not_found_by_name))
# Out:
# 22
# 49

# %% [markdown]
# Modifiy the keywords in the request to get the accurate results.

# %%
modified_list = [
"WSL", "Graduate Institute of International and Development Studies", "Chur", "EPFL", 
"Zurich University of Applied Sciences/ZHAW", "Zürich", "University of Lugano edu",
"Bern", "St. Gallen", "Swiss Federal Institute of Aquatic Science and Technology",
"empa", "Davos", "Neuchâtel", "Davos", "University of Zürich", "frick", "agroscope",
"Bellinzona", "Epalinges", "Zollikofen", "Winterthur", "Chur", "FHNW", "Schaffhauserstrasse",
"Sion", "Bern", "Nottwil", "Avenue du Grand-Champsec", "HES-SO", "Chaux-de-Fonds", "HEP-BEJUNE",
"University of applied sciences in Lucerne", "Bern", "SUPSI", "Fribourg", "Arth", "Kreuzlingen",
"Kreuzlingen", "Zürich", "Lausanne", "Saint-Maurice valais", "Rorschach", "Zug", "Locarno",
"Schaffhausen", "Nordwestschweiz", "Basel", "Lugano","Brig"]
unmodified_to_modified = dict(zip(not_found_by_name, modified_list))

# %%
for name in not_found_by_name:
    modified_names = unmodified_to_modified[name]
    soup = request_geo_name(modified_names)
    table_selector = soup.select('div table[class=restable]')
    selectors[name] = table_selector

# %% [markdown]
# ## Parse geo information

# %% [markdown]
# For two kinds of results, parse them seperately.

# %%
univ_loc = dict()
for name in univ_name_unique:
    found_in_wiki = 'wikipedia' in list((selectors[name][0].contents)[1].strings)
    if found_in_wiki:
        lat_lng = selectors[name][0].select('tr')[1].select('td[nowrap=] a')[-1].string
        univ_loc[name] = lat_lng.split(' / ')
    else: # found in database
        univ_loc[name] = [selectors[name][0].select('tr')[2].select('span[class=latitude]')[0].string,
                         selectors[name][0].select('tr')[2].select('span[class=longitude]')[0].string]

# %%
univ_loc
# Out:
# {'AO Research Institute': ['46.80428964656369', '9.837226867675781'],
#  'Allergie- und Asthmaforschung': ['47.3765286779741', '8.54921936988831'],
#  'Berner Fachhochschule': ['47.1044', '8.6747'],
#  'Biotechnologie Institut Thurgau': ['47.650512', '9.175038'],
#  "Centre de rech. sur l'environnement alpin": ['46.22739', '7.355592'],
#  'EPF Lausanne': ['46.5193924550827', '6.56673431396484'],
#  'ETH Zürich': ['47.3763034523898', '8.54804992675781'],
#  'Eidg. Anstalt für Wasserversorgung': ['47.3983', '8.6194'],
#  'Eidg. Forschungsanstalt für Wald,Schnee,Land': ['47.36044120058724',
#   '8.454840045676514'],
#  'Eidg. Hochschulinstitut für Berufsbildung': ['46.99904617562046',
#   '7.458086013793945'],
#  'Eidg. Material und Prüfungsanstalt': ['47.4031089613006',
#   '8.61246419472767'],
#  'Ente Ospedaliero Cantonale': ['46.19278438783632', '9.01702880859375'],
#  'Fachhochschule Kalaidos': ['47.3666667', '8.55'],
#  'Fachhochschule Nordwestschweiz (ohne PH)': ['47.5337767472998',
#   '7.63856112957001'],
#  'Fachhochschule Ostschweiz': ['47.4667', '9.05'],
#  'Facoltà di Teologia di Lugano': ['46.0100778450283', '8.96003723144531'],
#  'Fernfachhochschule Schweiz (Mitglied SUPSI)': ['46.3166667', '7.9833333'],
#  'Forschungsanstalten Agroscope': ['46.770507432212845', '7.105254777448807'],
#  'Forschungsinstitut für Opthalmologie': ['46.2319', '7.3838'],
#  'Forschungsinstitut für biologischen Landbau': ['47.51169', '8.024713'],
#  'Forschungskommission': ['46.9480943365053', '7.44744300842285'],
#  'Franklin University Switzerland': ['45.9997', '8.9383'],
#  'Friedrich Miescher Institute': ['47.5637', '7.5801'],
#  'HES de Suisse occidentale': ['47.3614', '7.3458'],
#  'Haute école pédagogique BE, JU, NE': ['47.10665592108913',
#   '6.8256220740791615'],
#  'Haute école pédagogique du canton de Vaud': ['47.3614', '7.3458'],
#  'Haute école pédagogique fribourgeoise': ['46.8023655344308',
#   '7.15128421783447'],
#  'Hochschule Luzern': ['47.014', '8.306'],
#  'Idiap Research Institute': ['46.1091', '7.0847'],
#  'Inst. Suisse de Spéléologie et Karstologie': ['47.0999278405134',
#   '6.82585716247559'],
#  'Inst. de Hautes Etudes Internat. et du Dév': ['46.1989', '6.1445'],
#  'Inst. universit. romand de Santé au Travail': ['46.551775', '6.668288'],
#  'Institut Universitaire Kurt Bösch': ['46.1989', '6.1445'],
#  'Institut für Kulturforschung Graubünden': ['46.8498606898684',
#   '9.53287124633789'],
#  'Instituto Ricerche Solari Locarno': ['46.17085590698898',
#   '8.79953384399414'],
#  'Interkant. Hochschule für Heilpädagogik ZH': ['47.5185', '8.7201'],
#  'Kantonsspital St. Gallen': ['47.42925492892253', '9.388259837297506'],
#  'Paul Scherrer Institut': ['47.5361', '8.2228'],
#  'Physikal.-Meteorolog. Observatorium Davos': ['46.80428964656369',
#   '9.837226867675781'],
#  'Pädag. Hochschule Tessin (Teilschule SUPSI)': ['46.02393965717121',
#   '8.91741156578064'],
#  'Pädagogische Hochschule Bern': ['46.9480943365053', '7.44744300842285'],
#  'Pädagogische Hochschule Graubünden': ['46.8498606898684',
#   '9.53287124633789'],
#  'Pädagogische Hochschule Luzern': ['47.014', '8.306'],
#  'Pädagogische Hochschule Nordwestschweiz': ['47.5337767472998',
#   '7.63856112957001'],
#  'Pädagogische Hochschule Schaffhausen': ['47.697316', '8.634929'],
#  'Pädagogische Hochschule Schwyz': ['47.06337', '8.523485'],
#  'Pädagogische Hochschule St. Gallen': ['47.42390636154281',
#   '9.374771118164062'],
#  'Pädagogische Hochschule Thurgau': ['47.650512', '9.175038'],
#  'Pädagogische Hochschule Wallis': ['46.218257', '7.003196'],
#  'Pädagogische Hochschule Zug': ['47.172421', '8.517445'],
#  'Pädagogische Hochschule Zürich': ['47.4969', '8.73'],
#  'Robert Walser-Stiftung Bern': ['46.9480943365053', '7.44744300842285'],
#  'SUP della Svizzera italiana': ['46.011', '8.958'],
#  'Schweiz. Hochschule für Logopädie Rorschach': ['47.4780001209756',
#   '9.49029922485352'],
#  'Schweiz. Institut für Kunstwissenschaft': ['47.3666667', '8.55'],
#  'Schweizer Kompetenzzentrum Sozialwissensch.': ['46.5159963488544',
#   '6.6328239440918'],
#  'Schweizer Paraplegiker Forschung': ['47.135692', '8.137122'],
#  'Staatsunabh. Theologische Hochschule Basel': ['47.558395', '7.573271'],
#  'Swiss Center for Electronics and Microtech.': ['46.9917870407831',
#   '6.93099975585938'],
#  'Swiss Institute of Bioinformatics': ['47.5637', '7.5801'],
#  'Università della Svizzera italiana': ['45.8667', '8.9833'],
#  'Universität Basel': ['47.55831967091123', '7.584031820297241'],
#  'Universität Bern': ['46.95095609536347', '7.4354831442083436'],
#  'Universität Luzern': ['47.0494', '8.3122'],
#  'Universität St. Gallen': ['47.4317', '9.3747'],
#  'Universität Zürich': ['47.37092', '8.53434'],
#  'Université de Fribourg': ['46.80683246786493', '7.153167516669125'],
#  'Université de Genève': ['46.1989', '6.1445'],
#  'Université de Lausanne': ['46.52376278378653', '6.5840935707092285'],
#  'Université de Neuchâtel': ['46.993854489413216', '6.937892486542709'],
#  'Zürcher Fachhochschule (ohne PH)': ['47.50564', '8.72413']}

# %% [markdown]
# ## Build dataframe

# %% [markdown]
# Build a datadrame based on each university.

# %%
lat = []
lng = []
uname = []
amount = []
for name in univ_name_unique:
    lat.append(univ_loc[name][0])
    lng.append(univ_loc[name][1])
    uname.append(name)
    amount.append(univ_amount[name_to_univ[name]])

# %%
name_x_grant_x_geo = pd.DataFrame({'lat': lat, 'lng': lng, 'grant':amount },index=uname)

# %%
name_x_grant_x_geo.iloc[0]
# Out:
# grant    1.83824e+09
# lat          46.1989
# lng           6.1445
# Name: Université de Genève, dtype: object

# %% [markdown]
# # Reverse geocoding

# %% [markdown]
# #### Parse the canton names from requested webpage, and map them to abbreviations

# %%
cantons = ["AG","AR","AI","BL","BS","BE","FR","GE","GL","GR",
 "JU","LU","NE","NW","OW","SG","SH","SZ","SO","TG","TI","UR","VS","VD","ZG","ZH"]

# %%
map_canton_name_to_abb = dict()
map_canton_name_to_abb['Genève'] = 'GE'
map_canton_name_to_abb['Basel-Stadt'] = 'BS'
map_canton_name_to_abb['Fribourg - Freiburg'] = 'FR'
map_canton_name_to_abb['Vaud'] = 'VD'
map_canton_name_to_abb['Bern - Berne'] = 'BE'
map_canton_name_to_abb['Neuchâtel'] = 'NE'
map_canton_name_to_abb['Sankt Gallen'] = 'SG'
map_canton_name_to_abb['Graubünden - Grigioni - Grischun'] = 'GR'
map_canton_name_to_abb['Luzern'] = 'LU'
map_canton_name_to_abb['Ticino'] = 'TI'
map_canton_name_to_abb['Jura'] = 'JU'
map_canton_name_to_abb['Schwyz'] = 'SZ'
map_canton_name_to_abb['Aargau'] = 'AG'
map_canton_name_to_abb['Basel-Landschaft'] = 'BL'
map_canton_name_to_abb['Valais - Wallis'] = 'VS'
map_canton_name_to_abb['Thurgau'] = 'TG'
map_canton_name_to_abb['Schaffhausen'] = 'SH'
map_canton_name_to_abb['Zug'] = 'ZG'
map_canton_name_to_abb['Zürich'] = 'ZH'

# %% [markdown]
# Requesting canton names by their positions

# %%
unvi_canton = []
for n in range(name_x_grant_x_geo.shape[0]):
    unvi_canton.append(reverse_geocoding(name_x_grant_x_geo.iloc[n]['lat'], name_x_grant_x_geo.iloc[n]['lng']))

# %%
unvi_canton[0:5]
# Out:
# ['Genève', 'Basel-Stadt', 'Fribourg - Freiburg', 'Zürich', 'Vaud']

# %% [markdown]
# Map the name of university to their cantons

# %%
univ_canton_abb = [map_canton_name_to_abb[place] for place in unvi_canton]

# %% [markdown]
# Add a column to our dataframe called 'id' which coincides with those in topojson files

# %%
name_x_grant_x_geo['id'] = univ_canton_abb

# %% [markdown]
# Group the dataframe by their ids (cantons) and conver the unit to million francs

# %%
series = name_x_grant_x_geo.groupby('id').sum().reset_index()
series.grant = series.grant/10**6
series
# Out:
#     id        grant
# 0   AG   122.711379
# 1   BE  1524.119575
# 2   BL    46.248056
# 3   BS  1404.081126
# 4   FR   492.189387
# 5   GE  1879.078880
# 6   GR    17.368351
# 7   JU    35.593651
# 8   LU    54.673287
# 9   NE   402.525027
# 10  SG    91.194102
# 11  SH     0.176691
# 12  SZ    31.965246
# 13  TG     4.018981
# 14  TI   115.262320
# 15  VD  2400.225216
# 16  VS    27.666750
# 17  ZG     0.495715
# 18  ZH  3719.884887

# %% [markdown]
# # Plot

# %% [markdown]
# Plot a map which combines the information from dataframe and topojson of Switzerland.
#
# The color of map reflects the amount of grants approved in each canton (in million francs).
#
# The location of each university is also marked in the map. Note that the `marker_cluster` we used will automatically
# aggragate the number of universities when zoomed.

# %%
topo_path1 = r'ch-cantons.topojson.json'
ch_map = folium.Map(location=[46.8418522,7.9253733], tiles='Mapbox Bright', zoom_start=8)
ch_map.choropleth(geo_path=topo_path1,
                  data = series,
                  columns=['id', 'grant'],
                  key_on = "feature.id",
                  fill_color='YlGn',
                  fill_opacity=0.3,
                  line_weight=2,
                  threshold_scale=[600, 1200, 1800, 2400, 3000, 3600],
                  legend_name='Grants approved (million francs)',
                  topojson='objects.cantons')

# %%
marker_cluster = folium.MarkerCluster().add_to(ch_map)

for i in range(len(uname)):
    folium.Marker(
        location=[float(lat[i]), float(lng[i])],
        popup=uname[i],
        icon=folium.Icon(color='red', icon='ok-sign'),
    ).add_to(marker_cluster)

ch_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %% [markdown]
# # bonus

# %%
swiss_df
# Out:
#                                                     Project Title  \
# Project Number
# 4               Batterie de tests à l'usage des enseignants po...
# 6               Katalog der datierten Handschriften in der Sch...
# 8               Die schweizerische Wirtschaftspolitik seit dem...
# 9               Theologische Forschungen zur Oekumene (Studien...
# 10              Konfuzianische Kulturwerte in der sozialen Ent...
# 11              Edizione degli scritti di Aurelio de' Giorgi B...
# 13              La construction de nouveautés au sein des morp...
# 14              Wissensstruktur, Fragegenese und Wissenserweit...
# 18              L'école et la vie: examens pédagogiques des re...
# 19                Das Ringen um soziale Sicherheit in der Schweiz
# 20              Kolloquium zum Thema "Ein System Sozialer Indi...
# 21              Struktur und Funktion didaktischer Bezugssyste...
# 23              Psycholinguistique génétique: l'évolution des ...
# 25              Grösse, Verwaltungsstruktur und Entwicklung sc...
# 27              Déviants sociaux et culturels, réseaux lausannois
# 28              Evaluation de quelques objectifs d'une école e...
# 30              Werte und Wertordnungen in der schweizerischen...
# 32              Der Einfluss kleinstaatlicher Bedingungen auf ...
# 33              Etude des instruments heuristiques propres à f...
# 38              Hateruma, sozio-religiöse Aspekte einer Inselk...
# 39              Chronologie und Oekologie schweizerischer ur- ...
# 42                  Llibre del Consolat de Mar. Kritische Ausgabe
# 44              Recherche de la documentation archivistique co...
# 48              Recherche sur la musique des habitants de Oual...
# 49                                  Auvernier, fouilles 1969-1975
# 50              Limites de la composition des constances visue...
# 54                      Internationale Oekumenische Bibliographie
# 55              Determinanten für den erfolgreichen Abschluss ...
# 56                Ein System sozialer Indikatoren für die Schweiz
# 57                             Edition der Amerbach-Korrespondenz
# ...                                                           ...
# 168927          Die Macht der Symbole. Die Alhambra in einem g...
# 168932                Biointerfaces International Conference 2016
# 168934          L'Afrique émergente. Dynamiques politiques de ...
# 168944          Souvenirs, notes et pensées intimes di Flauber...
# 168954          Warriors without Weapons: Humanitarian Action ...
# 168956          XIIIe Colloque de l'Association Internationale...
# 168979          Gesundheitliches Wissen in der Schule. Schulhy...
# 168992                                          Gebannte Bewegung
# 169097          Literatur und (ihre) Institutionen. Hetero- un...
# 169098          In and Out of Europe: British Literary and Cul...
# 169100          Tagungen des Congressi Stefano Franscini 2016/...
# 169173          DIA IV: Repenser la variation linguistique / R...
# 169174          Chercher la régularité pour ne trouver que le ...
# 169270                  Les individus dans l’événement politique
# 169317          Kirchengebäude in urbanen Gebieten. Wahrnehmun...
# 169383          Les circulations étudiantes dans l’espace fran...
# 169720          28ème Conférence Francophone sur l’Interaction...
# 170002          Minds of Animals: Reflections on the Human – n...
# 170351          Jenseits des Unbehagens: Christian Kracht revi...
# 170363          Poursuivre sur la lancée : renforcer le respec...
# 170364          La conception d'un artefact : approches ergono...
# 170414          Gleichstellungspolitik öffentlicher Arbeitgebe...
# 170813          NRP68 partial synthesis on spatial development...
# 170814          Thematic Synthesis NRP68: Soil Data, Methods a...
# 170883          Does Religion Make a Difference? Discourses an...
# 170953          Conference "Human : Non-Human: Body, things, a...
# 171009          Inventer la littérature médiévale (XVIe-XVIIe ...
# 171113                                  La fin de l'intériorité ?
# 171114                          Faulheit – Spielformen des Faulen
# 171126                       Sound Colour Space - Abschlusstagung
#
#                                             Project Title English  \
# Project Number
# 4                                                             NaN
# 6                                                             NaN
# 8                                                             NaN
# 9                                                             NaN
# 10                                                            NaN
# 11                                                            NaN
# 13                                                            NaN
# 14                                                            NaN
# 18                                                            NaN
# 19                                                            NaN
# 20                                                            NaN
# 21                                                            NaN
# 23                                                            NaN
# 25                                                            NaN
# 27                                                            NaN
# 28                                                            NaN
# 30                                                            NaN
# 32                                                            NaN
# 33                                                            NaN
# 38                                                            NaN
# 39                                                            NaN
# 42                                                            NaN
# 44                                                            NaN
# 48                                                            NaN
# 49                                                            NaN
# 50                                                            NaN
# 54                                                            NaN
# 55                                                            NaN
# 56                                                            NaN
# 57                                                            NaN
# ...                                                           ...
# 168927          The Power of Symbols. The Alhambra in a Global...
# 168932                Biointerfaces International Conference 2016
# 168934          Emerging Africa. The politics of economic grow...
# 168944          Souvenirs, notes et pensées intimes di Flauber...
# 168954                                                        NaN
# 168956          XIIIth Conference of the Association Internati...
# 168979          Health knowledge in school. School hygiene in ...
# 168992                                                        NaN
# 169097          Literature and Institution. Hetero- and Autono...
# 169098                                                        NaN
# 169100          Tagungen des Congressi Stefano Franscini 2016/...
# 169173                               Language Variation Revisited
# 169174          Looking for regularity and only finding chaos?...
# 169270                            Individuals in Political Events
# 169317          Church Buildings in Urban Areas. Perception - ...
# 169383          Students circulations in the french-speaking w...
# 169720          28th French-speaking conference on Human-Compu...
# 170002          Minds of Animals: Reflections on the Human – n...
# 170351                                                        NaN
# 170363          Building on the momentum: Strengthening compli...
# 170364          The artifact design : ergonomic and didactic a...
# 170414          Equal Opportunity Policies of Public Employers...
# 170813          NRP68 partial synthesis on spatial development...
# 170814                                                        NaN
# 170883          Does Religion Make a Difference? Discourses an...
# 170953                                                        NaN
# 171009          Inventing medieval literature (16th-17th century)
# 171113                                  La fin de l'intériorité ?
# 171114                                                        NaN
# 171126                      Sound Colour Space - Final Conference
#
#                         Responsible Applicant  \
# Project Number
# 4                          Massarenti Léonard
# 6                              Burckhardt Max
# 8                         Kleinewefers Henner
# 9                         Stirnimann Heinrich
# 10                           Deuchler Martina
# 11                            Stäuble Antonio
# 13                                Piaget Jean
# 14                             Flammer August
# 18                                Girod Roger
# 19                              Borner Silvio
# 20              Hoffmann-Nowotny Hans-Joachim
# 21                              Santini Bruno
# 23                           Sinclair Hermina
# 25                               Heintz Peter
# 27                            Willener Alfred
# 28                           Huberman Michael
# 30                               Rüegg Walter
# 32                                Frei Daniel
# 33                                Roulet Eddy
# 38                         Ouwehand Cornelius
# 39                            Bosshard Walter
# 42                               Colon German
# 44                              Fatio Olivier
# 48                                 Gabus Jean
# 49                             Sauter Marc-R.
# 50                            Vonèche Jacques
# 54                        Stirnimann Heinrich
# 55                              Hürsch Luzius
# 56              Hoffmann-Nowotny Hans-Joachim
# 57                               Gröbli Fredy
# ...                                       ...
# 168927                  Giese-Vögeli Francine
# 168932                            Vörös Janos
# 168934                         Péclard Didier
# 168944                       Di Febo Giuliana
# 168954                  Martín Moruno Dolores
# 168956                        Fuchs Michel E.
# 168979                        Hofmann Michèle
# 168992                         Wiegand Daniel
# 169097                         Thüring Hubert
# 169098                          Habermann Ina
# 169100                  Cometta-Morini Chiara
# 169173                          Völker Harald
# 169174                        Stark Elisabeth
# 169270                 Bennani-Chraibi Mounia
# 169317                           Keller Sonja
# 169383                     Gillabert Matthieu
# 169720                          Lalanne Denis
# 170002                          Bailoo Jeremy
# 170351                     Lorenz Matthias N.
# 170363                           Jaffé Philip
# 170364                            Didier John
# 170414                           Fuchs Gesine
# 170813                  Grêt-Regamey Adrienne
# 170814                           Keller Armin
# 170883                       Köhrsen Jens-Ole
# 170953                       Malinar Angelika
# 171009                          Dahhaoui Yann
# 171113                       Pierron Nathalie
# 171114                         Stetter Bitten
# 171126                          Neukom Martin
#
#                                           Funding Instrument  \
# Project Number
# 4                               Project funding (Div. I-III)
# 6                               Project funding (Div. I-III)
# 8                               Project funding (Div. I-III)
# 9                               Project funding (Div. I-III)
# 10                              Project funding (Div. I-III)
# 11                              Project funding (Div. I-III)
# 13                              Project funding (Div. I-III)
# 14                              Project funding (Div. I-III)
# 18                              Project funding (Div. I-III)
# 19                              Project funding (Div. I-III)
# 20                              Project funding (Div. I-III)
# 21                              Project funding (Div. I-III)
# 23                              Project funding (Div. I-III)
# 25                              Project funding (Div. I-III)
# 27                              Project funding (Div. I-III)
# 28                              Project funding (Div. I-III)
# 30                              Project funding (Div. I-III)
# 32                              Project funding (Div. I-III)
# 33                              Project funding (Div. I-III)
# 38                              Project funding (Div. I-III)
# 39                              Project funding (Div. I-III)
# 42                              Project funding (Div. I-III)
# 44                              Project funding (Div. I-III)
# 48                              Project funding (Div. I-III)
# 49                              Project funding (Div. I-III)
# 50                              Project funding (Div. I-III)
# 54                              Project funding (Div. I-III)
# 55                              Project funding (Div. I-III)
# 56                              Project funding (Div. I-III)
# 57                              Project funding (Div. I-III)
# ...                                                      ...
# 168927                                Scientific Conferences
# 168932                                Scientific Conferences
# 168934                                Scientific Conferences
# 168944                                                Doc.CH
# 168954                                Scientific Conferences
# 168956                                Scientific Conferences
# 168979                                    Publication grants
# 168992                                    Publication grants
# 169097                                Scientific Conferences
# 169098                                Scientific Conferences
# 169100                                Scientific Conferences
# 169173                                Scientific Conferences
# 169174                                Scientific Conferences
# 169270                                Scientific Conferences
# 169317                                    Publication grants
# 169383                                Scientific Conferences
# 169720                                Scientific Conferences
# 170002                                Scientific Conferences
# 170351                                Scientific Conferences
# 170363                                Scientific Conferences
# 170364                                Scientific Conferences
# 170414                                    Publication grants
# 170813          NRP 68 Sustainable Use of Soil as a Resource
# 170814          NRP 68 Sustainable Use of Soil as a Resource
# 170883                   International Exploratory Workshops
# 170953                                Scientific Conferences
# 171009                                Scientific Conferences
# 171113                                Scientific Conferences
# 171114                                Scientific Conferences
# 171126                                Scientific Conferences
#
#                                   Funding Instrument Hierarchy  \
# Project Number
# 4                                              Project funding
# 6                                              Project funding
# 8                                              Project funding
# 9                                              Project funding
# 10                                             Project funding
# 11                                             Project funding
# 13                                             Project funding
# 14                                             Project funding
# 18                                             Project funding
# 19                                             Project funding
# 20                                             Project funding
# 21                                             Project funding
# 23                                             Project funding
# 25                                             Project funding
# 27                                             Project funding
# 28                                             Project funding
# 30                                             Project funding
# 32                                             Project funding
# 33                                             Project funding
# 38                                             Project funding
# 39                                             Project funding
# 42                                             Project funding
# 44                                             Project funding
# 48                                             Project funding
# 49                                             Project funding
# 50                                             Project funding
# 54                                             Project funding
# 55                                             Project funding
# 56                                             Project funding
# 57                                             Project funding
# ...                                                        ...
# 168927                                   Science communication
# 168932                                   Science communication
# 168934                                   Science communication
# 168944                                                 Careers
# 168954                                   Science communication
# 168956                                   Science communication
# 168979                                   Science communication
# 168992                                   Science communication
# 169097                                   Science communication
# 169098                                   Science communication
# 169100                                   Science communication
# 169173                                   Science communication
# 169174                                   Science communication
# 169270                                   Science communication
# 169317                                   Science communication
# 169383                                   Science communication
# 169720                                   Science communication
# 170002                                   Science communication
# 170351                                   Science communication
# 170363                                   Science communication
# 170364                                   Science communication
# 170414                                   Science communication
# 170813          Programmes;National Research Programmes (NRPs)
# 170814          Programmes;National Research Programmes (NRPs)
# 170883                                   Science communication
# 170953                                   Science communication
# 171009                                   Science communication
# 171113                                   Science communication
# 171114                                   Science communication
# 171126                                   Science communication
#
#                                                       Institution  \
# Project Number
# 4               Faculté de Psychologie et des Sciences de l'Ed...
# 6               Abt. Handschriften und Alte Drucke Bibliothek ...
# 8               Séminaire de politique économique, d'économie ...
# 9               Institut für ökumenische Studien Université de...
# 10                      Ostasiatisches Seminar Universität Zürich
# 11                                                            NaN
# 13              Laboratoire de Didactique et Epistémologie des...
# 14              Klinische Psychologie und Psychotherapie Insti...
# 18              Département de Sociologie Faculté des Sciences...
# 19              Institut für Volkswirtschaft WWZ / FGS Univers...
# 20                     Soziologisches Institut Universität Zürich
# 21                                          Forschungszentrum FAL
# 23              Faculté de Psychologie et des Sciences de l'Ed...
# 25                     Soziologisches Institut Universität Zürich
# 27                                                            NaN
# 28              Faculté de Psychologie et des Sciences de l'Ed...
# 30                                                            NaN
# 32              Forschungsbereich Politisches Verhalten und Oe...
# 33              Département des langues et des littératures fr...
# 38                                                            NaN
# 39              Eidg. Forschungsanstalt für Wald, Schnee und L...
# 42                 Institut für Iberoromanistik Universität Basel
# 44                      Faculté de Théologie Université de Genève
# 48                                                            NaN
# 49              Unité d'anthropologie Département de génétique...
# 50              Faculté de Psychologie et des Sciences de l'Ed...
# 54              Institut für ökumenische Studien Université de...
# 55              Klinische Psychologie und Psychotherapie Insti...
# 56                     Soziologisches Institut Universität Zürich
# 57                      Universitätsbibliothek Basel Pressestelle
# ...                                                           ...
# 168927              Kunsthistorisches Institut Universität Zürich
# 168932          Institut für Biomedizinische Technik Universit...
# 168934              Global Studies Institute Université de Genève
# 168944          Istituto di Studi Italiani Facoltà di Scienze ...
# 168954          Institut Ethique Histoire Humanités - iEH2 Fac...
# 168956          Institut d'Archéologie et des Sciences de l'An...
# 168979          Pädagogische Hochschule Fachhochschule Nordwes...
# 168992            Seminar für Filmwissenschaft Universität Zürich
# 169097                        Deutsches Seminar Universität Basel
# 169098                       Englisches Seminar Universität Basel
# 169100                             Centro Stefano Franscini (CSF)
# 169173                     Romanisches Seminar Universität Zürich
# 169174                     Romanisches Seminar Universität Zürich
# 169270          Institut d'études politiques, historiques et i...
# 169317                   Theologische Fakultät Universität Zürich
# 169383          Institut des Sciences sociales du Politique IS...
# 169720          Département d'Informatique Université de Fribourg
# 170002                 Institut für Tieranatomie Universität Bern
# 170351          Institut für Germanistik Philosophisch-histori...
# 170363          Centre interfacultaire en droits de l'enfant  ...
# 170364                                 Haute Ecole Pédagogique VD
# 170414          Institut Sozialmanagement und Sozialpolitik Ho...
# 170813          Planning of Landscape and Urban Systems Instit...
# 170814          Forschungsanstalt Agroscope Reckenholz-Tänikon...
# 170883          Zentrum für Religion, Wirtschaft und Politik T...
# 170953                 Abteilung für Indologie Universität Zürich
# 171009          Institut Religions, Cultures, Modernité FTSR U...
# 171113             Haute École d'art et de design - Genève HES-SO
# 171114          Departement Design Zürcher Hochschule der Küns...
# 171126          Institute Performing Arts and Film Zürcher Hoc...
#
#                                                        University  \
# Project Number
# 4                                       Université de Genève - GE
# 6                                          Universität Basel - BS
# 8                                     Université de Fribourg - FR
# 9                                     Université de Fribourg - FR
# 10                                        Universität Zürich - ZH
# 11                                    Université de Lausanne - LA
# 13                                      Université de Genève - GE
# 14                                    Université de Fribourg - FR
# 18                                      Université de Genève - GE
# 19                                         Universität Basel - BS
# 20                                        Universität Zürich - ZH
# 21                                    Université de Fribourg - FR
# 23                                      Université de Genève - GE
# 25                                        Universität Zürich - ZH
# 27                                    Université de Lausanne - LA
# 28                                      Université de Genève - GE
# 30                                          Universität Bern - BE
# 32                                        Universität Zürich - ZH
# 33                                      Université de Genève - GE
# 38                                        Universität Zürich - ZH
# 39              Eidg. Forschungsanstalt für Wald,Schnee,Land -...
# 42                                         Universität Basel - BS
# 44                                      Université de Genève - GE
# 48                                   Université de Neuchâtel - NE
# 49                                      Université de Genève - GE
# 50                                      Université de Genève - GE
# 54                                    Université de Fribourg - FR
# 55                                          Universität Bern - BE
# 56                                        Universität Zürich - ZH
# 57                                         Universität Basel - BS
# ...                                                           ...
# 168927                                    Universität Zürich - ZH
# 168932                                          ETH Zürich - ETHZ
# 168934                                  Université de Genève - GE
# 168944                   Università della Svizzera italiana - USI
# 168954                                  Université de Genève - GE
# 168956                                Université de Lausanne - LA
# 168979           Pädagogische Hochschule Nordwestschweiz - PHFHNW
# 168992                                    Universität Zürich - ZH
# 169097                                     Universität Basel - BS
# 169098                                     Universität Basel - BS
# 169100                                          ETH Zürich - ETHZ
# 169173                                    Universität Zürich - ZH
# 169174                                    Universität Zürich - ZH
# 169270                                Université de Lausanne - LA
# 169317                                    Universität Zürich - ZH
# 169383                                Université de Fribourg - FR
# 169720                                Université de Fribourg - FR
# 170002                                      Universität Bern - BE
# 170351                                      Universität Bern - BE
# 170363                                  Université de Genève - GE
# 170364           Haute école pédagogique du canton de Vaud - HEPL
# 170414                                   Hochschule Luzern - HSLU
# 170813                                          ETH Zürich - ETHZ
# 170814                        Forschungsanstalten Agroscope - AGS
# 170883                                     Universität Basel - BS
# 170953                                    Universität Zürich - ZH
# 171009                                Université de Lausanne - LA
# 171113                         HES de Suisse occidentale - HES-SO
# 171114                     Zürcher Fachhochschule (ohne PH) - ZFH
# 171126                     Zürcher Fachhochschule (ohne PH) - ZFH
#
#                 Discipline Number  \
# Project Number
# 4                           10104
# 6                           10302
# 8                           10203
# 9                           10102
# 10                          10301
# 11                          10502
# 13                          10105
# 14                          10105
# 18                          10201
# 19                          10203
# 20                          10201
# 21                          10104
# 23                          10105
# 25                          10201
# 27                          10201
# 28                          10104
# 30                          10201
# 32                          10202
# 33                          10502
# 38                          10403
# 39                          10402
# 42                          10502
# 44                          10404
# 48                          10403
# 49                          10401
# 50                          10105
# 54                          10102
# 55                          10104
# 56                          10201
# 57                          10302
# ...                           ...
# 168927                      10404
# 168932                      20505
# 168934                      10202
# 168944                      10502
# 168954                      10301
# 168956                      10402
# 168979                      10104
# 168992                      10406
# 169097                      10501
# 169098                      10501
# 169100                      20100
# 169173                      10502
# 169174                      10502
# 169270                      10202
# 169317                      10102
# 169383                      10301
# 169720                      20506
# 170002                      10101
# 170351                      10501
# 170363                      10104
# 170364                      10104
# 170414                      10202
# 170813                      20511
# 170814                      20701
# 170883                      10102
# 170953                      10503
# 171009                      10301
# 171113                      10603
# 171114                      10603
# 171126                      10604
#
#                                             Discipline Name  \
# Project Number
# 4                          Educational science and Pedagogy
# 6                                             Swiss history
# 8                                                 Economics
# 9                              Religious sciences, Theology
# 10                                       History in general
# 11                         Romance languages and literature
# 13                                               Psychology
# 14                                               Psychology
# 18                                                Sociology
# 19                                                Economics
# 20                                                Sociology
# 21                         Educational science and Pedagogy
# 23                                               Psychology
# 25                                                Sociology
# 27                                                Sociology
# 28                         Educational science and Pedagogy
# 30                                                Sociology
# 32                                        Political science
# 33                         Romance languages and literature
# 38                                                Ethnology
# 39                                              Archaeology
# 42                         Romance languages and literature
# 44                              Visual arts and Art history
# 48                                                Ethnology
# 49                                               Prehistory
# 50                                               Psychology
# 54                             Religious sciences, Theology
# 55                         Educational science and Pedagogy
# 56                                                Sociology
# 57                                            Swiss history
# ...                                                     ...
# 168927                          Visual arts and Art history
# 168932                                    Material Sciences
# 168934                                    Political science
# 168944                     Romance languages and literature
# 168954                                   History in general
# 168956                                          Archaeology
# 168979                     Educational science and Pedagogy
# 168992                                   Theater and Cinema
# 169097          German and English languages and literature
# 169098          German and English languages and literature
# 169100                                          Mathematics
# 169173                     Romance languages and literature
# 169174                     Romance languages and literature
# 169270                                    Political science
# 169317                         Religious sciences, Theology
# 169383                                   History in general
# 169720                                 Information Sciences
# 170002                                           Philosophy
# 170351          German and English languages and literature
# 170363                     Educational science and Pedagogy
# 170364                     Educational science and Pedagogy
# 170414                                    Political science
# 170813            Other disciplines of Engineering Sciences
# 170814                                             Pedology
# 170883                         Religious sciences, Theology
# 170953                       Other languages and literature
# 171009                                   History in general
# 171113                                                 Arts
# 171114                                                 Arts
# 171126                                       Music, Theatre
#
#                                         Discipline Name Hierarchy  Start Date  \
# Project Number
# 4               Human and Social Sciences;Psychology, educatio...  01.10.1975
# 6               Human and Social Sciences;Theology & religious...  01.10.1975
# 8                        Human and Social Sciences;Economics, law  01.01.1976
# 9               Human and Social Sciences;Theology & religious...  01.01.1976
# 10              Human and Social Sciences;Theology & religious...  01.10.1975
# 11              Human and Social Sciences;Linguistics and lite...  01.10.1975
# 13              Human and Social Sciences;Psychology, educatio...  01.10.1975
# 14              Human and Social Sciences;Psychology, educatio...  01.10.1975
# 18              Human and Social Sciences;Sociology, social wo...  01.10.1975
# 19                       Human and Social Sciences;Economics, law  01.10.1975
# 20              Human and Social Sciences;Sociology, social wo...  01.10.1975
# 21              Human and Social Sciences;Psychology, educatio...  01.10.1975
# 23              Human and Social Sciences;Psychology, educatio...  01.10.1975
# 25              Human and Social Sciences;Sociology, social wo...  01.01.1976
# 27              Human and Social Sciences;Sociology, social wo...  01.12.1975
# 28              Human and Social Sciences;Psychology, educatio...  01.10.1975
# 30              Human and Social Sciences;Sociology, social wo...  01.10.1975
# 32              Human and Social Sciences;Sociology, social wo...  01.01.1976
# 33              Human and Social Sciences;Linguistics and lite...  01.10.1975
# 38              Human and Social Sciences;Ethnology, social an...  01.10.1975
# 39              Human and Social Sciences;Theology & religious...  01.10.1975
# 42              Human and Social Sciences;Linguistics and lite...  01.10.1975
# 44              Human and Social Sciences;Art studies, musicol...  01.10.1975
# 48              Human and Social Sciences;Ethnology, social an...  01.12.1975
# 49              Human and Social Sciences;Theology & religious...  01.01.1976
# 50              Human and Social Sciences;Psychology, educatio...  01.10.1975
# 54              Human and Social Sciences;Theology & religious...  01.02.1976
# 55              Human and Social Sciences;Psychology, educatio...  01.10.1975
# 56              Human and Social Sciences;Sociology, social wo...  01.10.1975
# 57              Human and Social Sciences;Theology & religious...  01.10.1975
# ...                                                           ...         ...
# 168927          Human and Social Sciences;Art studies, musicol...  01.09.2016
# 168932          Mathematics, Natural- and Engineering Sciences...  01.08.2016
# 168934          Human and Social Sciences;Sociology, social wo...  01.09.2016
# 168944          Human and Social Sciences;Linguistics and lite...  01.09.2016
# 168954          Human and Social Sciences;Theology & religious...  01.10.2016
# 168956          Human and Social Sciences;Theology & religious...  01.09.2016
# 168979          Human and Social Sciences;Psychology, educatio...  01.05.2016
# 168992          Human and Social Sciences;Art studies, musicol...  01.05.2016
# 169097          Human and Social Sciences;Linguistics and lite...  01.09.2016
# 169098          Human and Social Sciences;Linguistics and lite...  01.09.2016
# 169100             Mathematics, Natural- and Engineering Sciences  01.08.2016
# 169173          Human and Social Sciences;Linguistics and lite...  01.09.2016
# 169174          Human and Social Sciences;Linguistics and lite...  01.09.2016
# 169270          Human and Social Sciences;Sociology, social wo...  01.09.2016
# 169317          Human and Social Sciences;Theology & religious...  01.05.2016
# 169383          Human and Social Sciences;Theology & religious...  01.09.2016
# 169720          Mathematics, Natural- and Engineering Sciences...  01.10.2016
# 170002          Human and Social Sciences;Linguistics and lite...  01.09.2016
# 170351          Human and Social Sciences;Linguistics and lite...  01.10.2016
# 170363          Human and Social Sciences;Psychology, educatio...  01.09.2016
# 170364          Human and Social Sciences;Psychology, educatio...  01.10.2016
# 170414          Human and Social Sciences;Sociology, social wo...  01.08.2016
# 170813          Mathematics, Natural- and Engineering Sciences...  01.10.2016
# 170814          Mathematics, Natural- and Engineering Sciences...  01.10.2016
# 170883          Human and Social Sciences;Theology & religious...  01.10.2016
# 170953          Human and Social Sciences;Linguistics and lite...  01.10.2016
# 171009          Human and Social Sciences;Theology & religious...  01.10.2016
# 171113          Human and Social Sciences;Art studies, musicol...  01.10.2016
# 171114          Human and Social Sciences;Art studies, musicol...  01.10.2016
# 171126          Human and Social Sciences;Art studies, musicol...  01.09.2016
#
#                   End Date  Approved Amount  \
# Project Number
# 4               30.09.1976          41022.0
# 6               30.09.1976          52627.0
# 8               31.12.1978          53009.0
# 9               31.12.1976          25403.0
# 10              31.03.1977          47100.0
# 11              31.03.1977          25814.0
# 13              30.09.1978         360000.0
# 14              31.12.1978         153886.0
# 18              30.09.1977         116991.0
# 19              31.12.1978         112664.0
# 20              31.12.1975           5000.0
# 21              30.09.1977         204018.0
# 23              30.09.1977         149485.0
# 25              31.08.1977          83983.0
# 27              31.01.1977          14138.0
# 28              30.09.1978         164602.0
# 30              30.04.1978         147795.0
# 32              30.06.1977          24552.0
# 33              30.09.1978          44802.0
# 38              31.03.1976          20000.0
# 39              30.09.1978         445198.0
# 42              30.09.1976          19134.0
# 44              30.09.1977          13807.0
# 48              31.05.1979          51904.0
# 49              31.03.1978         462615.0
# 50              28.02.1981         143070.0
# 54              31.01.1978          63684.0
# 55              31.03.1977         154420.0
# 56              31.03.1977         117564.0
# 57              31.03.1977          64279.0
# ...                    ...              ...
# 168927          30.11.2016          11600.0
# 168932          30.11.2016          16000.0
# 168934          30.11.2016           4600.0
# 168944          31.08.2020         251554.0
# 168954          31.12.2016           5700.0
# 168956          30.11.2016          10000.0
# 168979          31.05.2016           7990.0
# 168992          31.05.2016          12416.0
# 169097          30.11.2016           1600.0
# 169098          30.11.2016           3200.0
# 169100          31.07.2017         120000.0
# 169173          30.11.2016           6300.0
# 169174          30.09.2016           1500.0
# 169270          30.11.2016          11782.0
# 169317          31.05.2016           2600.0
# 169383          30.09.2016           7700.0
# 169720          31.12.2016           2500.0
# 170002          30.11.2016           5900.0
# 170351          31.12.2016           7500.0
# 170363          30.11.2016           3000.0
# 170364          31.03.2017           3600.0
# 170414          31.07.2017           1898.0
# 170813          30.09.2017          99952.0
# 170814          31.12.2017          98040.0
# 170883          31.12.2016          10030.0
# 170953          31.12.2016          10600.0
# 171009          31.12.2016           2515.0
# 171113          31.12.2016           3000.0
# 171114          31.12.2016           1000.0
# 171126          30.11.2016           2000.0
#
#                                                          Keywords
# Project Number
# 4                                                             NaN
# 6                                                             NaN
# 8                                                             NaN
# 9                                                             NaN
# 10                                                            NaN
# 11                                                            NaN
# 13                                                            NaN
# 14                                                            NaN
# 18                                                            NaN
# 19                                                            NaN
# 20                                                            NaN
# 21                                                            NaN
# 23                                                            NaN
# 25                                                            NaN
# 27                                                            NaN
# 28                                                            NaN
# 30                                                            NaN
# 32                                                            NaN
# 33                                                            NaN
# 38                                                            NaN
# 39                                                            NaN
# 42                                                            NaN
# 44                                                            NaN
# 48                                                            NaN
# 49                                                            NaN
# 50                                                            NaN
# 54                                                            NaN
# 55                                                            NaN
# 56                                                            NaN
# 57                                                            NaN
# ...                                                           ...
# 168927               Alhambra, Iberische Halbinsel, Orientalismus
# 168932          Surface Science & Technology;Bioinspired Mater...
# 168934                Afrique;Croissance économique;Développement
# 168944              Literature;Translation;Poetry;Prose;Criticism
# 168954          History of Humanitarianism;Spanish Civil War;R...
# 168956          Peinture murale;Monde grec;Monde hellénistique...
# 168979          Schule;Gesundheit;19. Jahrhundert;20. Jahrhund...
# 168992          Film history;Media history;Art history;Visual ...
# 169097          Institution;Autonomie;Heteronomie;Recht;Legiti...
# 169098          European Britain;Geopolitics;Euroscepticism;Co...
# 169100                                                        CSF
# 169173          Linguistik;Romanische Sprachen;Variation;Varie...
# 169174          galloroman;morphosyntaxe;dialectes;clitiques;v...
# 169270          Evénement politique;Individu;Politisation;Mouv...
# 169317          Kirchengebäude;Empirische Religionsforschung;K...
# 169383          migrations étudiantes;circulation académique;f...
# 169720                                  Interaction Homme-Machine
# 170002          Cognition;Primatology;Evolution;Mental States;...
# 170351          Christian Kracht;Werkpolitik;Gegenwartsliterat...
# 170363          Guidelines ;the Alternative Care ;Children's r...
# 170364                      Design;Artefact;Education;Creativity
# 170414          Gleichstellungspolitik;Betriebliche Gleichstel...
# 170813                  Synthesis;Spatial Planning;Soil resources
# 170814          soil survey;cost benefit analysis;soil informa...
# 170883          Religion;Development;Global South;Sustainabili...
# 170953          Asia and Europe;Posthumanism;environmentalism;...
# 171009          Histoire des savoirs;Histoire de l'érudition;H...
# 171113          architecture d'intérieur;espace;architecture;t...
# 171114          Cultural Studies;Sociology;Design Research;Phi...
# 171126          Diagrammatologie;Klangfarbe;Tonsysteme;Farbe/T...
#
# [46188 rows x 14 columns]

# %%
swiss_df.groupby('Discipline Number').sum()()
