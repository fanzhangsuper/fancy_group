# %%
from os import path
from wordcloud import WordCloud, STOPWORDS
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sys
import nltk
from scipy.stats import itemfreq
import pycountry
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# You may need these data

# %%
nltk.download('twitter_samples'),nltk.download('opinion_lexicon')
nltk.download("vader_lexicon"), nltk.download('punkt')
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package twitter_samples to
# [nltk_data]     /Users/helie/nltk_data...
# [nltk_data]   Package twitter_samples is already up-to-date!
# [nltk_data] Downloading package opinion_lexicon to
# [nltk_data]     /Users/helie/nltk_data...
# [nltk_data]   Package opinion_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/helie/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/helie/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/helie/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
current_directory = 'hillary-clinton-emails/'
df = pd.read_csv(current_directory + 'Emails.csv', index_col=0)
df.head()
# Out:
#     DocNumber                                    MetadataSubject  \
# Id
# 1   C05739545                                                WOW
# 2   C05739546  H: LATEST: HOW SYRIA IS AIDING QADDAFI AND MOR...
# 3   C05739547                                      CHRIS STEVENS
# 4   C05739550                         CAIRO CONDEMNATION - FINAL
# 5   C05739554  H: LATEST: HOW SYRIA IS AIDING QADDAFI AND MOR...
#
#       MetadataTo       MetadataFrom  SenderPersonId  \
# Id
# 1              H  Sullivan, Jacob J            87.0
# 2              H                NaN             NaN
# 3             ;H    Mills, Cheryl D            32.0
# 4              H    Mills, Cheryl D            32.0
# 5   Abedin, Huma                  H            80.0
#
#              MetadataDateSent       MetadataDateReleased  \
# Id
# 1   2012-09-12T04:00:00+00:00  2015-05-22T04:00:00+00:00
# 2   2011-03-03T05:00:00+00:00  2015-05-22T04:00:00+00:00
# 3   2012-09-12T04:00:00+00:00  2015-05-22T04:00:00+00:00
# 4   2012-09-12T04:00:00+00:00  2015-05-22T04:00:00+00:00
# 5   2011-03-11T05:00:00+00:00  2015-05-22T04:00:00+00:00
#
#                                       MetadataPdfLink MetadataCaseNumber  \
# Id
# 1   DOCUMENTS/HRC_Email_1_296/HRCH2/DOC_0C05739545...       F-2015-04841
# 2   DOCUMENTS/HRC_Email_1_296/HRCH1/DOC_0C05739546...       F-2015-04841
# 3   DOCUMENTS/HRC_Email_1_296/HRCH2/DOC_0C05739547...       F-2015-04841
# 4   DOCUMENTS/HRC_Email_1_296/HRCH2/DOC_0C05739550...       F-2015-04841
# 5   DOCUMENTS/HRC_Email_1_296/HRCH1/DOC_0C05739554...       F-2015-04841
#
#    MetadataDocumentClass                        ...                          \
# Id                                              ...
# 1          HRC_Email_296                        ...
# 2          HRC_Email_296                        ...
# 3          HRC_Email_296                        ...
# 4          HRC_Email_296                        ...
# 5          HRC_Email_296                        ...
#
#    ExtractedTo                             ExtractedFrom         ExtractedCc  \
# Id
# 1          NaN  Sullivan, Jacob J <Sullivan11@state.gov>                 NaN
# 2          NaN                                       NaN                 NaN
# 3           B6       Mills, Cheryl D <MillsCD@state.gov>        Abedin, Huma
# 4          NaN       Mills, Cheryl D <MillsCD@state.gov>  Mitchell, Andrew B
# 5          NaN                                       NaN                 NaN
#
#                          ExtractedDateSent ExtractedCaseNumber  \
# Id
# 1   Wednesday, September 12, 2012 10:16 AM        F-2015-04841
# 2                                      NaN        F-2015-04841
# 3   Wednesday, September 12, 2012 11:52 AM        F-2015-04841
# 4    Wednesday, September 12,2012 12:44 PM        F-2015-04841
# 5                                      NaN        F-2015-04841
#
#    ExtractedDocNumber ExtractedDateReleased ExtractedReleaseInPartOrFull  \
# Id
# 1           C05739545            05/13/2015              RELEASE IN FULL
# 2           C05739546            05/13/2015              RELEASE IN PART
# 3           C05739547            05/14/2015              RELEASE IN PART
# 4           C05739550            05/13/2015              RELEASE IN PART
# 5           C05739554            05/13/2015              RELEASE IN PART
#
#                                     ExtractedBodyText  \
# Id
# 1                                                 NaN
# 2   B6\nThursday, March 3, 2011 9:45 PM\nH: Latest...
# 3                                                 Thx
# 4                                                 NaN
# 5   H <hrod17@clintonemail.com>\nFriday, March 11,...
#
#                                               RawText
# Id
# 1   UNCLASSIFIED\nU.S. Department of State\nCase N...
# 2   UNCLASSIFIED\nU.S. Department of State\nCase N...
# 3   UNCLASSIFIED\nU.S. Department of State\nCase N...
# 4   UNCLASSIFIED\nU.S. Department of State\nCase N...
# 5   B6\nUNCLASSIFIED\nU.S. Department of State\nCa...
#
# [5 rows x 21 columns]

# %% [markdown]
# ---
# # Word Cloud

# %%
def plot_word_cloud(wordcloud):
    plt.figure()
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.show()

# %% [markdown]
# ## Generate word cloud on raw corpus

# %% [markdown]
# First, we generate a wordcloud on raw corpus. The corpus we used here is `ExtractedBodyText` column in the `Eamil.csv`. As `WordCloud` will use default stopwords for filtering even if we didn't want, we have to manually set the stopwords to empty.

# %%
all_body_text = (df.loc[:, 'ExtractedBodyText'].dropna()).sum()

# %%
wordcloud = WordCloud(max_font_size=60, width=800, height=400)
wordcloud.stopwords = {}
wordcloud = wordcloud.generate(all_body_text)
plot_word_cloud(wordcloud)

# %% [markdown]
# ## Generate word cloud with preprocessing

# %% [markdown]
# ### Preprocessing Strategies
#
# 1. filter out some email word like `fw`, `fwd`, `subject` and so on
# 2. case folding: reduce all letters to lower case
# 3. ignoring punctuates
#
# TODO: (maybe)
#
# 1. Try Lemmatization
# 2. Try Stemming

# %% [markdown]
# ##### Remove Punctuation

# %%
import string
def remove_punctuation(text):
    return text.translate(str.maketrans({key: '' for key in string.punctuation}))

# %% [markdown]
# ##### Generate stopwords

# %%
email_word_list = ['fw', 'fwd', 'subject', 'to', 're', 'pm', 
                   'will', 'case', 'also', 're', 'call', 'may', 'mr', 'ms', 'mrs']
stopwords = set(email_word_list).union(set(STOPWORDS))

# %%
import re
# function to split the digits and letters of every entities in tokens
def split_digi_letter(tokens):
    # define a empty list, store the string after splitting the digits and letters
    tokens_refined = []
    for i in tokens:
        for j in re.findall('\d+|\D+', i):
            tokens_refined.append(j)
    return tokens_refined

# %% [markdown]
# ##### Processing words

# %%
# Concatenate all the Extracted Body Text
txt = (df.loc[:, 'ExtractedBodyText'].dropna()).sum()
txt = remove_punctuation(txt)
tokens = nltk.word_tokenize(txt)
tokens = [i.lower() for i in tokens if i.lower() not in stopwords]
tokens_origin = split_digi_letter(tokens)
tokens_freq = itemfreq(tokens_origin)
tokens, tokens_freq = tokens_freq[:, 0], tokens_freq[:, 1].astype(int)
tokens_x_freq = [(tokens[i], tokens_freq[i]) for i in range(len(tokens))]

# %% [markdown]
# ##### Create word cloud

# %%
wordcloud = WordCloud(max_font_size=80, 
                      stopwords=STOPWORDS, 
                      width=800, 
                      height=400,
                     max_words=500).generate_from_frequencies(tokens_x_freq)
plot_word_cloud(wordcloud)

# %% [markdown]
# In the above wordcloud, we find words like `president`, `department`, `obama`, `state`, `office`, `meeting` are very common in this cloud. It is reasonable to think that Hillary Clinton uses her private email server for official communications which may leak top secret of america.

# %% [markdown]
# #### Stemming

# %% [markdown]
# We will use *nltk.stem.lancaster*, *nltk.stem.snowball* and *nltk.stem.wordnet* module to stem the tokens.

# %%
from nltk.stem import SnowballStemmer, WordNetLemmatizer
from nltk.stem.lancaster import LancasterStemmer

# %%
st = LancasterStemmer()
pt = SnowballStemmer('english')
wnl = WordNetLemmatizer()

# %%
def compare_stem(word1, word2, method_name):
    """if two words have same """
    if method_name == wnl:
        return method_name.lemmatize(word1) == method_name.lemmatize(word2)
    else:
        return method_name.stem(word1) ==  method_name.stem(word2)

# %%
word1 = 'homegene'
word2 = 'homegeneous'
method_name = wnl
print('wnl method result: ',compare_stem(word1, word2, method_name))
method_name = st
print('st method result: ',compare_stem(word1, word2, method_name))
method_name = pt
print('pt method result: ',compare_stem(word1, word2, method_name))
# Out:
# wnl method result:  False
# st method result:  True
# pt method result:  True

# %% [markdown]
# Above results show that *wnl* method is more accurate than the other two. Hence, we use this method in the later analysis.

# %%
# stemming the tokens word by LancasterStemmer
token_stemmed = [wnl.lemmatize(i) for i in tokens_origin]

# %%
# Since we cannot get any information from digit strings,
# we will simply drop those strings and perform analysis to the rest.
token_stemmed_reduced = [i for i in token_stemmed if not i.isdigit()]
# drop single letter tokens
token_stemmed_reduced = [i for i in token_stemmed_reduced if len(i)>1]

# %% [markdown]
# ### Creat word cloud

# %%
tokens_freq_postprocess = itemfreq(token_stemmed_reduced)
tokens1, tokens_freq1 = tokens_freq_postprocess[:, 0], tokens_freq_postprocess[:, 1].astype(int)
tokens_x_freq = [(tokens1[i], tokens_freq1[i]) for i in range(len(tokens1))]

# %%
wordcloud = WordCloud(max_font_size=100, 
                      stopwords=STOPWORDS, 
                      width=800, 
                      height=400,
                     max_words=500).generate_from_frequencies(tokens_x_freq)
plot_word_cloud(wordcloud)

# %% [markdown]
# In the above wordcloud, we found a new list of words, like `secretary`, `president`, `department`, `obama`, `state`, `office`, `meeting`. They are very common in this cloud. It is reasonable to think that Hillary Clinton uses her private email server for official communications which may leak top secret of america.

# %% [markdown]
# ### Remining problem

# %%
# problem: how to segement these string which may contain useful informations
j = 0
k = 0
for i in token_stemmed_reduced:
    if len(i)>15:
        j = j+1
        k = k + len(i)
print('number of non-processed word:',j,', non-processed word total length', k)
# Out:
# number of non-processed word: 1811 , non-processed word total length 36790

# %% [markdown]
# ### Conclusion
#
# The first approach creates a wordcloud on raw corpus. It is very easy to use and reflects the frequencies of the words in the data. However, it has many disadvantages. Words like `a, the, be` ... dominates the screen. These words are frequently used in any context and they didn't provide useful information about the topic of email. Besides, words are not normalized.
#
# The second approach will process data first. By adding stopwords, tokenization, and stemming, we see a graph with much better results. Now it is much easier to know the topics of these emails without effort.

# %% [markdown]
# ## Exercise 2
#
# Find all the mentions of world countries in the whole corpus, using the `pycountry` utility (*HINT*: remember that
# there will be different surface forms for the same country in the text, e.g., Switzerland, switzerland, CH, etc.)
# Perform sentiment analysis on every email message using the demo methods in the `nltk.sentiment.util` module. Aggregate
# the polarity information of all the emails by country, and plot a histogram (ordered and colored by polarity level)
# that summarizes the perception of the different countries. Repeat the aggregation + plotting steps using different demo
# methods from the sentiment analysis module -- can you find substantial differences?

# %% [markdown]
# ### Mentioned countries
# 1. convert to lower case and tokenize all the body text.
# 2. intersect body text with country names in lowercase.
# 3. intersect body text with country abbreviations in lowercase.
# 4. union all the mentioned countries and make it unique
#
# Difficulties:
#
# 1. Some of abbreviations `alpha_2` and `alpha_3` has other meanings.
#    1. 'PM' refers to 'saint pierre and miquelon'
#    2. Norway alpha_2='NO'
#    and so on
#
#    It is reasonable to believe, people will not refer to misleading abbreviations in their emails. In fact, after checking the coutries found by `alpha_2`, `alpha_3`, we found only very very few countries will be refer in abbreviation and most of the times it is `U.S.`. So we only add some special cases rather than checkout all of them.
#
# 2. Some countries are usually refered in a way which different from `name/alpha_2/alpha_3`.
#
#     For example, Syria is not listed because its name is `Syrian Arab Republic`, and Russia is `Russian federal`.
#     The same case happen to some other place.
#
#     We will add special cases to it.
#
# 3. include special case  EU, U.N., Benghazi

# %%
# Map Country names
country_abbreviations_alpha_2 = [i.alpha_2 for i in pycountry.countries]
country_abbreviations_alpha_3 = [i.alpha_3 for i in pycountry.countries]
country_abbreviations_name    = [i.name for i in pycountry.countries]

def get_common_name_map():
    common_name_map = dict()
    common_name_map['syrian'] = 'Syrian Arab Republic'
    common_name_map['syria']  = 'Syrian Arab Republic'
    common_name_map['russia'] = 'Russian Federation'
    common_name_map['u.s.']   = 'United States'
    
    common_name_map['u.n.']     = 'UN'
    common_name_map['benghazi'] = 'Libya'
    common_name_map['eu']       = 'EU'

    for name in country_abbreviations_name:
        common_name_map[name.lower()] = name
        
    return common_name_map

common_name_map = get_common_name_map()

# %%
def tokenize_text(txt):
    return nltk.word_tokenize(txt)

def find_countries_in_text(tokenized_txt, country_list = common_name_map.keys()):
    lower_tokenized_text = set([i.lower() for i in tokenized_txt])
    return lower_tokenized_text.intersection(country_list)

# %%
tokenized_body_text = nltk.word_tokenize(all_body_text)
lower_tokenized_text = set([i.lower() for i in tokenized_body_text])

# %%
countries_found = find_countries_in_text(lower_tokenized_text, common_name_map.keys())
[common_name_map[c] for c in countries_found]
# Out:
# ['Turkey',
#  'Belarus',
#  'Ethiopia',
#  'Greece',
#  'Australia',
#  'Hungary',
#  'Libya',
#  'Qatar',
#  'Russian Federation',
#  'Israel',
#  'Zambia',
#  'Brazil',
#  'Italy',
#  'EU',
#  'Cambodia',
#  'Jamaica',
#  'Portugal',
#  'Haiti',
#  'Nauru',
#  'Colombia',
#  'Bermuda',
#  'Mongolia',
#  'Bahrain',
#  'Tunisia',
#  'Nepal',
#  'Guinea-Bissau',
#  'Iceland',
#  'Argentina',
#  'Albania',
#  'Slovakia',
#  'Cameroon',
#  'Sweden',
#  'Malawi',
#  'Chile',
#  'Serbia',
#  'Netherlands',
#  'Antarctica',
#  'Pakistan',
#  'Maldives',
#  'Germany',
#  'Spain',
#  'Ireland',
#  'Gabon',
#  'Kyrgyzstan',
#  'Guinea',
#  'Singapore',
#  'Belgium',
#  'Rwanda',
#  'Lithuania',
#  'Uruguay',
#  'Morocco',
#  'Kuwait',
#  'Malta',
#  'Liberia',
#  'Bangladesh',
#  'Guatemala',
#  'Romania',
#  'Cyprus',
#  'Zimbabwe',
#  'Afghanistan',
#  'Nigeria',
#  'Malaysia',
#  'Cuba',
#  'Canada',
#  'Mexico',
#  'Honduras',
#  'Greenland',
#  'Lesotho',
#  'Indonesia',
#  'Estonia',
#  'Madagascar',
#  'Suriname',
#  'Tajikistan',
#  'Japan',
#  'Libya',
#  'Yemen',
#  'Peru',
#  'United States',
#  'Slovenia',
#  'Azerbaijan',
#  'Kazakhstan',
#  'Egypt',
#  'Luxembourg',
#  'Austria',
#  'Algeria',
#  'Ukraine',
#  'Syrian Arab Republic',
#  'UN',
#  'Samoa',
#  'Ecuador',
#  'Finland',
#  'Georgia',
#  'Switzerland',
#  'Angola',
#  'Guyana',
#  'Palau',
#  'Myanmar',
#  'Bahamas',
#  'Ghana',
#  'Oman',
#  'Guam',
#  'Niger',
#  'Philippines',
#  'Jersey',
#  'Turkmenistan',
#  'Latvia',
#  'Kenya',
#  'China',
#  'France',
#  'Denmark',
#  'Chad',
#  'Senegal',
#  'Armenia',
#  'Nicaragua',
#  'Poland',
#  'Jordan',
#  'Norway',
#  'Uzbekistan',
#  'Mozambique',
#  'Panama',
#  'Syrian Arab Republic',
#  'Somalia',
#  'Monaco',
#  'Congo',
#  'Uganda',
#  'Iraq',
#  'Sudan',
#  'Thailand',
#  'India',
#  'Lebanon']

# %% [markdown]
# ### Sentiment analysis
#
# `nltk.sentiment.util.demo_vader_instance` is used to analyse the polarity and sentiment of each

# %%
from nltk.sentiment import util
from nltk.sentiment import SentimentIntensityAnalyzer
vader_analyzer = SentimentIntensityAnalyzer()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %%
extrected_body_text_series = df.loc[:, 'ExtractedBodyText'].dropna()

# %%
def map_email_bodies_to_countries(email_bodies):
    """
    Parameters
    ----------
    email_bodies : pandas.Series
    
    Return
    ------
    country_to_emails : dict
        map lowercase country names to a list of indices of emails which mentions this country.
    
    """
    assert(email_bodies.dropna().shape == email_bodies.shape)
    country_to_emails = dict(zip(set(common_name_map.values()), [[ ] for i in range(len(common_name_map.values()))]))
    emails_to_country = dict(zip(set(email_bodies.index), [[ ] for i in range(len(email_bodies.index))]))

    for idx in email_bodies.index:
        email = tokenize_text(email_bodies.loc[idx])
        countries = find_countries_in_text(email)
        for c in countries:
            country_to_emails[common_name_map[c]].append(idx)
            emails_to_country[idx].append(common_name_map[c])
            
    return country_to_emails, emails_to_country

# %%
map_coutry_to_emails, map_emails_to_country = map_email_bodies_to_countries(extrected_body_text_series)

# %%
map_coutry_to_num_emails = dict()
for c in map_coutry_to_emails.keys():
    map_coutry_to_num_emails[c] = len(map_coutry_to_emails[c])

# %%
country_num_emails_df = pd.DataFrame(list(map_coutry_to_num_emails.items()), columns=['country', 'num'])
country_num_emails_df.set_index('country', inplace=True)
country_num_emails_df.head()
# Out:
#                     num
# country
# Viet Nam              0
# Jamaica               4
# Serbia                1
# Norway               12
# Korea, Republic of    0

# %%
country_num_emails_df.sort_values('num', ascending=False).head(20).plot(kind='bar')
plt.title("Top 20 countries mentioned in Hillary's email")
plt.show()

# %%
def map_email_to_vader_sentiment(emails):
    polarity_score = dict()
    for idx in emails.index:
        txt = emails.loc[idx]
        polarity_score[idx] = vader_analyzer.polarity_scores(txt)
    
    return polarity_score

# %% [markdown]
# Apply vader_analysis to emails. The results will be a dictionary `map_idx_to_sentiment`
#
# It may take some time to do the computatoin.

# %%
import pickle
import os

if os.path.exists("map_idx_to_sentiment.pickle"):
    with open('map_idx_to_sentiment.pickle', 'rb') as handle:
        map_idx_to_sentiment = pickle.load(handle)
else:
    map_idx_to_sentiment = dict()
    map_idx_to_sentiment['vader'] = map_email_to_vader_sentiment(extrected_body_text_series)
    with open('map_idx_to_sentiment.pickle', 'wb') as handle:
        pickle.dump(map_idx_to_sentiment, handle)

# %%
def extract_senti(idx, senti):
    return [idx, senti['compound'], senti['neg'], senti['pos'], senti['neu']]

# %%
# a = np.array([extract_senti(idx, senti) for idx, senti in map_idx_to_sentiment['vader'].items()])

# %%
map_idx_to_sentiment['vader']
# Out:
# {2: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  3: {'compound': 0.3612, 'neg': 0.0, 'neu': 0.0, 'pos': 1.0},
#  5: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  6: {'compound': -0.8402, 'neg': 0.14, 'neu': 0.821, 'pos': 0.039},
#  8: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  9: {'compound': 0.2023, 'neg': 0.0, 'neu': 0.0, 'pos': 1.0},
#  10: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  11: {'compound': 0.2023, 'neg': 0.0, 'neu': 0.357, 'pos': 0.643},
#  12: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  13: {'compound': 0.2023, 'neg': 0.0, 'neu': 0.0, 'pos': 1.0},
#  14: {'compound': 0.9881, 'neg': 0.089, 'neu': 0.8, 'pos': 0.111},
#  15: {'compound': 0.9259, 'neg': 0.026, 'neu': 0.786, 'pos': 0.188},
#  16: {'compound': 0.8869, 'neg': 0.069, 'neu': 0.795, 'pos': 0.137},
#  17: {'compound': 0.4404, 'neg': 0.0, 'neu': 0.633, 'pos': 0.367},
#  18: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  19: {'compound': 0.4215, 'neg': 0.0, 'neu': 0.417, 'pos': 0.583},
#  20: {'compound': -0.2103, 'neg': 0.139, 'neu': 0.748, 'pos': 0.114},
#  21: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  22: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  23: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  24: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  25: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  26: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  27: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  28: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  29: {'compound': -0.996, 'neg': 0.152, 'neu': 0.739, 'pos': 0.109},
#  30: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  31: {'compound': 0.2023, 'neg': 0.0, 'neu': 0.0, 'pos': 1.0},
#  32: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  33: {'compound': -0.9936, 'neg': 0.122, 'neu': 0.814, 'pos': 0.063},
#  34: {'compound': 0.368, 'neg': 0.0, 'neu': 0.917, 'pos': 0.083},
#  35: {'compound': 0.2023, 'neg': 0.0, 'neu': 0.0, 'pos': 1.0},
#  37: {'compound': 0.7865, 'neg': 0.061, 'neu': 0.87, 'pos': 0.068},
#  39: {'compound': 0.7096, 'neg': 0.129, 'neu': 0.34, 'pos': 0.531},
#  40: {'compound': -0.34, 'neg': 0.192, 'neu': 0.706, 'pos': 0.103},
#  41: {'compound': 0.2023, 'neg': 0.0, 'neu': 0.357, 'pos': 0.643},
#  42: {'compound': 0.8588, 'neg': 0.0, 'neu': 0.32, 'pos': 0.68},
#  43: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  44: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  45: {'compound': 0.2023, 'neg': 0.0, 'neu': 0.0, 'pos': 1.0},
#  46: {'compound': -0.1779, 'neg': 0.121, 'neu': 0.805, 'pos': 0.074},
#  47: {'compound': -0.9958, 'neg': 0.125, 'neu': 0.794, 'pos': 0.081},
#  48: {'compound': 0.3612, 'neg': 0.0, 'neu': 0.783, 'pos': 0.217},
#  49: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  50: {'compound': 0.7879, 'neg': 0.0, 'neu': 0.683, 'pos': 0.317},
#  51: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  52: {'compound': -0.1346, 'neg': 0.188, 'neu': 0.657, 'pos': 0.156},
#  53: {'compound': -0.434, 'neg': 0.082, 'neu': 0.853, 'pos': 0.065},
#  54: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  55: {'compound': 0.6486, 'neg': 0.114, 'neu': 0.735, 'pos': 0.151},
#  56: {'compound': -0.434, 'neg': 0.067, 'neu': 0.88, 'pos': 0.053},
#  58: {'compound': 0.9967, 'neg': 0.133, 'neu': 0.678, 'pos': 0.189},
#  59: {'compound': 0.694, 'neg': 0.0, 'neu': 0.83, 'pos': 0.17},
#  61: {'compound': -0.9593, 'neg': 0.154, 'neu': 0.783, 'pos': 0.063},
#  62: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  65: {'compound': 0.2432, 'neg': 0.086, 'neu': 0.834, 'pos': 0.08},
#  66: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  67: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  68: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  69: {'compound': 0.2023, 'neg': 0.0, 'neu': 0.0, 'pos': 1.0},
#  70: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  71: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  72: {'compound': -0.0772, 'neg': 0.025, 'neu': 0.945, 'pos': 0.03},
#  73: {'compound': -0.198, 'neg': 0.117, 'neu': 0.776, 'pos': 0.107},
#  74: {'compound': 0.4939, 'neg': 0.0, 'neu': 0.323, 'pos': 0.677},
#  75: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  76: {'compound': 0.9502, 'neg': 0.029, 'neu': 0.859, 'pos': 0.112},
#  77: {'compound': 0.3612, 'neg': 0.0, 'neu': 0.884, 'pos': 0.116},
#  78: {'compound': 0.4588, 'neg': 0.077, 'neu': 0.772, 'pos': 0.151},
#  79: {'compound': 0.4404, 'neg': 0.0, 'neu': 0.408, 'pos': 0.592},
#  80: {'compound': 0.0, 'neg': 0.0, 'neu': 0.0, 'pos': 0.0},
#  81: {'compound': -0.25, 'neg': 0.113, 'neu': 0.845, 'pos': 0.042},
#  82: {'compound': 0.4939, 'neg': 0.093, 'neu': 0.797, 'pos': 0.111},
#  83: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  86: {'compound': 0.1027, 'neg': 0.092, 'neu': 0.805, 'pos': 0.103},
#  87: {'compound': -0.9965, 'neg': 0.214, 'neu': 0.657, 'pos': 0.129},
#  88: {'compound': -0.3939, 'neg': 0.116, 'neu': 0.802, 'pos': 0.082},
#  89: {'compound': -0.1511, 'neg': 0.15, 'neu': 0.85, 'pos': 0.0},
#  90: {'compound': 0.6767, 'neg': 0.0, 'neu': 0.834, 'pos': 0.166},
#  91: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  92: {'compound': 0.1901, 'neg': 0.0, 'neu': 0.837, 'pos': 0.163},
#  93: {'compound': 0.4696, 'neg': 0.0, 'neu': 0.809, 'pos': 0.191},
#  94: {'compound': 0.4019, 'neg': 0.0, 'neu': 0.856, 'pos': 0.144},
#  97: {'compound': 0.4939, 'neg': 0.0, 'neu': 0.874, 'pos': 0.126},
#  98: {'compound': 0.9808, 'neg': 0.016, 'neu': 0.811, 'pos': 0.172},
#  99: {'compound': 0.34, 'neg': 0.0, 'neu': 0.893, 'pos': 0.107},
#  100: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  101: {'compound': -0.34, 'neg': 0.187, 'neu': 0.713, 'pos': 0.1},
#  102: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  103: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  104: {'compound': 0.5719, 'neg': 0.0, 'neu': 0.561, 'pos': 0.439},
#  105: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  106: {'compound': 0.296, 'neg': 0.0, 'neu': 0.833, 'pos': 0.167},
#  107: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  108: {'compound': -0.9488, 'neg': 0.103, 'neu': 0.863, 'pos': 0.035},
#  109: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  110: {'compound': -0.3612, 'neg': 0.28, 'neu': 0.72, 'pos': 0.0},
#  111: {'compound': -0.4767, 'neg': 0.279, 'neu': 0.721, 'pos': 0.0},
#  112: {'compound': 0.296, 'neg': 0.0, 'neu': 0.312, 'pos': 0.688},
#  113: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  114: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  115: {'compound': 0.0772, 'neg': 0.0, 'neu': 0.933, 'pos': 0.067},
#  116: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  118: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  119: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  120: {'compound': 0.2023, 'neg': 0.0, 'neu': 0.0, 'pos': 1.0},
#  121: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  122: {'compound': 0.4215, 'neg': 0.0, 'neu': 0.941, 'pos': 0.059},
#  123: {'compound': 0.8988, 'neg': 0.133, 'neu': 0.636, 'pos': 0.231},
#  124: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  125: {'compound': -0.3336, 'neg': 0.106, 'neu': 0.823, 'pos': 0.071},
#  127: {'compound': 0.5322, 'neg': 0.103, 'neu': 0.789, 'pos': 0.108},
#  128: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  129: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  130: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  131: {'compound': -0.5859, 'neg': 0.135, 'neu': 0.792, 'pos': 0.072},
#  132: {'compound': 0.4754, 'neg': 0.0, 'neu': 0.564, 'pos': 0.436},
#  133: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  134: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  135: {'compound': 0.4404, 'neg': 0.0, 'neu': 0.0, 'pos': 1.0},
#  136: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  137: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  139: {'compound': 0.4019, 'neg': 0.0, 'neu': 0.0, 'pos': 1.0},
#  140: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  141: {'compound': -0.8316, 'neg': 0.157, 'neu': 0.785, 'pos': 0.057},
#  142: {'compound': -0.9382, 'neg': 0.325, 'neu': 0.675, 'pos': 0.0},
#  143: {'compound': 0.4215, 'neg': 0.0, 'neu': 0.891, 'pos': 0.109},
#  144: {'compound': -0.5574, 'neg': 0.114, 'neu': 0.848, 'pos': 0.038},
#  145: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  147: {'compound': 0.5902, 'neg': 0.117, 'neu': 0.761, 'pos': 0.121},
#  148: {'compound': -0.0516, 'neg': 0.068, 'neu': 0.851, 'pos': 0.082},
#  149: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  152: {'compound': 0.0124, 'neg': 0.131, 'neu': 0.734, 'pos': 0.135},
#  153: {'compound': 0.9923, 'neg': 0.054, 'neu': 0.792, 'pos': 0.154},
#  154: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  155: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  157: {'compound': 0.2023, 'neg': 0.0, 'neu': 0.357, 'pos': 0.643},
#  158: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  159: {'compound': 0.6369, 'neg': 0.0, 'neu': 0.792, 'pos': 0.208},
#  160: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  161: {'compound': -0.5574, 'neg': 0.114, 'neu': 0.848, 'pos': 0.038},
#  162: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  163: {'compound': -0.8567, 'neg': 0.058, 'neu': 0.915, 'pos': 0.027},
#  164: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  165: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  168: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  169: {'compound': -0.34, 'neg': 0.158, 'neu': 0.756, 'pos': 0.085},
#  170: {'compound': 0.9184, 'neg': 0.048, 'neu': 0.863, 'pos': 0.089},
#  172: {'compound': -0.5574, 'neg': 0.143, 'neu': 0.797, 'pos': 0.059},
#  174: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  175: {'compound': -0.9996, 'neg': 0.18, 'neu': 0.746, 'pos': 0.074},
#  176: {'compound': -0.9978, 'neg': 0.22, 'neu': 0.653, 'pos': 0.127},
#  177: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  178: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  179: {'compound': 0.2023, 'neg': 0.0, 'neu': 0.769, 'pos': 0.231},
#  180: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  182: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  183: {'compound': 0.9612, 'neg': 0.068, 'neu': 0.801, 'pos': 0.131},
#  184: {'compound': 0.0772, 'neg': 0.0, 'neu': 0.435, 'pos': 0.565},
#  185: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  186: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  187: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  188: {'compound': 0.5319, 'neg': 0.0, 'neu': 0.838, 'pos': 0.162},
#  190: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  191: {'compound': 0.6908, 'neg': 0.0, 'neu': 0.84, 'pos': 0.16},
#  192: {'compound': 0.2023, 'neg': 0.0, 'neu': 0.0, 'pos': 1.0},
#  193: {'compound': 0.0772, 'neg': 0.0, 'neu': 0.606, 'pos': 0.394},
#  194: {'compound': -0.3818, 'neg': 0.115, 'neu': 0.885, 'pos': 0.0},
#  195: {'compound': 0.4404, 'neg': 0.0, 'neu': 0.791, 'pos': 0.209},
#  196: {'compound': 0.4404, 'neg': 0.0, 'neu': 0.805, 'pos': 0.195},
#  197: {'compound': 0.3818, 'neg': 0.0, 'neu': 0.885, 'pos': 0.115},
#  198: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  199: {'compound': -0.2732, 'neg': 0.189, 'neu': 0.709, 'pos': 0.102},
#  201: {'compound': 0.6476, 'neg': 0.088, 'neu': 0.678, 'pos': 0.234},
#  202: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  203: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  205: {'compound': 0.6114, 'neg': 0.0, 'neu': 0.667, 'pos': 0.333},
#  206: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  207: {'compound': -0.9894, 'neg': 0.126, 'neu': 0.772, 'pos': 0.101},
#  208: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  210: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  211: {'compound': 0.2023, 'neg': 0.0, 'neu': 0.0, 'pos': 1.0},
#  212: {'compound': 0.2502, 'neg': 0.079, 'neu': 0.836, 'pos': 0.085},
#  213: {'compound': 0.694, 'neg': 0.0, 'neu': 0.677, 'pos': 0.323},
#  214: {'compound': -0.9961, 'neg': 0.192, 'neu': 0.729, 'pos': 0.078},
#  215: {'compound': 1.0, 'neg': 0.109, 'neu': 0.7, 'pos': 0.191},
#  216: {'compound': 0.0772, 'neg': 0.0, 'neu': 0.435, 'pos': 0.565},
#  217: {'compound': -0.2716, 'neg': 0.054, 'neu': 0.901, 'pos': 0.045},
#  218: {'compound': 0.2023, 'neg': 0.0, 'neu': 0.0, 'pos': 1.0},
#  220: {'compound': -0.34, 'neg': 0.178, 'neu': 0.727, 'pos': 0.095},
#  221: {'compound': -0.7096, 'neg': 0.313, 'neu': 0.599, 'pos': 0.088},
#  222: {'compound': 0.6249, 'neg': 0.0, 'neu': 0.196, 'pos': 0.804},
#  223: {'compound': -0.5904, 'neg': 0.19, 'neu': 0.737, 'pos': 0.074},
#  224: {'compound': -0.34, 'neg': 0.104, 'neu': 0.84, 'pos': 0.056},
#  225: {'compound': -0.34, 'neg': 0.178, 'neu': 0.727, 'pos': 0.095},
#  226: {'compound': 0.5719, 'neg': 0.0, 'neu': 0.847, 'pos': 0.153},
#  227: {'compound': 0.4404, 'neg': 0.0, 'neu': 0.408, 'pos': 0.592},
#  228: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  229: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  230: {'compound': -0.4404, 'neg': 0.081, 'neu': 0.919, 'pos': 0.0},
#  231: {'compound': 0.6808, 'neg': 0.056, 'neu': 0.882, 'pos': 0.062},
#  232: {'compound': 0.2023, 'neg': 0.0, 'neu': 0.0, 'pos': 1.0},
#  233: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  234: {'compound': 0.0772, 'neg': 0.0, 'neu': 0.435, 'pos': 0.565},
#  235: {'compound': 0.7964, 'neg': 0.051, 'neu': 0.886, 'pos': 0.063},
#  236: {'compound': 0.5904, 'neg': 0.036, 'neu': 0.918, 'pos': 0.046},
#  237: {'compound': -0.34, 'neg': 0.169, 'neu': 0.74, 'pos': 0.091},
#  238: {'compound': 0.368, 'neg': 0.0, 'neu': 0.283, 'pos': 0.717},
#  240: {'compound': -0.9891, 'neg': 0.098, 'neu': 0.847, 'pos': 0.055},
#  241: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  242: {'compound': 0.1027, 'neg': 0.0, 'neu': 0.588, 'pos': 0.412},
#  244: {'compound': -0.9986, 'neg': 0.166, 'neu': 0.754, 'pos': 0.08},
#  245: {'compound': 0.9651, 'neg': 0.095, 'neu': 0.654, 'pos': 0.25},
#  246: {'compound': 0.6801, 'neg': 0.0, 'neu': 0.715, 'pos': 0.285},
#  247: {'compound': 0.9565, 'neg': 0.0, 'neu': 0.461, 'pos': 0.539},
#  248: {'compound': 0.4753, 'neg': 0.0, 'neu': 0.786, 'pos': 0.214},
#  249: {'compound': 0.8986, 'neg': 0.0, 'neu': 0.588, 'pos': 0.412},
#  250: {'compound': -0.3156, 'neg': 0.08, 'neu': 0.858, 'pos': 0.062},
#  251: {'compound': 0.3612, 'neg': 0.0, 'neu': 0.872, 'pos': 0.128},
#  252: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  253: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  254: {'compound': 0.2023, 'neg': 0.0, 'neu': 0.0, 'pos': 1.0},
#  255: {'compound': 0.2023, 'neg': 0.0, 'neu': 0.0, 'pos': 1.0},
#  256: {'compound': 0.4404, 'neg': 0.0, 'neu': 0.884, 'pos': 0.116},
#  257: {'compound': 0.775, 'neg': 0.0, 'neu': 0.846, 'pos': 0.154},
#  258: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  259: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  260: {'compound': -0.5106, 'neg': 0.078, 'neu': 0.9, 'pos': 0.022},
#  262: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  263: {'compound': 0.0772, 'neg': 0.0, 'neu': 0.606, 'pos': 0.394},
#  264: {'compound': -0.296, 'neg': 0.068, 'neu': 0.932, 'pos': 0.0},
#  265: {'compound': -0.2382, 'neg': 0.14, 'neu': 0.7, 'pos': 0.16},
#  266: {'compound': 0.2023, 'neg': 0.0, 'neu': 0.0, 'pos': 1.0},
#  267: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  268: {'compound': 0.9882, 'neg': 0.053, 'neu': 0.848, 'pos': 0.099},
#  269: {'compound': 0.368, 'neg': 0.0, 'neu': 0.283, 'pos': 0.717},
#  270: {'compound': 0.981, 'neg': 0.092, 'neu': 0.801, 'pos': 0.107},
#  271: {'compound': 0.368, 'neg': 0.0, 'neu': 0.837, 'pos': 0.163},
#  272: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  273: {'compound': -0.928, 'neg': 0.092, 'neu': 0.83, 'pos': 0.078},
#  274: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  275: {'compound': 0.2023, 'neg': 0.0, 'neu': 0.0, 'pos': 1.0},
#  276: {'compound': -0.34, 'neg': 0.173, 'neu': 0.733, 'pos': 0.093},
#  277: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  278: {'compound': 0.4576, 'neg': 0.0, 'neu': 0.25, 'pos': 0.75},
#  279: {'compound': 0.0772, 'neg': 0.338, 'neu': 0.282, 'pos': 0.38},
#  280: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  281: {'compound': 0.0772, 'neg': 0.0, 'neu': 0.435, 'pos': 0.565},
#  282: {'compound': 0.7351, 'neg': 0.0, 'neu': 0.563, 'pos': 0.437},
#  283: {'compound': -0.34, 'neg': 0.103, 'neu': 0.842, 'pos': 0.055},
#  284: {'compound': 0.34, 'neg': 0.08, 'neu': 0.764, 'pos': 0.156},
#  285: {'compound': -0.743, 'neg': 0.196, 'neu': 0.735, 'pos': 0.069},
#  286: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  287: {'compound': 0.296, 'neg': 0.0, 'neu': 0.0, 'pos': 1.0},
#  288: {'compound': 0.1613, 'neg': 0.081, 'neu': 0.805, 'pos': 0.114},
#  290: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  291: {'compound': -0.34, 'neg': 0.192, 'neu': 0.706, 'pos': 0.103},
#  292: {'compound': -0.8318, 'neg': 0.234, 'neu': 0.666, 'pos': 0.1},
#  293: {'compound': 0.1091, 'neg': 0.125, 'neu': 0.744, 'pos': 0.131},
#  294: {'compound': 0.34, 'neg': 0.0, 'neu': 0.854, 'pos': 0.146},
#  295: {'compound': -0.4757, 'neg': 0.163, 'neu': 0.723, 'pos': 0.114},
#  296: {'compound': 0.5719, 'neg': 0.118, 'neu': 0.747, 'pos': 0.135},
#  297: {'compound': 0.3612, 'neg': 0.0, 'neu': 0.615, 'pos': 0.385},
#  298: {'compound': 0.4404, 'neg': 0.0, 'neu': 0.256, 'pos': 0.744},
#  300: {'compound': 0.0772, 'neg': 0.0, 'neu': 0.86, 'pos': 0.14},
#  301: {'compound': 0.3612, 'neg': 0.0, 'neu': 0.762, 'pos': 0.238},
#  302: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  303: {'compound': 0.3612, 'neg': 0.0, 'neu': 0.545, 'pos': 0.455},
#  304: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  305: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  306: {'compound': 0.3612, 'neg': 0.0, 'neu': 0.872, 'pos': 0.128},
#  307: {'compound': 0.0772, 'neg': 0.0, 'neu': 0.843, 'pos': 0.157},
#  308: {'compound': 0.296, 'neg': 0.0, 'neu': 0.476, 'pos': 0.524},
#  309: {'compound': 0.4184, 'neg': 0.0, 'neu': 0.59, 'pos': 0.41},
#  310: {'compound': 0.4199, 'neg': 0.0, 'neu': 0.682, 'pos': 0.318},
#  311: {'compound': 0.3612, 'neg': 0.0, 'neu': 0.93, 'pos': 0.07},
#  312: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  313: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  315: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  316: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  317: {'compound': 0.4215, 'neg': 0.0, 'neu': 0.853, 'pos': 0.147},
#  318: {'compound': 0.8126, 'neg': 0.0, 'neu': 0.704, 'pos': 0.296},
#  319: {'compound': 0.3818, 'neg': 0.0, 'neu': 0.66, 'pos': 0.34},
#  320: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  321: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  323: {'compound': 0.4019, 'neg': 0.0, 'neu': 0.27, 'pos': 0.73},
#  324: {'compound': 0.4902, 'neg': 0.0, 'neu': 0.825, 'pos': 0.175},
#  325: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  326: {'compound': 0.6588, 'neg': 0.0, 'neu': 0.185, 'pos': 0.815},
#  327: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  328: {'compound': 0.4215, 'neg': 0.0, 'neu': 0.84, 'pos': 0.16},
#  329: {'compound': 0.3612, 'neg': 0.0, 'neu': 0.912, 'pos': 0.088},
#  330: {'compound': 0.8248, 'neg': 0.031, 'neu': 0.739, 'pos': 0.23},
#  331: {'compound': 0.5267, 'neg': 0.0, 'neu': 0.812, 'pos': 0.188},
#  332: {'compound': -0.9118, 'neg': 0.281, 'neu': 0.579, 'pos': 0.139},
#  333: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  334: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  335: {'compound': 0.4137, 'neg': 0.0, 'neu': 0.799, 'pos': 0.201},
#  336: {'compound': 0.296, 'neg': 0.0, 'neu': 0.896, 'pos': 0.104},
#  337: {'compound': -0.4767, 'neg': 0.608, 'neu': 0.392, 'pos': 0.0},
#  338: {'compound': 0.1779, 'neg': 0.081, 'neu': 0.828, 'pos': 0.091},
#  340: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  341: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  342: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  343: {'compound': 0.296, 'neg': 0.0, 'neu': 0.0, 'pos': 1.0},
#  344: {'compound': 0.7184, 'neg': 0.0, 'neu': 0.72, 'pos': 0.28},
#  345: {'compound': 0.8555, 'neg': 0.051, 'neu': 0.827, 'pos': 0.122},
#  347: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  348: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  349: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  350: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  351: {'compound': 0.6705, 'neg': 0.0, 'neu': 0.649, 'pos': 0.351},
#  352: {'compound': -0.296, 'neg': 0.18, 'neu': 0.82, 'pos': 0.0},
#  353: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  354: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  355: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  356: {'compound': -0.0516, 'neg': 0.13, 'neu': 0.87, 'pos': 0.0},
#  357: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  358: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  359: {'compound': 0.296, 'neg': 0.0, 'neu': 0.0, 'pos': 1.0},
#  360: {'compound': -0.0772, 'neg': 0.218, 'neu': 0.495, 'pos': 0.287},
#  361: {'compound': 0.4329, 'neg': 0.0, 'neu': 0.71, 'pos': 0.29},
#  366: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  367: {'compound': 0.0772, 'neg': 0.0, 'neu': 0.435, 'pos': 0.565},
#  369: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  370: {'compound': -0.128, 'neg': 0.147, 'neu': 0.733, 'pos': 0.12},
#  371: {'compound': 0.3612, 'neg': 0.0, 'neu': 0.8, 'pos': 0.2},
#  372: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  373: {'compound': 0.5023, 'neg': 0.0, 'neu': 0.885, 'pos': 0.115},
#  374: {'compound': 0.4215, 'neg': 0.0, 'neu': 0.441, 'pos': 0.559},
#  375: {'compound': 0.3612, 'neg': 0.0, 'neu': 0.615, 'pos': 0.385},
#  376: {'compound': 0.0772, 'neg': 0.0, 'neu': 0.86, 'pos': 0.14},
#  377: {'compound': 0.1027, 'neg': 0.105, 'neu': 0.726, 'pos': 0.169},
#  378: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  379: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  380: {'compound': 0.0444, 'neg': 0.067, 'neu': 0.837, 'pos': 0.096},
#  381: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  382: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  383: {'compound': 0.3736, 'neg': 0.0, 'neu': 0.835, 'pos': 0.165},
#  384: {'compound': -0.0772, 'neg': 0.085, 'neu': 0.915, 'pos': 0.0},
#  385: {'compound': -0.3818, 'neg': 0.286, 'neu': 0.714, 'pos': 0.0},
#  386: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  387: {'compound': 0.296, 'neg': 0.0, 'neu': 0.577, 'pos': 0.423},
#  388: {'compound': 0.2263, 'neg': 0.0, 'neu': 0.345, 'pos': 0.655},
#  389: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  390: {'compound': 0.0772, 'neg': 0.0, 'neu': 0.794, 'pos': 0.206},
#  391: {'compound': 0.0772, 'neg': 0.0, 'neu': 0.915, 'pos': 0.085},
#  392: {'compound': -0.2263, 'neg': 0.079, 'neu': 0.921, 'pos': 0.0},
#  393: {'compound': 0.4817, 'neg': 0.04, 'neu': 0.818, 'pos': 0.142},
#  394: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  395: {'compound': 0.3595, 'neg': 0.0, 'neu': 0.0, 'pos': 1.0},
#  396: {'compound': 0.0772, 'neg': 0.0, 'neu': 0.435, 'pos': 0.565},
#  398: {'compound': 0.3182, 'neg': 0.0, 'neu': 0.635, 'pos': 0.365},
#  399: {'compound': 0.4404, 'neg': 0.0, 'neu': 0.256, 'pos': 0.744},
#  400: {'compound': 0.0772, 'neg': 0.0, 'neu': 0.966, 'pos': 0.034},
#  401: {'compound': 0.9481, 'neg': 0.019, 'neu': 0.767, 'pos': 0.215},
#  402: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  403: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  404: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  405: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  406: {'compound': 0.3612, 'neg': 0.0, 'neu': 0.815, 'pos': 0.185},
#  407: {'compound': 0.6486, 'neg': 0.0, 'neu': 0.785, 'pos': 0.215},
#  408: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  409: {'compound': -0.5423, 'neg': 0.467, 'neu': 0.533, 'pos': 0.0},
#  410: {'compound': 0.6753, 'neg': 0.055, 'neu': 0.808, 'pos': 0.138},
#  411: {'compound': 0.807, 'neg': 0.0, 'neu': 0.772, 'pos': 0.228},
#  412: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  413: {'compound': 0.296, 'neg': 0.0, 'neu': 0.0, 'pos': 1.0},
#  414: {'compound': -0.395, 'neg': 0.25, 'neu': 0.75, 'pos': 0.0},
#  415: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  416: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  417: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  418: {'compound': 0.872, 'neg': 0.0, 'neu': 0.669, 'pos': 0.331},
#  419: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  420: {'compound': 0.4939, 'neg': 0.0, 'neu': 0.775, 'pos': 0.225},
#  421: {'compound': 0.8957, 'neg': 0.0, 'neu': 0.812, 'pos': 0.188},
#  422: {'compound': -0.0531, 'neg': 0.129, 'neu': 0.752, 'pos': 0.118},
#  423: {'compound': 0.0772, 'neg': 0.0, 'neu': 0.755, 'pos': 0.245},
#  426: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  427: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  428: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  429: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  430: {'compound': 0.0772, 'neg': 0.0, 'neu': 0.435, 'pos': 0.565},
#  432: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  433: {'compound': 0.0772, 'neg': 0.0, 'neu': 0.822, 'pos': 0.178},
#  434: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  435: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  437: {'compound': 0.3612, 'neg': 0.0, 'neu': 0.865, 'pos': 0.135},
#  438: {'compound': 0.6597, 'neg': 0.0, 'neu': 0.69, 'pos': 0.31},
#  439: {'compound': 0.4926, 'neg': 0.0, 'neu': 0.0, 'pos': 1.0},
#  440: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  441: {'compound': 0.1531, 'neg': 0.0, 'neu': 0.945, 'pos': 0.055},
#  442: {'compound': 0.9316, 'neg': 0.014, 'neu': 0.781, 'pos': 0.205},
#  443: {'compound': 0.5023, 'neg': 0.0, 'neu': 0.927, 'pos': 0.073},
#  444: {'compound': 0.3612, 'neg': 0.0, 'neu': 0.857, 'pos': 0.143},
#  445: {'compound': 0.0772, 'neg': 0.0, 'neu': 0.929, 'pos': 0.071},
#  446: {'compound': 0.6705, 'neg': 0.0, 'neu': 0.806, 'pos': 0.194},
#  447: {'compound': 0.0258, 'neg': 0.0, 'neu': 0.939, 'pos': 0.061},
#  448: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  449: {'compound': 0.4144, 'neg': 0.0, 'neu': 0.86, 'pos': 0.14},
#  450: {'compound': 0.5574, 'neg': 0.0, 'neu': 0.765, 'pos': 0.235},
#  451: {'compound': -0.296, 'neg': 0.091, 'neu': 0.909, 'pos': 0.0},
#  452: {'compound': 0.4019, 'neg': 0.0, 'neu': 0.821, 'pos': 0.179},
#  453: {'compound': 0.5994, 'neg': 0.0, 'neu': 0.741, 'pos': 0.259},
#  454: {'compound': 0.296, 'neg': 0.0, 'neu': 0.0, 'pos': 1.0},
#  455: {'compound': 0.1901, 'neg': 0.0, 'neu': 0.863, 'pos': 0.137},
#  456: {'compound': 0.0772, 'neg': 0.0, 'neu': 0.894, 'pos': 0.106},
#  457: {'compound': 0.3182, 'neg': 0.0, 'neu': 0.685, 'pos': 0.315},
#  458: {'compound': 0.5859, 'neg': 0.0, 'neu': 0.51, 'pos': 0.49},
#  459: {'compound': 0.0382, 'neg': 0.0, 'neu': 0.859, 'pos': 0.141},
#  460: {'compound': 0.7635, 'neg': 0.035, 'neu': 0.771, 'pos': 0.194},
#  461: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  462: {'compound': 0.9426, 'neg': 0.0, 'neu': 0.705, 'pos': 0.295},
#  463: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  464: {'compound': 0.4404, 'neg': 0.0, 'neu': 0.805, 'pos': 0.195},
#  465: {'compound': 0.3736, 'neg': 0.0, 'neu': 0.854, 'pos': 0.146},
#  466: {'compound': 0.3818, 'neg': 0.0, 'neu': 0.66, 'pos': 0.34},
#  467: {'compound': 0.6486, 'neg': 0.063, 'neu': 0.749, 'pos': 0.187},
#  468: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  469: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  470: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  471: {'compound': 0.0772, 'neg': 0.0, 'neu': 0.963, 'pos': 0.037},
#  472: {'compound': 0.3818, 'neg': 0.0, 'neu': 0.357, 'pos': 0.643},
#  473: {'compound': 0.2023, 'neg': 0.0, 'neu': 0.0, 'pos': 1.0},
#  474: {'compound': 0.4588, 'neg': 0.099, 'neu': 0.66, 'pos': 0.241},
#  475: {'compound': 0.9215, 'neg': 0.0, 'neu': 0.695, 'pos': 0.305},
#  476: {'compound': 0.3612, 'neg': 0.0, 'neu': 0.828, 'pos': 0.172},
#  477: {'compound': 0.296, 'neg': 0.0, 'neu': 0.0, 'pos': 1.0},
#  478: {'compound': 0.0772, 'neg': 0.0, 'neu': 0.843, 'pos': 0.157},
#  479: {'compound': 0.0772, 'neg': 0.0, 'neu': 0.909, 'pos': 0.091},
#  481: {'compound': 0.3612, 'neg': 0.0, 'neu': 0.783, 'pos': 0.217},
#  482: {'compound': 0.5106, 'neg': 0.0, 'neu': 0.769, 'pos': 0.231},
#  483: {'compound': -0.4098, 'neg': 0.089, 'neu': 0.911, 'pos': 0.0},
#  484: {'compound': 0.4019, 'neg': 0.0, 'neu': 0.803, 'pos': 0.197},
#  486: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  487: {'compound': 0.4019, 'neg': 0.0, 'neu': 0.0, 'pos': 1.0},
#  488: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  489: {'compound': 0.6908, 'neg': 0.0, 'neu': 0.551, 'pos': 0.449},
#  490: {'compound': 0.6705, 'neg': 0.0, 'neu': 0.912, 'pos': 0.088},
#  491: {'compound': 0.0772, 'neg': 0.217, 'neu': 0.543, 'pos': 0.24},
#  492: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  493: {'compound': 0.6249, 'neg': 0.0, 'neu': 0.805, 'pos': 0.195},
#  494: {'compound': 0.296, 'neg': 0.0, 'neu': 0.0, 'pos': 1.0},
#  495: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  496: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  497: {'compound': 0.5423, 'neg': 0.0, 'neu': 0.791, 'pos': 0.209},
#  498: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  499: {'compound': 0.0772, 'neg': 0.0, 'neu': 0.843, 'pos': 0.157},
#  500: {'compound': 0.6124, 'neg': 0.0, 'neu': 0.914, 'pos': 0.086},
#  501: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  502: {'compound': -0.264, 'neg': 0.103, 'neu': 0.813, 'pos': 0.083},
#  503: {'compound': 0.296, 'neg': 0.0, 'neu': 0.0, 'pos': 1.0},
#  504: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  505: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  507: {'compound': 0.0258, 'neg': 0.0, 'neu': 0.901, 'pos': 0.099},
#  508: {'compound': 0.8632, 'neg': 0.0, 'neu': 0.794, 'pos': 0.206},
#  509: {'compound': 0.4404, 'neg': 0.0, 'neu': 0.674, 'pos': 0.326},
#  510: {'compound': 0.3182, 'neg': 0.0, 'neu': 0.813, 'pos': 0.187},
#  511: {'compound': 0.964, 'neg': 0.019, 'neu': 0.739, 'pos': 0.242},
#  512: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  513: {'compound': 0.0772, 'neg': 0.0, 'neu': 0.915, 'pos': 0.085},
#  514: {'compound': 0.5487, 'neg': 0.0, 'neu': 0.819, 'pos': 0.181},
#  515: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  516: {'compound': 0.2023, 'neg': 0.0, 'neu': 0.625, 'pos': 0.375},
#  517: {'compound': 0.3786, 'neg': 0.063, 'neu': 0.79, 'pos': 0.147},
#  518: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  519: {'compound': 0.296, 'neg': 0.0, 'neu': 0.784, 'pos': 0.216},
#  520: {'compound': 0.3818, 'neg': 0.0, 'neu': 0.795, 'pos': 0.205},
#  521: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  522: {'compound': 0.3612, 'neg': 0.0, 'neu': 0.615, 'pos': 0.385},
#  523: {'compound': 0.2023, 'neg': 0.0, 'neu': 0.526, 'pos': 0.474},
#  524: {'compound': 0.296, 'neg': 0.0, 'neu': 0.0, 'pos': 1.0},
#  526: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  528: {'compound': 0.3612, 'neg': 0.0, 'neu': 0.0, 'pos': 1.0},
#  529: {'compound': 0.953, 'neg': 0.026, 'neu': 0.657, 'pos': 0.317},
#  530: {'compound': 0.9551, 'neg': 0.029, 'neu': 0.555, 'pos': 0.417},
#  531: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  532: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  533: {'compound': 0.7845, 'neg': 0.0, 'neu': 0.655, 'pos': 0.345},
#  534: {'compound': 0.296, 'neg': 0.0, 'neu': 0.0, 'pos': 1.0},
#  535: {'compound': 0.2263, 'neg': 0.073, 'neu': 0.792, 'pos': 0.135},
#  536: {'compound': 0.296, 'neg': 0.0, 'neu': 0.0, 'pos': 1.0},
#  537: {'compound': -0.431, 'neg': 0.252, 'neu': 0.65, 'pos': 0.098},
#  538: {'compound': 0.5106, 'neg': 0.0, 'neu': 0.583, 'pos': 0.417},
#  539: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  540: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  541: {'compound': 0.3612, 'neg': 0.0, 'neu': 0.444, 'pos': 0.556},
#  542: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  543: {'compound': 0.296, 'neg': 0.0, 'neu': 0.732, 'pos': 0.268},
#  544: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  545: {'compound': 0.3612, 'neg': 0.0, 'neu': 0.878, 'pos': 0.122},
#  547: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  548: {'compound': 0.6767, 'neg': 0.0, 'neu': 0.568, 'pos': 0.432},
#  549: {'compound': 0.4019, 'neg': 0.0, 'neu': 0.922, 'pos': 0.078},
#  550: {'compound': 0.296, 'neg': 0.0, 'neu': 0.872, 'pos': 0.128},
#  551: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  552: {'compound': -0.7755, 'neg': 0.097, 'neu': 0.903, 'pos': 0.0},
#  554: {'compound': 0.3612, 'neg': 0.0, 'neu': 0.0, 'pos': 1.0},
#  555: {'compound': -0.1474, 'neg': 0.044, 'neu': 0.956, 'pos': 0.0},
#  556: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  557: {'compound': 0.296, 'neg': 0.0, 'neu': 0.476, 'pos': 0.524},
#  558: {'compound': 0.3612, 'neg': 0.0, 'neu': 0.898, 'pos': 0.102},
#  559: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  562: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  563: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  564: {'compound': 0.2023, 'neg': 0.0, 'neu': 0.847, 'pos': 0.153},
#  565: {'compound': 0.0772, 'neg': 0.0, 'neu': 0.933, 'pos': 0.067},
#  566: {'compound': 0.8126, 'neg': 0.0, 'neu': 0.724, 'pos': 0.276},
#  567: {'compound': 0.5574, 'neg': 0.0, 'neu': 0.739, 'pos': 0.261},
#  568: {'compound': 0.6786, 'neg': 0.0, 'neu': 0.785, 'pos': 0.215},
#  569: {'compound': 0.0772, 'neg': 0.0, 'neu': 0.698, 'pos': 0.302},
#  570: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  571: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  572: {'compound': 0.7845, 'neg': 0.0, 'neu': 0.786, 'pos': 0.214},
#  573: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  574: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  575: {'compound': 0.296, 'neg': 0.0, 'neu': 0.0, 'pos': 1.0},
#  576: {'compound': 0.0772, 'neg': 0.0, 'neu': 0.86, 'pos': 0.14},
#  578: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  579: {'compound': 0.3612, 'neg': 0.055, 'neu': 0.802, 'pos': 0.143},
#  580: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  581: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  582: {'compound': -0.4019, 'neg': 0.231, 'neu': 0.769, 'pos': 0.0},
#  583: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  584: {'compound': 0.4144, 'neg': 0.0, 'neu': 0.685, 'pos': 0.315},
#  585: {'compound': -0.2244, 'neg': 0.131, 'neu': 0.772, 'pos': 0.097},
#  586: {'compound': 0.6124, 'neg': 0.0, 'neu': 0.783, 'pos': 0.217},
#  587: {'compound': 0.6369, 'neg': 0.0, 'neu': 0.366, 'pos': 0.634},
#  588: {'compound': -0.3313, 'neg': 0.129, 'neu': 0.871, 'pos': 0.0},
#  589: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  590: {'compound': 0.8957, 'neg': 0.0, 'neu': 0.68, 'pos': 0.32},
#  591: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  592: {'compound': 0.6705, 'neg': 0.0, 'neu': 0.864, 'pos': 0.136},
#  593: {'compound': 0.7227, 'neg': 0.0, 'neu': 0.856, 'pos': 0.144},
#  594: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  595: {'compound': 0.3612, 'neg': 0.0, 'neu': 0.839, 'pos': 0.161},
#  596: {'compound': 0.296, 'neg': 0.0, 'neu': 0.872, 'pos': 0.128},
#  597: {'compound': 0.296, 'neg': 0.0, 'neu': 0.694, 'pos': 0.306},
#  598: {'compound': 0.296, 'neg': 0.0, 'neu': 0.0, 'pos': 1.0},
#  599: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  600: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  601: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  602: {'compound': 0.3736, 'neg': 0.0, 'neu': 0.796, 'pos': 0.204},
#  603: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  604: {'compound': 0.2023, 'neg': 0.0, 'neu': 0.0, 'pos': 1.0},
#  605: {'compound': 0.5719, 'neg': 0.0, 'neu': 0.0, 'pos': 1.0},
#  606: {'compound': 0.0772, 'neg': 0.0, 'neu': 0.902, 'pos': 0.098},
#  607: {'compound': 0.3612, 'neg': 0.0, 'neu': 0.0, 'pos': 1.0},
#  608: {'compound': -0.782, 'neg': 0.094, 'neu': 0.879, 'pos': 0.027},
#  609: {'compound': 0.34, 'neg': 0.0, 'neu': 0.833, 'pos': 0.167},
#  610: {'compound': 0.3612, 'neg': 0.0, 'neu': 0.902, 'pos': 0.098},
#  611: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  612: {'compound': 0.6981, 'neg': 0.0, 'neu': 0.634, 'pos': 0.366},
#  613: {'compound': 0.6369, 'neg': 0.0, 'neu': 0.743, 'pos': 0.257},
#  614: {'compound': 0.6369, 'neg': 0.0, 'neu': 0.698, 'pos': 0.302},
#  615: {'compound': 0.6369, 'neg': 0.0, 'neu': 0.536, 'pos': 0.464},
#  616: {'compound': 0.8555, 'neg': 0.0, 'neu': 0.644, 'pos': 0.356},
#  617: {'compound': 0.6369, 'neg': 0.0, 'neu': 0.435, 'pos': 0.565},
#  618: {'compound': 0.3612, 'neg': 0.0, 'neu': 0.828, 'pos': 0.172},
#  619: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  620: {'compound': -0.1511, 'neg': 0.285, 'neu': 0.715, 'pos': 0.0},
#  621: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  622: {'compound': 0.5106, 'neg': 0.0, 'neu': 0.836, 'pos': 0.164},
#  623: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  624: {'compound': 0.8516, 'neg': 0.096, 'neu': 0.478, 'pos': 0.426},
#  625: {'compound': 0.9337, 'neg': 0.0, 'neu': 0.614, 'pos': 0.386},
#  626: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  627: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  628: {'compound': 0.296, 'neg': 0.0, 'neu': 0.732, 'pos': 0.268},
#  629: {'compound': 0.1779, 'neg': 0.361, 'neu': 0.164, 'pos': 0.475},
#  630: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  631: {'compound': -0.1511, 'neg': 0.285, 'neu': 0.715, 'pos': 0.0},
#  632: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  633: {'compound': 0.296, 'neg': 0.114, 'neu': 0.598, 'pos': 0.288},
#  635: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  636: {'compound': 0.9337, 'neg': 0.0, 'neu': 0.614, 'pos': 0.386},
#  637: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  638: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  639: {'compound': 0.296, 'neg': 0.0, 'neu': 0.732, 'pos': 0.268},
#  640: {'compound': 0.1779, 'neg': 0.361, 'neu': 0.164, 'pos': 0.475},
#  641: {'compound': -0.296, 'neg': 0.239, 'neu': 0.761, 'pos': 0.0},
#  642: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  643: {'compound': 0.296, 'neg': 0.0, 'neu': 0.0, 'pos': 1.0},
#  644: {'compound': 0.296, 'neg': 0.0, 'neu': 0.0, 'pos': 1.0},
#  645: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  646: {'compound': 0.296, 'neg': 0.0, 'neu': 0.0, 'pos': 1.0},
#  647: {'compound': 0.3182, 'neg': 0.0, 'neu': 0.913, 'pos': 0.087},
#  648: {'compound': -0.2263, 'neg': 0.147, 'neu': 0.853, 'pos': 0.0},
#  649: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  650: {'compound': 0.3612, 'neg': 0.0, 'neu': 0.865, 'pos': 0.135},
#  651: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  652: {'compound': 0.296, 'neg': 0.0, 'neu': 0.905, 'pos': 0.095},
#  654: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  655: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  656: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  664: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  665: {'compound': -0.3182, 'neg': 0.099, 'neu': 0.901, 'pos': 0.0},
#  666: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  667: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  668: {'compound': 0.2824, 'neg': 0.0, 'neu': 0.957, 'pos': 0.043},
#  669: {'compound': 0.4019, 'neg': 0.084, 'neu': 0.759, 'pos': 0.156},
#  670: {'compound': 0.6775, 'neg': 0.077, 'neu': 0.715, 'pos': 0.208},
#  672: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  673: {'compound': 0.3612, 'neg': 0.0, 'neu': 0.737, 'pos': 0.263},
#  674: {'compound': 0.4404, 'neg': 0.0, 'neu': 0.847, 'pos': 0.153},
#  675: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  676: {'compound': 0.5023, 'neg': 0.0, 'neu': 0.881, 'pos': 0.119},
#  677: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  678: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  679: {'compound': 0.1531, 'neg': 0.093, 'neu': 0.784, 'pos': 0.123},
#  680: {'compound': 0.296, 'neg': 0.0, 'neu': 0.936, 'pos': 0.064},
#  681: {'compound': 0.0772, 'neg': 0.0, 'neu': 0.435, 'pos': 0.565},
#  682: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  683: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  684: {'compound': 0.0772, 'neg': 0.0, 'neu': 0.92, 'pos': 0.08},
#  685: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  686: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  687: {'compound': 0.5719, 'neg': 0.0, 'neu': 0.46, 'pos': 0.54},
#  688: {'compound': 0.7845, 'neg': 0.0, 'neu': 0.432, 'pos': 0.568},
#  689: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  690: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  692: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  693: {'compound': 0.5661, 'neg': 0.0, 'neu': 0.863, 'pos': 0.137},
#  694: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  695: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  696: {'compound': 0.2732, 'neg': 0.065, 'neu': 0.83, 'pos': 0.105},
#  697: {'compound': -0.6486, 'neg': 0.207, 'neu': 0.689, 'pos': 0.105},
#  698: {'compound': 0.6249, 'neg': 0.0, 'neu': 0.549, 'pos': 0.451},
#  699: {'compound': 0.5423, 'neg': 0.0, 'neu': 0.883, 'pos': 0.117},
#  700: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  701: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  702: {'compound': 0.4199, 'neg': 0.0, 'neu': 0.518, 'pos': 0.482},
#  703: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  704: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  705: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  706: {'compound': 0.296, 'neg': 0.0, 'neu': 0.645, 'pos': 0.355},
#  707: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  708: {'compound': 0.2382, 'neg': 0.0, 'neu': 0.822, 'pos': 0.178},
#  709: {'compound': 0.4019, 'neg': 0.0, 'neu': 0.649, 'pos': 0.351},
#  710: {'compound': 0.2732, 'neg': 0.0, 'neu': 0.92, 'pos': 0.08},
#  711: {'compound': 0.4019, 'neg': 0.0, 'neu': 0.0, 'pos': 1.0},
#  712: {'compound': 0.4019, 'neg': 0.0, 'neu': 0.0, 'pos': 1.0},
#  713: {'compound': 0.7096, 'neg': 0.0, 'neu': 0.831, 'pos': 0.169},
#  714: {'compound': 0.8834, 'neg': 0.071, 'neu': 0.744, 'pos': 0.185},
#  715: {'compound': 0.4939, 'neg': 0.0, 'neu': 0.656, 'pos': 0.344},
#  716: {'compound': 0.3071, 'neg': 0.029, 'neu': 0.928, 'pos': 0.043},
#  717: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  718: {'compound': 0.296, 'neg': 0.0, 'neu': 0.939, 'pos': 0.061},
#  719: {'compound': 0.0772, 'neg': 0.0, 'neu': 0.794, 'pos': 0.206},
#  720: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  721: {'compound': 0.3612, 'neg': 0.0, 'neu': 0.828, 'pos': 0.172},
#  722: {'compound': 0.6369, 'neg': 0.0, 'neu': 0.729, 'pos': 0.271},
#  723: {'compound': 0.2732, 'neg': 0.0, 'neu': 0.905, 'pos': 0.095},
#  724: {'compound': 0.4404, 'neg': 0.0, 'neu': 0.791, 'pos': 0.209},
#  725: {'compound': -0.4767, 'neg': 0.171, 'neu': 0.829, 'pos': 0.0},
#  726: {'compound': 0.3612, 'neg': 0.0, 'neu': 0.0, 'pos': 1.0},
#  727: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  728: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  729: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  730: {'compound': 0.0772, 'neg': 0.0, 'neu': 0.698, 'pos': 0.302},
#  731: {'compound': 0.3818, 'neg': 0.0, 'neu': 0.526, 'pos': 0.474},
#  732: {'compound': 0.632, 'neg': 0.0, 'neu': 0.419, 'pos': 0.581},
#  733: {'compound': 0.1531, 'neg': 0.0, 'neu': 0.867, 'pos': 0.133},
#  734: {'compound': 0.3612, 'neg': 0.0, 'neu': 0.286, 'pos': 0.714},
#  735: {'compound': 0.6808, 'neg': 0.0, 'neu': 0.772, 'pos': 0.228},
#  736: {'compound': 0.0772, 'neg': 0.0, 'neu': 0.92, 'pos': 0.08},
#  737: {'compound': 0.5209, 'neg': 0.0, 'neu': 0.673, 'pos': 0.327},
#  738: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  739: {'compound': 0.0772, 'neg': 0.0, 'neu': 0.435, 'pos': 0.565},
#  740: {'compound': 0.0772, 'neg': 0.0, 'neu': 0.435, 'pos': 0.565},
#  741: {'compound': 0.0772, 'neg': 0.0, 'neu': 0.435, 'pos': 0.565},
#  742: {'compound': 0.296, 'neg': 0.0, 'neu': 0.645, 'pos': 0.355},
#  743: {'compound': 0.5719, 'neg': 0.0, 'neu': 0.0, 'pos': 1.0},
#  744: {'compound': 0.8313, 'neg': 0.0, 'neu': 0.585, 'pos': 0.415},
#  745: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  746: {'compound': 0.7351, 'neg': 0.0, 'neu': 0.41, 'pos': 0.59},
#  748: {'compound': -0.0516, 'neg': 0.107, 'neu': 0.893, 'pos': 0.0},
#  749: {'compound': -0.128, 'neg': 0.181, 'neu': 0.671, 'pos': 0.148},
#  750: {'compound': 0.5883, 'neg': 0.0, 'neu': 0.745, 'pos': 0.255},
#  751: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  752: {'compound': 0.7506, 'neg': 0.0, 'neu': 0.73, 'pos': 0.27},
#  753: {'compound': 0.3612, 'neg': 0.0, 'neu': 0.884, 'pos': 0.116},
#  754: {'compound': 0.168, 'neg': 0.0, 'neu': 0.9, 'pos': 0.1},
#  755: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  756: {'compound': 0.6124, 'neg': 0.0, 'neu': 0.5, 'pos': 0.5},
#  757: {'compound': 0.4019, 'neg': 0.0, 'neu': 0.0, 'pos': 1.0},
#  758: {'compound': -0.467, 'neg': 0.076, 'neu': 0.924, 'pos': 0.0},
#  759: {'compound': 0.34, 'neg': 0.0, 'neu': 0.676, 'pos': 0.324},
#  760: {'compound': 0.3736, 'neg': 0.0, 'neu': 0.732, 'pos': 0.268},
#  761: {'compound': 0.3612, 'neg': 0.0, 'neu': 0.8, 'pos': 0.2},
#  762: {'compound': -0.4215, 'neg': 0.123, 'neu': 0.877, 'pos': 0.0},
#  763: {'compound': 0.296, 'neg': 0.0, 'neu': 0.0, 'pos': 1.0},
#  764: {'compound': 0.3612, 'neg': 0.0, 'neu': 0.783, 'pos': 0.217},
#  765: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  766: {'compound': 0.8491, 'neg': 0.056, 'neu': 0.866, 'pos': 0.079},
#  767: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  768: {'compound': 0.0772, 'neg': 0.0, 'neu': 0.885, 'pos': 0.115},
#  769: {'compound': 0.0772, 'neg': 0.0, 'neu': 0.794, 'pos': 0.206},
#  770: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  771: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  772: {'compound': 0.8198, 'neg': 0.058, 'neu': 0.695, 'pos': 0.247},
#  773: {'compound': 0.8481, 'neg': 0.0, 'neu': 0.649, 'pos': 0.351},
#  774: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  775: {'compound': 0.4404, 'neg': 0.0, 'neu': 0.256, 'pos': 0.744},
#  776: {'compound': 0.4144, 'neg': 0.0, 'neu': 0.685, 'pos': 0.315},
#  777: {'compound': 0.0772, 'neg': 0.0, 'neu': 0.843, 'pos': 0.157},
#  778: {'compound': 0.0772, 'neg': 0.0, 'neu': 0.755, 'pos': 0.245},
#  779: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  780: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  781: {'compound': 0.7088, 'neg': 0.0, 'neu': 0.576, 'pos': 0.424},
#  782: {'compound': 0.296, 'neg': 0.0, 'neu': 0.577, 'pos': 0.423},
#  783: {'compound': -0.0516, 'neg': 0.098, 'neu': 0.902, 'pos': 0.0},
#  784: {'compound': 0.6808, 'neg': 0.0, 'neu': 0.789, 'pos': 0.211},
#  785: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  786: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  787: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  788: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  789: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  790: {'compound': 0.4019, 'neg': 0.0, 'neu': 0.748, 'pos': 0.252},
#  791: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  792: {'compound': 0.296, 'neg': 0.0, 'neu': 0.0, 'pos': 1.0},
#  794: {'compound': 0.0772, 'neg': 0.0, 'neu': 0.947, 'pos': 0.053},
#  795: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  797: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  798: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  799: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  800: {'compound': 0.1154, 'neg': 0.0, 'neu': 0.941, 'pos': 0.059},
#  801: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  802: {'compound': 0.0772, 'neg': 0.0, 'neu': 0.952, 'pos': 0.048},
#  803: {'compound': 0.4404, 'neg': 0.0, 'neu': 0.828, 'pos': 0.172},
#  804: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  805: {'compound': 0.6808, 'neg': 0.06, 'neu': 0.684, 'pos': 0.256},
#  806: {'compound': 0.296, 'neg': 0.0, 'neu': 0.0, 'pos': 1.0},
#  807: {'compound': 0.8519, 'neg': 0.0, 'neu': 0.659, 'pos': 0.341},
#  808: {'compound': 0.4404, 'neg': 0.0, 'neu': 0.909, 'pos': 0.091},
# ...
#  831: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  832: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  833: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  834: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  835: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  836: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  837: {'compound': 0.7717, 'neg': 0.0, 'neu': 0.717, 'pos': 0.283},
#  838: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  839: {'compound': 0.0258, 'neg': 0.044, 'neu': 0.911, 'pos': 0.046},
#  840: {'compound': 0.3612, 'neg': 0.0, 'neu': 0.545, 'pos': 0.455},
#  841: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  842: {'compound': 0.4019, 'neg': 0.0, 'neu': 0.895, 'pos': 0.105},
#  843: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  844: {'compound': 0.7783, 'neg': 0.027, 'neu': 0.85, 'pos': 0.123},
#  845: {'compound': 0.533, 'neg': 0.0, 'neu': 0.853, 'pos': 0.147},
#  846: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  847: {'compound': 0.296, 'neg': 0.0, 'neu': 0.732, 'pos': 0.268},
#  848: {'compound': 0.4215, 'neg': 0.0, 'neu': 0.517, 'pos': 0.483},
#  849: {'compound': -0.2263, 'neg': 0.213, 'neu': 0.787, 'pos': 0.0},
#  850: {'compound': 0.3818, 'neg': 0.0, 'neu': 0.933, 'pos': 0.067},
#  851: {'compound': 0.2263, 'neg': 0.0, 'neu': 0.917, 'pos': 0.083},
#  852: {'compound': 0.296, 'neg': 0.0, 'neu': 0.0, 'pos': 1.0},
#  853: {'compound': 0.9134, 'neg': 0.047, 'neu': 0.799, 'pos': 0.154},
#  854: {'compound': 0.7783, 'neg': 0.0, 'neu': 0.842, 'pos': 0.158},
#  855: {'compound': 0.0772, 'neg': 0.0, 'neu': 0.698, 'pos': 0.302},
#  856: {'compound': 0.0772, 'neg': 0.0, 'neu': 0.435, 'pos': 0.565},
#  858: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  860: {'compound': 0.3612, 'neg': 0.0, 'neu': 0.878, 'pos': 0.122},
#  861: {'compound': 0.3612, 'neg': 0.0, 'neu': 0.872, 'pos': 0.128},
#  862: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  863: {'compound': 0.2732, 'neg': 0.0, 'neu': 0.909, 'pos': 0.091},
#  864: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  865: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  866: {'compound': 0.5859, 'neg': 0.0, 'neu': 0.821, 'pos': 0.179},
#  867: {'compound': 0.5661, 'neg': 0.0, 'neu': 0.894, 'pos': 0.106},
#  868: {'compound': 0.296, 'neg': 0.0, 'neu': 0.0, 'pos': 1.0},
#  869: {'compound': -0.0258, 'neg': 0.049, 'neu': 0.905, 'pos': 0.046},
#  870: {'compound': -0.0276, 'neg': 0.097, 'neu': 0.809, 'pos': 0.094},
#  871: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  872: {'compound': 0.3182, 'neg': 0.0, 'neu': 0.685, 'pos': 0.315},
#  873: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  874: {'compound': -0.296, 'neg': 0.423, 'neu': 0.577, 'pos': 0.0},
#  875: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  876: {'compound': 0.7759, 'neg': 0.0, 'neu': 0.748, 'pos': 0.252},
#  877: {'compound': 0.296, 'neg': 0.0, 'neu': 0.849, 'pos': 0.151},
#  878: {'compound': 0.5719, 'neg': 0.0, 'neu': 0.907, 'pos': 0.093},
#  879: {'compound': -0.3612, 'neg': 0.385, 'neu': 0.615, 'pos': 0.0},
#  880: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  881: {'compound': 0.0772, 'neg': 0.0, 'neu': 0.843, 'pos': 0.157},
#  882: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  883: {'compound': 0.0772, 'neg': 0.0, 'neu': 0.874, 'pos': 0.126},
#  884: {'compound': 0.3612, 'neg': 0.0, 'neu': 0.444, 'pos': 0.556},
#  885: {'compound': 0.8168, 'neg': 0.0, 'neu': 0.635, 'pos': 0.365},
#  886: {'compound': 0.1531, 'neg': 0.0, 'neu': 0.894, 'pos': 0.106},
#  888: {'compound': 0.3182, 'neg': 0.0, 'neu': 0.566, 'pos': 0.434},
#  889: {'compound': 0.4019, 'neg': 0.0, 'neu': 0.0, 'pos': 1.0},
#  890: {'compound': 0.5574, 'neg': 0.0, 'neu': 0.521, 'pos': 0.479},
#  891: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  892: {'compound': -0.0572, 'neg': 0.088, 'neu': 0.861, 'pos': 0.051},
#  893: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  894: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  895: {'compound': 0.4019, 'neg': 0.0, 'neu': 0.748, 'pos': 0.252},
#  896: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  897: {'compound': 0.6542, 'neg': 0.024, 'neu': 0.881, 'pos': 0.096},
#  898: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  899: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  900: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  901: {'compound': 0.296, 'neg': 0.0, 'neu': 0.0, 'pos': 1.0},
#  902: {'compound': 0.2389, 'neg': 0.0, 'neu': 0.911, 'pos': 0.089},
#  903: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  904: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  905: {'compound': 0.9023, 'neg': 0.055, 'neu': 0.655, 'pos': 0.29},
#  906: {'compound': 0.3612, 'neg': 0.0, 'neu': 0.828, 'pos': 0.172},
#  907: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  908: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  909: {'compound': 0.296, 'neg': 0.0, 'neu': 0.312, 'pos': 0.688},
#  910: {'compound': 0.6779, 'neg': 0.0, 'neu': 0.812, 'pos': 0.188},
#  911: {'compound': 0.6767, 'neg': 0.0, 'neu': 0.788, 'pos': 0.212},
#  912: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  913: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  914: {'compound': 0.7178, 'neg': 0.0, 'neu': 0.684, 'pos': 0.316},
#  915: {'compound': 0.5423, 'neg': 0.0, 'neu': 0.886, 'pos': 0.114},
#  916: {'compound': -0.1531, 'neg': 0.104, 'neu': 0.824, 'pos': 0.071},
#  917: {'compound': 0.6124, 'neg': 0.0, 'neu': 0.889, 'pos': 0.111},
#  922: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  923: {'compound': 0.8519, 'neg': 0.0, 'neu': 0.791, 'pos': 0.209},
#  924: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  925: {'compound': 0.9313, 'neg': 0.0, 'neu': 0.769, 'pos': 0.231},
#  926: {'compound': 0.9296, 'neg': 0.0, 'neu': 0.807, 'pos': 0.193},
#  927: {'compound': 0.0772, 'neg': 0.0, 'neu': 0.794, 'pos': 0.206},
#  928: {'compound': 0.5719, 'neg': 0.0, 'neu': 0.0, 'pos': 1.0},
#  929: {'compound': 0.4019, 'neg': 0.0, 'neu': 0.748, 'pos': 0.252},
#  930: {'compound': 0.8948, 'neg': 0.0, 'neu': 0.76, 'pos': 0.24},
#  931: {'compound': 0.3612, 'neg': 0.0, 'neu': 0.828, 'pos': 0.172},
#  932: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  933: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  934: {'compound': 0.644, 'neg': 0.0, 'neu': 0.854, 'pos': 0.146},
#  935: {'compound': 0.8042, 'neg': 0.0, 'neu': 0.859, 'pos': 0.141},
#  936: {'compound': 0.3612, 'neg': 0.0, 'neu': 0.839, 'pos': 0.161},
#  937: {'compound': -0.1779, 'neg': 0.328, 'neu': 0.299, 'pos': 0.373},
#  938: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  939: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  940: {'compound': 0.936, 'neg': 0.0, 'neu': 0.825, 'pos': 0.175},
#  941: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  942: {'compound': 0.3612, 'neg': 0.0, 'neu': 0.872, 'pos': 0.128},
#  943: {'compound': 0.9804, 'neg': 0.017, 'neu': 0.769, 'pos': 0.213},
#  944: {'compound': 0.2023, 'neg': 0.0, 'neu': 0.0, 'pos': 1.0},
#  945: {'compound': 0.3612, 'neg': 0.0, 'neu': 0.737, 'pos': 0.263},
#  946: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  947: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  948: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  949: {'compound': 0.4215, 'neg': 0.0, 'neu': 0.808, 'pos': 0.192},
#  950: {'compound': 0.5562, 'neg': 0.0, 'neu': 0.919, 'pos': 0.081},
#  952: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  953: {'compound': 0.765, 'neg': 0.0, 'neu': 0.548, 'pos': 0.452},
#  954: {'compound': 0.765, 'neg': 0.0, 'neu': 0.548, 'pos': 0.452},
#  955: {'compound': 0.5502, 'neg': 0.0, 'neu': 0.842, 'pos': 0.158},
#  956: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  957: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  958: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  959: {'compound': 0.9308, 'neg': 0.0, 'neu': 0.551, 'pos': 0.449},
#  960: {'compound': 0.5719, 'neg': 0.0, 'neu': 0.885, 'pos': 0.115},
#  961: {'compound': 0.9136, 'neg': 0.096, 'neu': 0.597, 'pos': 0.307},
#  962: {'compound': 0.9098, 'neg': 0.017, 'neu': 0.807, 'pos': 0.177},
#  963: {'compound': 0.7041, 'neg': 0.0, 'neu': 0.837, 'pos': 0.163},
#  964: {'compound': 0.368, 'neg': 0.0, 'neu': 0.892, 'pos': 0.108},
#  965: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  968: {'compound': 0.765, 'neg': 0.0, 'neu': 0.855, 'pos': 0.145},
#  969: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  970: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  971: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  972: {'compound': -0.541, 'neg': 0.084, 'neu': 0.916, 'pos': 0.0},
#  973: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  974: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  975: {'compound': 0.5719, 'neg': 0.0, 'neu': 0.575, 'pos': 0.425},
#  976: {'compound': 0.0772, 'neg': 0.0, 'neu': 0.435, 'pos': 0.565},
#  977: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  978: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  979: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  981: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  982: {'compound': 0.4404, 'neg': 0.0, 'neu': 0.828, 'pos': 0.172},
#  983: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  984: {'compound': 0.0772, 'neg': 0.0, 'neu': 0.92, 'pos': 0.08},
#  985: {'compound': 0.4173, 'neg': 0.0, 'neu': 0.798, 'pos': 0.202},
#  986: {'compound': 0.0772, 'neg': 0.0, 'neu': 0.794, 'pos': 0.206},
#  987: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  988: {'compound': 0.0772, 'neg': 0.0, 'neu': 0.435, 'pos': 0.565},
#  989: {'compound': 0.9098, 'neg': 0.017, 'neu': 0.807, 'pos': 0.177},
#  990: {'compound': 0.3612, 'neg': 0.0, 'neu': 0.222, 'pos': 0.778},
#  991: {'compound': 0.3182, 'neg': 0.156, 'neu': 0.519, 'pos': 0.325},
#  992: {'compound': 0.6124, 'neg': 0.0, 'neu': 0.643, 'pos': 0.357},
#  993: {'compound': 0.6597, 'neg': 0.0, 'neu': 0.856, 'pos': 0.144},
#  994: {'compound': 0.4404, 'neg': 0.0, 'neu': 0.256, 'pos': 0.744},
#  995: {'compound': 0.6588, 'neg': 0.0, 'neu': 0.406, 'pos': 0.594},
#  996: {'compound': 0.0772, 'neg': 0.0, 'neu': 0.698, 'pos': 0.302},
#  999: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  1000: {'compound': 0.7845, 'neg': 0.0, 'neu': 0.603, 'pos': 0.397},
#  1001: {'compound': 0.4939, 'neg': 0.0, 'neu': 0.781, 'pos': 0.219},
#  1002: {'compound': 0.4927, 'neg': 0.0, 'neu': 0.878, 'pos': 0.122},
#  1003: {'compound': -0.2263, 'neg': 0.118, 'neu': 0.817, 'pos': 0.065},
#  1004: {'compound': 0.0772, 'neg': 0.0, 'neu': 0.885, 'pos': 0.115},
#  1005: {'compound': 0.296, 'neg': 0.0, 'neu': 0.0, 'pos': 1.0},
#  1006: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  1007: {'compound': 0.5487, 'neg': 0.0, 'neu': 0.867, 'pos': 0.133},
#  1008: {'compound': 0.9263, 'neg': 0.0, 'neu': 0.571, 'pos': 0.429},
#  1009: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  1010: {'compound': 0.0772, 'neg': 0.0, 'neu': 0.435, 'pos': 0.565},
#  1011: {'compound': 0.1531, 'neg': 0.0, 'neu': 0.89, 'pos': 0.11},
#  1012: {'compound': 0.6334, 'neg': 0.0, 'neu': 0.725, 'pos': 0.275},
#  1013: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  1014: {'compound': 0.782, 'neg': 0.0, 'neu': 0.768, 'pos': 0.232},
#  1015: {'compound': 0.946, 'neg': 0.0, 'neu': 0.734, 'pos': 0.266},
#  1016: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  1017: {'compound': 0.7717, 'neg': 0.0, 'neu': 0.729, 'pos': 0.271},
#  1018: {'compound': -0.4019, 'neg': 0.144, 'neu': 0.856, 'pos': 0.0},
#  1019: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  1020: {'compound': -0.4215, 'neg': 0.078, 'neu': 0.922, 'pos': 0.0},
#  1021: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  1022: {'compound': -0.4767, 'neg': 0.205, 'neu': 0.795, 'pos': 0.0},
#  1023: {'compound': -0.4871, 'neg': 0.087, 'neu': 0.913, 'pos': 0.0},
#  1024: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  1025: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  1026: {'compound': 0.3612, 'neg': 0.0, 'neu': 0.545, 'pos': 0.455},
#  1027: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  1028: {'compound': 0.2023, 'neg': 0.0, 'neu': 0.904, 'pos': 0.096},
#  1029: {'compound': 0.6199, 'neg': 0.0, 'neu': 0.813, 'pos': 0.187},
#  1030: {'compound': 0.2732, 'neg': 0.0, 'neu': 0.93, 'pos': 0.07},
#  1031: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  1032: {'compound': 0.4019, 'neg': 0.0, 'neu': 0.597, 'pos': 0.403},
#  1033: {'compound': -0.9427, 'neg': 0.098, 'neu': 0.824, 'pos': 0.078},
#  1034: {'compound': 0.8143, 'neg': 0.0, 'neu': 0.681, 'pos': 0.319},
#  1035: {'compound': 0.4215, 'neg': 0.0, 'neu': 0.648, 'pos': 0.352},
#  1036: {'compound': 0.6369, 'neg': 0.0, 'neu': 0.0, 'pos': 1.0},
#  1037: {'compound': 0.8957, 'neg': 0.081, 'neu': 0.768, 'pos': 0.152},
#  1038: {'compound': 0.6542, 'neg': 0.0, 'neu': 0.853, 'pos': 0.147},
#  1039: {'compound': 0.0772, 'neg': 0.0, 'neu': 0.755, 'pos': 0.245},
#  1040: {'compound': 0.7707, 'neg': 0.0, 'neu': 0.811, 'pos': 0.189},
#  1041: {'compound': 0.8481, 'neg': 0.0, 'neu': 0.765, 'pos': 0.235},
#  1042: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  1043: {'compound': 0.3612, 'neg': 0.0, 'neu': 0.828, 'pos': 0.172},
#  1044: {'compound': 0.296, 'neg': 0.0, 'neu': 0.891, 'pos': 0.109},
#  1045: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  1046: {'compound': 0.3612, 'neg': 0.0, 'neu': 0.884, 'pos': 0.116},
#  1047: {'compound': 0.8008, 'neg': 0.0, 'neu': 0.834, 'pos': 0.166},
#  1048: {'compound': 0.9719, 'neg': 0.0, 'neu': 0.586, 'pos': 0.414},
#  1050: {'compound': 0.7991, 'neg': 0.0, 'neu': 0.632, 'pos': 0.368},
#  1051: {'compound': 0.7184, 'neg': 0.0, 'neu': 0.714, 'pos': 0.286},
#  1052: {'compound': 0.7003, 'neg': 0.0, 'neu': 0.688, 'pos': 0.312},
#  1054: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  1055: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  1056: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  1057: {'compound': 0.0772, 'neg': 0.0, 'neu': 0.968, 'pos': 0.032},
#  1058: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  1059: {'compound': 0.9468, 'neg': 0.016, 'neu': 0.785, 'pos': 0.2},
#  1060: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  1061: {'compound': 0.7096, 'neg': 0.0, 'neu': 0.859, 'pos': 0.141},
#  1062: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  1063: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  1064: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  1065: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  1066: {'compound': -0.1449, 'neg': 0.101, 'neu': 0.816, 'pos': 0.083},
#  1067: {'compound': -0.3612, 'neg': 0.385, 'neu': 0.615, 'pos': 0.0},
#  1068: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  1069: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  1070: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  1071: {'compound': -0.0516, 'neg': 0.057, 'neu': 0.943, 'pos': 0.0},
#  1072: {'compound': 0.5346, 'neg': 0.0, 'neu': 0.793, 'pos': 0.207},
#  1073: {'compound': 0.3612, 'neg': 0.0, 'neu': 0.0, 'pos': 1.0},
#  1074: {'compound': 0.5267, 'neg': 0.0, 'neu': 0.793, 'pos': 0.207},
#  1075: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  1076: {'compound': 0.4588, 'neg': 0.0, 'neu': 0.87, 'pos': 0.13},
#  1077: {'compound': -0.6983, 'neg': 0.069, 'neu': 0.917, 'pos': 0.014},
#  1078: {'compound': 0.3182, 'neg': 0.0, 'neu': 0.927, 'pos': 0.073},
#  1079: {'compound': 0.0772, 'neg': 0.0, 'neu': 0.952, 'pos': 0.048},
#  1080: {'compound': 0.7579, 'neg': 0.029, 'neu': 0.843, 'pos': 0.129},
#  1081: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  1082: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  1083: {'compound': 0.5106, 'neg': 0.0, 'neu': 0.68, 'pos': 0.32},
#  1084: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  1085: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  1086: {'compound': 0.6588, 'neg': 0.0, 'neu': 0.84, 'pos': 0.16},
#  1087: {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0},
#  1088: {'compound': 0.3612, 'neg': 0.0, 'neu': 0.815, 'pos': 0.185},
#  ...}

# %% [markdown]
# Gather data from dictionary and form a dataframe. The sentiment of each country is averaged and the counter of each.
#
# Countries mentioned less than 5 times are not considered.

# %%
compound = dict(zip(map_coutry_to_emails.keys(), np.zeros(len(map_coutry_to_emails.keys()))))
neg   = dict(zip(map_coutry_to_emails.keys(), np.zeros(len(map_coutry_to_emails.keys()))))
pos   = dict(zip(map_coutry_to_emails.keys(), np.zeros(len(map_coutry_to_emails.keys()))))
neu   = dict(zip(map_coutry_to_emails.keys(), np.zeros(len(map_coutry_to_emails.keys()))))
count = dict(zip(map_coutry_to_emails.keys(), np.zeros(len(map_coutry_to_emails.keys()))))

for idx, senti in map_idx_to_sentiment['vader'].items():
    for c in map_emails_to_country[idx]:
        compound[c] += senti['compound']
        neg[c] += senti['neg']
        pos[c] += senti['pos']
        neu[c] += senti['neu']
        count[c] += 1
        
for c, num in count.items():
    if num > 0:
        compound[c] = compound[c] / num
        neg[c] = neg[c] / num
        pos[c] = pos[c] / num
        neu[c] = neu[c] / num

# %%
a = []

for c, num in count.items():
    a.append((c, compound[c], neg[c],pos[c], neu[c], num))
    
country_x_senti = pd.DataFrame(a, columns=['country', 'compound', 'neg', 'pos', 'neu', 'num'])
country_x_senti.set_index('country', inplace=True)
country_x_senti.head()
# Out:
#                     compound       neg     pos       neu   num
# country
# Viet Nam            0.000000  0.000000  0.0000  0.000000   0.0
# Jamaica            -0.076800  0.010250  0.0545  0.935250   4.0
# Serbia              0.992300  0.054000  0.1540  0.792000   1.0
# Norway              0.346433  0.058833  0.1160  0.825083  12.0
# Korea, Republic of  0.000000  0.000000  0.0000  0.000000   0.0

# %%
top_countries = country_x_senti[country_x_senti.num > 5]
top_countries.head()
# Out:
#              compound       neg       pos       neu   num
# country
# Norway       0.346433  0.058833  0.116000  0.825083  12.0
# Canada       0.259433  0.064933  0.107467  0.827667  15.0
# Honduras     0.289185  0.042148  0.087741  0.870111  27.0
# Netherlands  0.030643  0.077429  0.081000  0.841714   7.0
# Brazil       0.414296  0.049400  0.096240  0.854360  25.0

# %% [markdown]
# ### Overall

# %%
country_x_senti[country_x_senti.num > 10][['compound', 'neu', "neg", "pos"]].plot.bar(stacked=True)

# %%
country_x_senti[country_x_senti.num > 10][["neg", "pos"]].plot.bar(stacked=True)

# %% [markdown]
# ### Most Negative Sentiment countries
#
# We sort the difference
#
#     neg - pos
#
# to find the most negative sentiment. In this way, we can reduce the bias.

# %%
((top_countries['neg'] - top_countries['pos'])).sort_values(ascending=False)[:20].plot(kind='bar')
plt.title('Most Negative')
plt.plot()
# Out:
# []

# %% [markdown]
# It is well-known that `Benghazi attack` (Libya, 2012) is her nightmare. There is no doubt that `Libya` would rank high in this list.
#
# It is very interesting to see that Hillary holds a much more negative view towards `Congo`. When we searched google with keyword `hillary` and `congo`, we find that she and her husband received a very high speaking fee from congo
#
# [http://www.forbes.com/sites/richardminiter/2016/04/17/why-did-congo-offer-clinton-650000-for-two-pics-and-a-speech/#436be0e33f11](http://www.forbes.com/sites/richardminiter/2016/04/17/why-did-congo-offer-clinton-650000-for-two-pics-and-a-speech/#436be0e33f11)
#
# and a news about Hillary met a rude question in Congo http://thelede.blogs.nytimes.com/2009/08/13/was-hillary-clintons-answer-in-congo-the-right-one/?_r=0

# %%
((top_countries['pos'] - top_countries['neg'])).sort_values(ascending=False)[:20].plot(kind='bar')
plt.title('Most Positive')
plt.plot()
# Out:
# []

# %% [markdown]
# ## Other Sentimental analysis methods

# %% [markdown]
# #### Liu and Hu Lexicon
#
# Modify Liu and Hu lexicon code in NLTK utility for speed reasons and collecting data.

# %%
def Liu_and_Hu(sentence):
    """ Liu and Hu sentiment analysis tool. Adapted from 
    http://www.nltk.org/_modules/nltk/sentiment/util.html#demo_liu_hu_lexicon"""
    from nltk.corpus import opinion_lexicon
    from nltk.tokenize import treebank

    tokenizer = treebank.TreebankWordTokenizer()
    pos_words = 0
    neg_words = 0
    tokenized_sent = pd.Series([word.lower() for word in tokenizer.tokenize(sentence)])
    value_count = tokenized_sent.value_counts()
    pos_words = np.sum([value_count[w] for w in np.intersect1d(tokenized_sent, opinion_lexicon.positive())])
    neg_words = np.sum([value_count[w] for w in np.intersect1d(tokenized_sent, opinion_lexicon.negative())])
    
    if pos_words > neg_words:
        return 'Positive'
    elif pos_words < neg_words:
        return 'Negative'
    elif pos_words == neg_words:
        return 'Neutral'

# %%
def map_email_to_liu_and_hu_sentiment(emails):
    polarity_score = dict()
    for idx in emails.index:
        print(idx, len(emails))
        txt = emails.loc[idx]
        polarity_score[idx] = Liu_and_Hu(txt)
    
    return polarity_score

# %% [markdown]
# #### Analysing emails using liu and hu sentiment

# %%
if os.path.exists("map_idx_to_liu_and_hu.pickle"):
    with open('map_idx_to_liu_and_hu.pickle', 'rb') as handle:
        liu_and_hu_score = pickle.load(handle)
else:
    liu_and_hu_score = map_email_to_liu_and_hu_sentiment(extrected_body_text_series)
    with open('map_idx_to_liu_and_hu.pickle', 'wb') as handle:
        pickle.dump(liu_and_hu_score, handle)
        
map_idx_to_sentiment['liu_and_hu'] = liu_and_hu_score

# %%
map_idx_to_sentiment['liu_and_hu']
# Out:
# {2: 'Neutral',
#  3: 'Neutral',
#  5: 'Neutral',
#  6: 'Negative',
#  8: 'Neutral',
#  9: 'Neutral',
#  10: 'Neutral',
#  11: 'Neutral',
#  12: 'Neutral',
#  13: 'Neutral',
#  14: 'Positive',
#  15: 'Positive',
#  16: 'Positive',
#  17: 'Neutral',
#  18: 'Neutral',
#  19: 'Positive',
#  20: 'Neutral',
#  21: 'Neutral',
#  22: 'Neutral',
#  23: 'Neutral',
#  24: 'Neutral',
#  25: 'Neutral',
#  26: 'Neutral',
#  27: 'Neutral',
#  28: 'Neutral',
#  29: 'Negative',
#  30: 'Neutral',
#  31: 'Neutral',
#  32: 'Neutral',
#  33: 'Negative',
#  34: 'Neutral',
#  35: 'Neutral',
#  37: 'Positive',
#  39: 'Positive',
#  40: 'Positive',
#  41: 'Neutral',
#  42: 'Positive',
#  43: 'Neutral',
#  44: 'Neutral',
#  45: 'Neutral',
#  46: 'Positive',
#  47: 'Negative',
#  48: 'Neutral',
#  49: 'Neutral',
#  50: 'Positive',
#  51: 'Neutral',
#  52: 'Positive',
#  53: 'Negative',
#  54: 'Neutral',
#  55: 'Positive',
#  56: 'Negative',
#  58: 'Positive',
#  59: 'Neutral',
#  61: 'Neutral',
#  62: 'Neutral',
#  65: 'Positive',
#  66: 'Neutral',
#  67: 'Neutral',
#  68: 'Neutral',
#  69: 'Neutral',
#  70: 'Neutral',
#  71: 'Neutral',
#  72: 'Positive',
#  73: 'Positive',
#  74: 'Positive',
#  75: 'Neutral',
#  76: 'Positive',
#  77: 'Positive',
#  78: 'Positive',
#  79: 'Neutral',
#  80: 'Neutral',
#  81: 'Neutral',
#  82: 'Positive',
#  83: 'Neutral',
#  86: 'Neutral',
#  87: 'Positive',
#  88: 'Positive',
#  89: 'Negative',
#  90: 'Positive',
#  91: 'Neutral',
#  92: 'Neutral',
#  93: 'Neutral',
#  94: 'Positive',
#  97: 'Positive',
#  98: 'Positive',
#  99: 'Neutral',
#  100: 'Neutral',
#  101: 'Positive',
#  102: 'Neutral',
#  103: 'Neutral',
#  104: 'Neutral',
#  105: 'Neutral',
#  106: 'Neutral',
#  107: 'Neutral',
#  108: 'Negative',
#  109: 'Neutral',
#  110: 'Negative',
#  111: 'Neutral',
#  112: 'Neutral',
#  113: 'Neutral',
#  114: 'Neutral',
#  115: 'Positive',
#  116: 'Positive',
#  118: 'Positive',
#  119: 'Neutral',
#  120: 'Neutral',
#  121: 'Neutral',
#  122: 'Negative',
#  123: 'Positive',
#  124: 'Neutral',
#  125: 'Negative',
#  127: 'Positive',
#  128: 'Neutral',
#  129: 'Neutral',
#  130: 'Neutral',
#  131: 'Positive',
#  132: 'Neutral',
#  133: 'Neutral',
#  134: 'Neutral',
#  135: 'Positive',
#  136: 'Neutral',
#  137: 'Neutral',
#  139: 'Positive',
#  140: 'Neutral',
#  141: 'Neutral',
#  142: 'Negative',
#  143: 'Neutral',
#  144: 'Negative',
#  145: 'Neutral',
#  147: 'Positive',
#  148: 'Positive',
#  149: 'Neutral',
#  152: 'Positive',
#  153: 'Positive',
#  154: 'Neutral',
#  155: 'Neutral',
#  157: 'Neutral',
#  158: 'Neutral',
#  159: 'Positive',
#  160: 'Neutral',
#  161: 'Negative',
#  162: 'Neutral',
#  163: 'Positive',
#  164: 'Neutral',
#  165: 'Neutral',
#  168: 'Neutral',
#  169: 'Positive',
#  170: 'Positive',
#  172: 'Positive',
#  174: 'Neutral',
#  175: 'Negative',
#  176: 'Positive',
#  177: 'Neutral',
#  178: 'Neutral',
#  179: 'Neutral',
#  180: 'Neutral',
#  182: 'Neutral',
#  183: 'Positive',
#  184: 'Neutral',
#  185: 'Neutral',
#  186: 'Neutral',
#  187: 'Neutral',
#  188: 'Positive',
#  190: 'Neutral',
#  191: 'Positive',
#  192: 'Neutral',
#  193: 'Neutral',
#  194: 'Negative',
#  195: 'Neutral',
#  196: 'Neutral',
#  197: 'Positive',
#  198: 'Neutral',
#  199: 'Neutral',
#  201: 'Neutral',
#  202: 'Negative',
#  203: 'Neutral',
#  205: 'Positive',
#  206: 'Neutral',
#  207: 'Negative',
#  208: 'Neutral',
#  210: 'Neutral',
#  211: 'Neutral',
#  212: 'Negative',
#  213: 'Neutral',
#  214: 'Negative',
#  215: 'Positive',
#  216: 'Neutral',
#  217: 'Neutral',
#  218: 'Neutral',
#  220: 'Positive',
#  221: 'Negative',
#  222: 'Positive',
#  223: 'Neutral',
#  224: 'Positive',
#  225: 'Positive',
#  226: 'Neutral',
#  227: 'Positive',
#  228: 'Neutral',
#  229: 'Neutral',
#  230: 'Negative',
#  231: 'Positive',
#  232: 'Neutral',
#  233: 'Neutral',
#  234: 'Neutral',
#  235: 'Positive',
#  236: 'Positive',
#  237: 'Positive',
#  238: 'Neutral',
#  240: 'Negative',
#  241: 'Neutral',
#  242: 'Neutral',
#  244: 'Negative',
#  245: 'Positive',
#  246: 'Positive',
#  247: 'Positive',
#  248: 'Neutral',
#  249: 'Positive',
#  250: 'Positive',
#  251: 'Positive',
#  252: 'Neutral',
#  253: 'Neutral',
#  254: 'Neutral',
#  255: 'Neutral',
#  256: 'Neutral',
#  257: 'Neutral',
#  258: 'Neutral',
#  259: 'Neutral',
#  260: 'Negative',
#  262: 'Neutral',
#  263: 'Neutral',
#  264: 'Negative',
#  265: 'Positive',
#  266: 'Neutral',
#  267: 'Neutral',
#  268: 'Positive',
#  269: 'Neutral',
#  270: 'Negative',
#  271: 'Neutral',
#  272: 'Neutral',
#  273: 'Negative',
#  274: 'Negative',
#  275: 'Neutral',
#  276: 'Positive',
#  277: 'Neutral',
#  278: 'Positive',
#  279: 'Negative',
#  280: 'Neutral',
#  281: 'Neutral',
#  282: 'Neutral',
#  283: 'Positive',
#  284: 'Positive',
#  285: 'Positive',
#  286: 'Neutral',
#  287: 'Neutral',
#  288: 'Neutral',
#  290: 'Neutral',
#  291: 'Positive',
#  292: 'Negative',
#  293: 'Positive',
#  294: 'Positive',
#  295: 'Neutral',
#  296: 'Positive',
#  297: 'Positive',
#  298: 'Positive',
#  300: 'Neutral',
#  301: 'Neutral',
#  302: 'Neutral',
#  303: 'Neutral',
#  304: 'Neutral',
#  305: 'Neutral',
#  306: 'Positive',
#  307: 'Neutral',
#  308: 'Neutral',
#  309: 'Neutral',
#  310: 'Positive',
#  311: 'Positive',
#  312: 'Neutral',
#  313: 'Neutral',
#  315: 'Negative',
#  316: 'Neutral',
#  317: 'Positive',
#  318: 'Positive',
#  319: 'Neutral',
#  320: 'Neutral',
#  321: 'Neutral',
#  323: 'Neutral',
#  324: 'Positive',
#  325: 'Neutral',
#  326: 'Positive',
#  327: 'Neutral',
#  328: 'Positive',
#  329: 'Positive',
#  330: 'Positive',
#  331: 'Positive',
#  332: 'Negative',
#  333: 'Neutral',
#  334: 'Neutral',
#  335: 'Positive',
#  336: 'Negative',
#  337: 'Negative',
#  338: 'Negative',
#  340: 'Neutral',
#  341: 'Neutral',
#  342: 'Neutral',
#  343: 'Neutral',
#  344: 'Neutral',
#  345: 'Positive',
#  347: 'Neutral',
#  348: 'Neutral',
#  349: 'Neutral',
#  350: 'Neutral',
#  351: 'Positive',
#  352: 'Positive',
#  353: 'Neutral',
#  354: 'Neutral',
#  355: 'Neutral',
#  356: 'Neutral',
#  357: 'Neutral',
#  358: 'Neutral',
#  359: 'Neutral',
#  360: 'Neutral',
#  361: 'Neutral',
#  366: 'Neutral',
#  367: 'Neutral',
#  369: 'Neutral',
#  370: 'Positive',
#  371: 'Neutral',
#  372: 'Neutral',
#  373: 'Neutral',
#  374: 'Neutral',
#  375: 'Neutral',
#  376: 'Neutral',
#  377: 'Positive',
#  378: 'Neutral',
#  379: 'Neutral',
#  380: 'Positive',
#  381: 'Neutral',
#  382: 'Neutral',
#  383: 'Neutral',
#  384: 'Neutral',
#  385: 'Negative',
#  386: 'Negative',
#  387: 'Neutral',
#  388: 'Neutral',
#  389: 'Neutral',
#  390: 'Neutral',
#  391: 'Neutral',
#  392: 'Neutral',
#  393: 'Negative',
#  394: 'Neutral',
#  395: 'Neutral',
#  396: 'Neutral',
#  398: 'Neutral',
#  399: 'Positive',
#  400: 'Negative',
#  401: 'Neutral',
#  402: 'Neutral',
#  403: 'Neutral',
#  404: 'Neutral',
#  405: 'Neutral',
#  406: 'Neutral',
#  407: 'Neutral',
#  408: 'Neutral',
#  409: 'Negative',
#  410: 'Positive',
#  411: 'Positive',
#  412: 'Neutral',
#  413: 'Neutral',
#  414: 'Neutral',
#  415: 'Neutral',
#  416: 'Neutral',
#  417: 'Neutral',
#  418: 'Positive',
#  419: 'Neutral',
#  420: 'Positive',
#  421: 'Positive',
#  422: 'Positive',
#  423: 'Neutral',
#  426: 'Neutral',
#  427: 'Neutral',
#  428: 'Neutral',
#  429: 'Neutral',
#  430: 'Neutral',
#  432: 'Neutral',
#  433: 'Neutral',
#  434: 'Neutral',
#  435: 'Positive',
#  437: 'Neutral',
#  438: 'Positive',
#  439: 'Neutral',
#  440: 'Neutral',
#  441: 'Negative',
#  442: 'Positive',
#  443: 'Neutral',
#  444: 'Neutral',
#  445: 'Neutral',
#  446: 'Neutral',
#  447: 'Neutral',
#  448: 'Neutral',
#  449: 'Positive',
#  450: 'Positive',
#  451: 'Positive',
#  452: 'Positive',
#  453: 'Positive',
#  454: 'Neutral',
#  455: 'Positive',
#  456: 'Neutral',
#  457: 'Neutral',
#  458: 'Positive',
#  459: 'Neutral',
#  460: 'Positive',
#  461: 'Neutral',
#  462: 'Positive',
#  463: 'Neutral',
#  464: 'Positive',
#  465: 'Neutral',
#  466: 'Neutral',
#  467: 'Positive',
#  468: 'Neutral',
#  469: 'Neutral',
#  470: 'Neutral',
#  471: 'Positive',
#  472: 'Neutral',
#  473: 'Neutral',
#  474: 'Positive',
#  475: 'Positive',
#  476: 'Neutral',
#  477: 'Neutral',
#  478: 'Neutral',
#  479: 'Neutral',
#  481: 'Neutral',
#  482: 'Positive',
#  483: 'Neutral',
#  484: 'Neutral',
#  486: 'Neutral',
#  487: 'Neutral',
#  488: 'Neutral',
#  489: 'Positive',
#  490: 'Positive',
#  491: 'Neutral',
#  492: 'Neutral',
#  493: 'Neutral',
#  494: 'Neutral',
#  495: 'Neutral',
#  496: 'Neutral',
#  497: 'Neutral',
#  498: 'Neutral',
#  499: 'Neutral',
#  500: 'Positive',
#  501: 'Neutral',
#  502: 'Positive',
#  503: 'Neutral',
#  504: 'Neutral',
#  505: 'Neutral',
#  507: 'Positive',
#  508: 'Positive',
#  509: 'Neutral',
#  510: 'Neutral',
#  511: 'Positive',
#  512: 'Neutral',
#  513: 'Neutral',
#  514: 'Positive',
#  515: 'Neutral',
#  516: 'Positive',
#  517: 'Neutral',
#  518: 'Neutral',
#  519: 'Neutral',
#  520: 'Neutral',
#  521: 'Neutral',
#  522: 'Neutral',
#  523: 'Neutral',
#  524: 'Neutral',
#  526: 'Neutral',
#  528: 'Neutral',
#  529: 'Positive',
#  530: 'Positive',
#  531: 'Neutral',
#  532: 'Neutral',
#  533: 'Positive',
#  534: 'Neutral',
#  535: 'Neutral',
#  536: 'Neutral',
#  537: 'Negative',
#  538: 'Neutral',
#  539: 'Neutral',
#  540: 'Neutral',
#  541: 'Positive',
#  542: 'Neutral',
#  543: 'Neutral',
#  544: 'Neutral',
#  545: 'Neutral',
#  547: 'Neutral',
#  548: 'Positive',
#  549: 'Neutral',
#  550: 'Neutral',
#  551: 'Positive',
#  552: 'Negative',
#  554: 'Neutral',
#  555: 'Positive',
#  556: 'Neutral',
#  557: 'Neutral',
#  558: 'Positive',
#  559: 'Neutral',
#  562: 'Neutral',
#  563: 'Neutral',
#  564: 'Neutral',
#  565: 'Neutral',
#  566: 'Positive',
#  567: 'Neutral',
#  568: 'Positive',
#  569: 'Neutral',
#  570: 'Neutral',
#  571: 'Neutral',
#  572: 'Positive',
#  573: 'Neutral',
#  574: 'Neutral',
#  575: 'Neutral',
#  576: 'Neutral',
#  578: 'Neutral',
#  579: 'Neutral',
#  580: 'Neutral',
#  581: 'Neutral',
#  582: 'Negative',
#  583: 'Neutral',
#  584: 'Neutral',
#  585: 'Negative',
#  586: 'Positive',
#  587: 'Neutral',
#  588: 'Neutral',
#  589: 'Neutral',
#  590: 'Positive',
#  591: 'Neutral',
#  592: 'Positive',
#  593: 'Positive',
#  594: 'Neutral',
#  595: 'Neutral',
#  596: 'Neutral',
#  597: 'Neutral',
#  598: 'Neutral',
#  599: 'Neutral',
#  600: 'Neutral',
#  601: 'Neutral',
#  602: 'Neutral',
#  603: 'Neutral',
#  604: 'Neutral',
#  605: 'Neutral',
#  606: 'Neutral',
#  607: 'Neutral',
#  608: 'Neutral',
#  609: 'Positive',
#  610: 'Neutral',
#  611: 'Neutral',
#  612: 'Neutral',
#  613: 'Neutral',
#  614: 'Neutral',
#  615: 'Neutral',
#  616: 'Positive',
#  617: 'Neutral',
#  618: 'Neutral',
#  619: 'Neutral',
#  620: 'Negative',
#  621: 'Neutral',
#  622: 'Positive',
#  623: 'Neutral',
#  624: 'Positive',
#  625: 'Positive',
#  626: 'Neutral',
#  627: 'Negative',
#  628: 'Neutral',
#  629: 'Positive',
#  630: 'Neutral',
#  631: 'Negative',
#  632: 'Neutral',
#  633: 'Positive',
#  635: 'Neutral',
#  636: 'Positive',
#  637: 'Neutral',
#  638: 'Negative',
#  639: 'Neutral',
#  640: 'Positive',
#  641: 'Neutral',
#  642: 'Neutral',
#  643: 'Neutral',
#  644: 'Neutral',
#  645: 'Neutral',
#  646: 'Neutral',
#  647: 'Neutral',
#  648: 'Neutral',
#  649: 'Neutral',
#  650: 'Negative',
#  651: 'Neutral',
#  652: 'Positive',
#  654: 'Neutral',
#  655: 'Neutral',
#  656: 'Neutral',
#  664: 'Neutral',
#  665: 'Negative',
#  666: 'Neutral',
#  667: 'Neutral',
#  668: 'Neutral',
#  669: 'Positive',
#  670: 'Positive',
#  672: 'Neutral',
#  673: 'Positive',
#  674: 'Positive',
#  675: 'Neutral',
#  676: 'Positive',
#  677: 'Positive',
#  678: 'Neutral',
#  679: 'Neutral',
#  680: 'Negative',
#  681: 'Neutral',
#  682: 'Neutral',
#  683: 'Positive',
#  684: 'Neutral',
#  685: 'Neutral',
#  686: 'Neutral',
#  687: 'Neutral',
#  688: 'Positive',
#  689: 'Neutral',
#  690: 'Neutral',
#  692: 'Neutral',
#  693: 'Positive',
#  694: 'Neutral',
#  695: 'Neutral',
#  696: 'Positive',
#  697: 'Negative',
#  698: 'Neutral',
#  699: 'Neutral',
#  700: 'Neutral',
#  701: 'Neutral',
#  702: 'Neutral',
#  703: 'Neutral',
#  704: 'Neutral',
#  705: 'Positive',
#  706: 'Neutral',
#  707: 'Neutral',
#  708: 'Positive',
#  709: 'Neutral',
#  710: 'Positive',
#  711: 'Neutral',
#  712: 'Neutral',
#  713: 'Neutral',
#  714: 'Neutral',
#  715: 'Neutral',
#  716: 'Positive',
#  717: 'Neutral',
#  718: 'Neutral',
#  719: 'Neutral',
#  720: 'Neutral',
#  721: 'Neutral',
#  722: 'Neutral',
#  723: 'Neutral',
#  724: 'Neutral',
#  725: 'Neutral',
#  726: 'Neutral',
#  727: 'Neutral',
#  728: 'Neutral',
#  729: 'Neutral',
#  730: 'Neutral',
#  731: 'Neutral',
#  732: 'Positive',
#  733: 'Negative',
#  734: 'Positive',
#  735: 'Neutral',
#  736: 'Neutral',
#  737: 'Neutral',
#  738: 'Neutral',
#  739: 'Neutral',
#  740: 'Neutral',
#  741: 'Neutral',
#  742: 'Neutral',
#  743: 'Neutral',
#  744: 'Neutral',
#  745: 'Neutral',
#  746: 'Neutral',
#  748: 'Neutral',
#  749: 'Negative',
#  750: 'Neutral',
#  751: 'Neutral',
#  752: 'Neutral',
#  753: 'Neutral',
#  754: 'Neutral',
#  755: 'Neutral',
#  756: 'Neutral',
#  757: 'Neutral',
#  758: 'Neutral',
#  759: 'Positive',
#  760: 'Neutral',
#  761: 'Neutral',
#  762: 'Negative',
#  763: 'Neutral',
#  764: 'Positive',
#  765: 'Neutral',
#  766: 'Neutral',
#  767: 'Positive',
#  768: 'Neutral',
#  769: 'Neutral',
#  770: 'Neutral',
#  771: 'Neutral',
#  772: 'Positive',
#  773: 'Positive',
#  774: 'Positive',
#  775: 'Neutral',
#  776: 'Neutral',
#  777: 'Neutral',
#  778: 'Neutral',
#  779: 'Neutral',
#  780: 'Neutral',
#  781: 'Positive',
#  782: 'Neutral',
#  783: 'Neutral',
#  784: 'Neutral',
#  785: 'Neutral',
#  786: 'Neutral',
#  787: 'Neutral',
#  788: 'Neutral',
#  789: 'Neutral',
#  790: 'Neutral',
#  791: 'Neutral',
#  792: 'Neutral',
#  794: 'Neutral',
#  795: 'Neutral',
#  797: 'Neutral',
#  798: 'Neutral',
#  799: 'Neutral',
#  800: 'Neutral',
#  801: 'Neutral',
#  802: 'Neutral',
#  803: 'Neutral',
#  804: 'Negative',
#  805: 'Positive',
#  806: 'Neutral',
#  807: 'Positive',
#  808: 'Negative',
#  809: 'Positive',
#  810: 'Neutral',
#  811: 'Positive',
#  812: 'Neutral',
#  813: 'Neutral',
#  814: 'Neutral',
#  815: 'Positive',
#  816: 'Neutral',
#  817: 'Neutral',
#  818: 'Positive',
#  819: 'Neutral',
#  820: 'Positive',
#  821: 'Positive',
#  822: 'Neutral',
#  823: 'Neutral',
#  824: 'Neutral',
#  825: 'Neutral',
#  826: 'Negative',
#  827: 'Positive',
#  828: 'Neutral',
#  829: 'Neutral',
#  830: 'Negative',
#  831: 'Negative',
#  832: 'Neutral',
#  833: 'Neutral',
#  834: 'Positive',
#  835: 'Neutral',
#  836: 'Positive',
#  837: 'Positive',
#  838: 'Neutral',
#  839: 'Neutral',
#  840: 'Positive',
#  841: 'Neutral',
#  842: 'Neutral',
#  843: 'Neutral',
#  844: 'Positive',
#  845: 'Positive',
#  846: 'Neutral',
#  847: 'Neutral',
#  848: 'Positive',
#  849: 'Neutral',
#  850: 'Positive',
#  851: 'Neutral',
#  852: 'Neutral',
#  853: 'Negative',
#  854: 'Positive',
#  855: 'Neutral',
#  856: 'Neutral',
#  858: 'Neutral',
#  860: 'Neutral',
#  861: 'Positive',
#  862: 'Negative',
#  863: 'Neutral',
#  864: 'Neutral',
#  865: 'Neutral',
#  866: 'Positive',
#  867: 'Positive',
#  868: 'Neutral',
#  869: 'Positive',
#  870: 'Positive',
#  871: 'Neutral',
#  872: 'Neutral',
#  873: 'Neutral',
#  874: 'Neutral',
#  875: 'Neutral',
#  876: 'Positive',
#  877: 'Positive',
#  878: 'Positive',
#  879: 'Neutral',
#  880: 'Neutral',
#  881: 'Neutral',
#  882: 'Neutral',
#  883: 'Neutral',
#  884: 'Neutral',
#  885: 'Positive',
#  886: 'Positive',
#  888: 'Neutral',
#  889: 'Neutral',
#  890: 'Positive',
#  891: 'Neutral',
#  892: 'Negative',
#  893: 'Positive',
#  894: 'Positive',
#  895: 'Neutral',
#  896: 'Neutral',
#  897: 'Positive',
#  898: 'Positive',
#  899: 'Neutral',
#  900: 'Neutral',
#  901: 'Neutral',
#  902: 'Neutral',
#  903: 'Neutral',
#  904: 'Neutral',
#  905: 'Positive',
#  906: 'Neutral',
#  907: 'Neutral',
#  908: 'Neutral',
#  909: 'Neutral',
#  910: 'Positive',
#  911: 'Positive',
#  912: 'Neutral',
#  913: 'Neutral',
#  914: 'Positive',
#  915: 'Neutral',
#  916: 'Negative',
#  917: 'Positive',
#  922: 'Negative',
#  923: 'Positive',
#  924: 'Neutral',
#  925: 'Positive',
#  926: 'Positive',
#  927: 'Neutral',
#  928: 'Neutral',
#  929: 'Neutral',
#  930: 'Positive',
#  931: 'Positive',
#  932: 'Neutral',
#  933: 'Neutral',
#  934: 'Positive',
#  935: 'Neutral',
#  936: 'Positive',
#  937: 'Neutral',
#  938: 'Neutral',
#  939: 'Neutral',
#  940: 'Positive',
#  941: 'Neutral',
#  942: 'Positive',
#  943: 'Positive',
#  944: 'Neutral',
#  945: 'Neutral',
#  946: 'Neutral',
#  947: 'Neutral',
#  948: 'Neutral',
#  949: 'Neutral',
#  950: 'Neutral',
#  952: 'Neutral',
#  953: 'Positive',
#  954: 'Positive',
#  955: 'Neutral',
#  956: 'Neutral',
#  957: 'Neutral',
#  958: 'Neutral',
#  959: 'Positive',
#  960: 'Neutral',
#  961: 'Neutral',
#  962: 'Positive',
#  963: 'Negative',
#  964: 'Negative',
#  965: 'Neutral',
#  968: 'Positive',
#  969: 'Neutral',
#  970: 'Neutral',
#  971: 'Neutral',
#  972: 'Negative',
#  973: 'Neutral',
#  974: 'Neutral',
#  975: 'Positive',
#  976: 'Neutral',
#  977: 'Neutral',
#  978: 'Neutral',
#  979: 'Neutral',
#  981: 'Neutral',
#  982: 'Neutral',
#  983: 'Neutral',
#  984: 'Neutral',
#  985: 'Positive',
#  986: 'Neutral',
#  987: 'Neutral',
#  988: 'Neutral',
#  989: 'Positive',
#  990: 'Neutral',
#  991: 'Neutral',
#  992: 'Neutral',
#  993: 'Positive',
#  994: 'Positive',
#  995: 'Positive',
#  996: 'Neutral',
#  999: 'Neutral',
#  1000: 'Positive',
#  1001: 'Neutral',
#  1002: 'Positive',
#  1003: 'Negative',
#  1004: 'Neutral',
#  1005: 'Neutral',
#  1006: 'Neutral',
#  1007: 'Positive',
#  1008: 'Positive',
#  1009: 'Neutral',
#  1010: 'Neutral',
#  1011: 'Neutral',
#  1012: 'Positive',
#  1013: 'Neutral',
#  1014: 'Positive',
#  1015: 'Positive',
#  1016: 'Neutral',
#  1017: 'Positive',
#  1018: 'Negative',
#  1019: 'Neutral',
#  1020: 'Negative',
#  1021: 'Neutral',
#  1022: 'Negative',
#  1023: 'Neutral',
#  1024: 'Neutral',
#  1025: 'Neutral',
#  1026: 'Neutral',
#  1027: 'Neutral',
#  1028: 'Negative',
#  1029: 'Positive',
#  1030: 'Neutral',
#  1031: 'Neutral',
#  1032: 'Neutral',
#  1033: 'Negative',
#  1034: 'Positive',
#  1035: 'Neutral',
#  1036: 'Neutral',
#  1037: 'Positive',
#  1038: 'Neutral',
#  1039: 'Neutral',
#  1040: 'Neutral',
#  1041: 'Positive',
#  1042: 'Neutral',
#  1043: 'Neutral',
#  1044: 'Neutral',
#  1045: 'Neutral',
#  1046: 'Positive',
#  1047: 'Positive',
#  1048: 'Positive',
#  1050: 'Positive',
#  1051: 'Positive',
#  1052: 'Neutral',
#  1054: 'Neutral',
#  1055: 'Neutral',
#  1056: 'Neutral',
#  1057: 'Neutral',
#  1058: 'Neutral',
#  1059: 'Positive',
#  1060: 'Neutral',
#  1061: 'Positive',
#  1062: 'Neutral',
#  1063: 'Neutral',
#  1064: 'Neutral',
#  1065: 'Neutral',
#  1066: 'Negative',
#  1067: 'Neutral',
#  1068: 'Neutral',
#  1069: 'Neutral',
#  1070: 'Neutral',
#  1071: 'Neutral',
#  1072: 'Neutral',
#  1073: 'Neutral',
#  1074: 'Neutral',
#  1075: 'Positive',
#  1076: 'Positive',
#  1077: 'Positive',
#  1078: 'Neutral',
#  1079: 'Neutral',
#  1080: 'Negative',
#  1081: 'Neutral',
#  1082: 'Neutral',
#  1083: 'Positive',
#  1084: 'Neutral',
#  1085: 'Neutral',
#  1086: 'Positive',
#  1087: 'Neutral',
#  1088: 'Positive',
#  ...}

# %% [markdown]
# ##### Constructing a dataframe from analysing results

# %%
positive = dict(zip(map_coutry_to_emails.keys(), np.zeros(len(map_coutry_to_emails.keys()))))
negative = dict(zip(map_coutry_to_emails.keys(), np.zeros(len(map_coutry_to_emails.keys()))))
neutral  = dict(zip(map_coutry_to_emails.keys(), np.zeros(len(map_coutry_to_emails.keys()))))
count    = dict(zip(map_coutry_to_emails.keys(), np.zeros(len(map_coutry_to_emails.keys()))))

for idx, senti in map_idx_to_sentiment['liu_and_hu'].items():
    for c in map_emails_to_country[idx]:
        if senti == 'Positive':
            positive[c] += 1
        elif senti == 'Negative':
            negative[c] += 1
        else:
            neutral[c] += 1
            
        count[c] += 1
        
for c, num in count.items():
    if num > 0:
        negative[c] = negative[c] / num
        positive[c] = positive[c] / num
        neutral[c] = neutral[c] / num

# %%
a = []

for c, num in count.items():
    a.append((c, negative[c], positive[c], neutral[c], num))
    
country_x_senti = pd.DataFrame(a, columns=['country', 'negative', 'positive', 'neutral', 'num'])
country_x_senti.set_index('country', inplace=True)
country_x_senti.head()
# Out:
#                     negative  positive   neutral   num
# country
# Viet Nam                0.00  0.000000  0.000000   0.0
# Jamaica                 0.25  0.000000  0.750000   4.0
# Serbia                  0.00  1.000000  0.000000   1.0
# Norway                  0.25  0.583333  0.166667  12.0
# Korea, Republic of      0.00  0.000000  0.000000   0.0

# %%
top_countries = country_x_senti[country_x_senti.num > 5]
top_countries.head()
# Out:
#              negative  positive   neutral   num
# country
# Norway       0.250000  0.583333  0.166667  12.0
# Canada       0.333333  0.333333  0.333333  15.0
# Honduras     0.148148  0.407407  0.444444  27.0
# Netherlands  0.428571  0.000000  0.571429   7.0
# Brazil       0.280000  0.440000  0.280000  25.0

# %% [markdown]
# #### Plot the most negative and most positive countries in Hillary's email using Liu and Hu

# %% [markdown]
# Congo is still the most unfavorable country in this method. Other european country also keeps same positions as we did in vader analysis. However, Libya and Syrian does not appear in this list. Syria is even in the positive list.

# %%
((top_countries['negative'] - top_countries['positive'])).sort_values(ascending=False)[:20].plot(kind='bar')
plt.title('Most Negative')
plt.plot()
# Out:
# []

# %%
((top_countries['positive'] - top_countries['negative'])).sort_values(ascending=False)[:20].plot(kind='bar')
plt.title('Most Positive')
plt.plot()
# Out:
# []

# %%
country_x_senti[country_x_senti.num > 10][['neutral', "negative", "positive"]].plot.bar(stacked=True)

# %% [markdown]
# ## Exercise 3

# %% [markdown]
# Using the *models.ldamodel* module from the **gensim** library, run topic modeling over the corpus. Explore different numbers of topics (varying from 5 to 50), and settle for the parameter which returns topics that you consider to be meaningful at first sight.

# %%
from gensim import corpora, models
import gensim
# Out:
# /Users/lcav/anaconda/lib/python3.5/site-packages/gensim-0.13.3-py3.5-macosx-10.6-x86_64.egg/gensim/utils.py:1015: UserWarning: Pattern library is not installed, lemmatization won't be available.
#   warnings.warn("Pattern library is not installed, lemmatization won't be available.")

# %% [markdown]
# There is a confusion that we use the summed data or the data that each row contains one email's content.

# %% [markdown]
# ### sliptted email text

# %%
# function to compute the tokens
def compute_tokens(body_text):
    # list of index 
    index_list = body_text.index
    # list for tokenized documents in loop
    texts = []
    for i in index_list:    
        txt = remove_punctuation(body_text.loc[i])
        tokens = nltk.word_tokenize(txt)
        tokens = [i.lower() for i in tokens if i.lower() not in stopwords]
        tokens_origin = split_digi_letter(tokens)
        # stemming the tokens word by LancasterStemmer
        token_stemmed = [wnl.lemmatize(i) for i in tokens_origin]
        # drop those strings and perform analysis to the rest.
        token_stemmed_reduced = [i for i in token_stemmed if not i.isdigit()]
        # drop single letter tokens
        token_stemmed_reduced = [i for i in token_stemmed_reduced if len(i)>1]
        # add tokens to list
        texts.append(token_stemmed_reduced)
    return texts

# %%
# data set we use
body_text = df.loc[:, 'ExtractedBodyText'].dropna()
# compute tokens
texts = compute_tokens(body_text)

# %%
# turn our tokenized documents into a id <-> term dictionary
dictionary = corpora.Dictionary(texts)   
#remove extremes (similar to the min/max df step used when creating the tf-idf matrix)
dictionary.filter_extremes(no_below=1, no_above=0.8)
# convert tokenized documents into a document-term matrix
corpus = [dictionary.doc2bow(text) for text in texts]

# %%
lda = models.LdaModel(corpus, num_topics=5, 
                      id2word=dictionary, update_every=5, 
                      chunksize=1000, passes=50)

# %%
lda.show_topics()
# Out:
# [(0,
#   '0.007*"republican" + 0.007*"woman" + 0.006*"said" + 0.005*"bill" + 0.005*"vote" + 0.005*"senate" + 0.004*"percent" + 0.004*"issue" + 0.004*"new" + 0.004*"democrat"'),
#  (1,
#   '0.009*"koch" + 0.008*"party" + 0.006*"tea" + 0.005*"mill" + 0.004*"beck" + 0.004*"ok" + 0.004*"group" + 0.004*"republican" + 0.004*"movement" + 0.004*"conservative"'),
#  (2,
#   '0.036*"secretary" + 0.029*"state" + 0.029*"office" + 0.019*"department" + 0.017*"meeting" + 0.014*"room" + 0.010*"arrive" + 0.010*"house" + 0.010*"en" + 0.010*"route"'),
#  (3,
#   '0.005*"state" + 0.005*"american" + 0.005*"one" + 0.005*"president" + 0.004*"new" + 0.004*"obama" + 0.004*"time" + 0.004*"said" + 0.004*"government" + 0.004*"year"'),
#  (4,
#   '0.011*"fyi" + 0.008*"see" + 0.007*"know" + 0.007*"work" + 0.006*"now" + 0.006*"tomorrow" + 0.006*"im" + 0.006*"want" + 0.005*"pls" + 0.005*"need"')]

# %% [markdown]
# Here, I convert the topics into just a list of the top 20 words in each topic.

# %%
topics_matrix = lda.show_topics(formatted=False, num_words=20)
for i in range(len(topics_matrix)):
    topics_matrix_word = list(np.asarray(topics_matrix[i][1])[:,0])
    print([str(word) for word in topics_matrix_word])
    print()
# Out:
# ['republican', 'woman', 'said', 'bill', 'vote', 'senate', 'percent', 'issue', 'new', 'democrat', 'state', 'year', 'one', 'president', 'house', 'enough', 'senator', 'congress', 'candidate', 'obama']
#
# ['koch', 'party', 'tea', 'mill', 'beck', 'ok', 'group', 'republican', 'movement', 'conservative', 'obama', 'cheryl', 'david', 'millscdstategov', 'charles', 'said', 'political', 'first', 'million', 'company']
#
# ['secretary', 'state', 'office', 'department', 'meeting', 'room', 'arrive', 'house', 'en', 'route', 'depart', 'private', 'residence', 'conference', 'time', 'doc', 'benghazi', 'daily', 'staff', 'date']
#
# ['state', 'american', 'one', 'president', 'new', 'obama', 'time', 'said', 'government', 'year', 'people', 'policy', 'country', 'israel', 'clinton', 'world', 'party', 'political', 'right', 'united']
#
# ['fyi', 'see', 'know', 'work', 'now', 'tomorrow', 'im', 'want', 'pls', 'need', 'today', 'think', 'time', 'email', 'good', 'let', 'talk', 'thx', 'clintonemailcom', 'huma']

# %% [markdown]
# ### Summed email text

# %%
# turn our tokenized documents into a id <-> term dictionary
dictionary = corpora.Dictionary([token_stemmed_reduced]) 
#remove extremes (similar to the min/max df step used when creating the tf-idf matrix)
dictionary.filter_extremes(no_below=1, no_above=0.8)
# convert tokenized documents into a document-term matrix
corpus1 = [dictionary.doc2bow(text) for text in [token_stemmed_reduced]]

# %%
corpus1
# Out:
# [[]]

# %% [markdown]
# It seems that we cannot use the summed information. The remove extremes will prevent outputing any corpus.

# %%
lda1 = models.LdaModel(corpus1, num_topics=5, 
                      id2word=dictionary, update_every=5, 
                      chunksize=1000, passes=50)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-87-79720fac864c> in <module>()
#       1 lda1 = models.LdaModel(corpus1, num_topics=5,
#       2                       id2word=dictionary, update_every=5,
# ----> 3                       chunksize=1000, passes=50)
#
# /Users/lcav/anaconda/lib/python3.5/site-packages/gensim-0.13.3-py3.5-macosx-10.6-x86_64.egg/gensim/models/ldamodel.py in __init__(self, corpus, num_topics, id2word, distributed, chunksize, passes, update_every, alpha, eta, decay, offset, eval_every, iterations, gamma_threshold, minimum_probability, random_state, ns_conf)
#     285
#     286         if self.num_terms == 0:
# --> 287             raise ValueError("cannot compute LDA over an empty collection (no terms)")
#     288
#     289         self.distributed = bool(distributed)
#
# ValueError: cannot compute LDA over an empty collection (no terms)

# %%
lda1.show_topics()

# %% [markdown]
# Here, I convert the topics into just a list of the top 20 words in each topic.

# %%
topics_matrix = lda1.show_topics(formatted=False, num_words=20)
topics_matrix = np.array(topics_matrix)

topic_words = topics_matrix[:,:,1]
for i in topic_words:
    print([str(word) for word in i])
    print()

# %% [markdown]
# ## Exercise 4

# %% [markdown]
# BONUS: build the communication graph (unweighted and undirected) among the different email senders and recipients using the NetworkX library. Find communities in this graph with community.best_partition(G) method from the community detection module. Print the most frequent 20 words used by the email authors of each community. Do these word lists look similar to what you've produced at step 3 with LDA? Can you identify clear discussion topics for each community? Discuss briefly the obtained results.

# %%
all_sender_receiver = (df.loc[:, ['MetadataFrom','SenderPersonId','MetadataTo']].dropna())

# %%
all_sender_receiver.head()
# Out:
#          MetadataFrom  SenderPersonId         MetadataTo
# Id
# 1   Sullivan, Jacob J            87.0                  H
# 3     Mills, Cheryl D            32.0                 ;H
# 4     Mills, Cheryl D            32.0                  H
# 5                   H            80.0       Abedin, Huma
# 6                   H            80.0  Russorv@state.gov

# %%
print('number of unique sender based on name:',len(all_sender_receiver['MetadataFrom'].unique()))
print('number of unique sender based on ID:', len(all_sender_receiver['SenderPersonId'].unique()))
print('number of unique receiver based on name:', len(all_sender_receiver['MetadataTo'].unique()))
# Out:
# number of unique sender based on name: 243
# number of unique sender based on ID: 124
# number of unique receiver based on name: 229

# %%
receiver_name_set = set(all_sender_receiver['MetadataTo'].unique())
sender_name_set = set(all_sender_receiver['MetadataFrom'].unique())
sender_id_set = set(all_sender_receiver['SenderPersonId'].unique())

# %% [markdown]
# Clearly, we need to use ID to identify the sender and receiver. Since we do not have the ID for the corresponding receiver, we have to build a dictionary of sender ID and name. We find that some receivers's name cannot be found in the dictionary, hence, we will add new nodes for these names which means creat some ID for them.

# %%
# the dataframe of sender and its id
all_sender = (df.loc[:, ['MetadataFrom','SenderPersonId']].dropna())
# for each id, sum all the corresponding name string
df_id_name = all_sender.groupby('SenderPersonId').sum()
# unique receiver name
unique_receiver_name = all_sender_receiver['MetadataTo'].unique()

# %%
# dictionary to map receiver name to id
dic_id_receiver = {'H':80,';H':80, 'l': 227, 'Hillary':80, 'Secretary':80, 'Secretary Clinton':80, 
                   'H2':80, 'Clinton':80, 'Clinton, Hillary':80, 'Clinton, Hillary Rodham':80}
# remainding receiver name
remain_receiver_name = list(unique_receiver_name.copy())
for i in list(dic_id_receiver.keys()):
    remain_receiver_name.remove(i)
for single_name in unique_receiver_name:
    if single_name not in dic_id_receiver.keys():
        id_num_store = []
        # since we mapped Hillary, we remove her from the id list
        for single_id in df_id_name.index[df_id_name.index!=80]:
            condition1 = single_name == df_id_name.loc[single_id,'MetadataFrom']
            condition2 = (df_id_name.loc[single_id,'MetadataFrom']).count(single_name)>1
            if condition1 or condition2:
                id_num_store.append(((df_id_name.loc[single_id,'MetadataFrom']).count(single_name),single_id))
        if id_num_store != []:
            # max count
            max_count_index = np.argmax(np.array(id_num_store)[:,0])
            # assert the dictionary
            select_index = np.array(id_num_store)[max_count_index,1]
            dic_id_receiver[single_name] = select_index
            remain_receiver_name.remove(single_name)

# %%
remain_receiver_name
# Out:
# ['Russorv@state.gov',
#  'sullivanjj@state.gov',
#  'Flores, Oscar',
#  'abedinh@state.gov',
#  'millscd@state.gov',
#  'hanleymr@state.gov',
#  'ValmoroLj@state.gov',
#  'Burnswj@state.gov',
#  'NidesTR@state.gov',
#  'Jake.Sullivan',
#  'Jake.sullivan',
#  'michele.flournoy',
#  'brian',
#  'bam@mikulski.senate.gov',
#  'ntanden',
#  'jacobjlew',
#  'Huma Abedin',
#  'rsloan',
#  'jilotyLC@state.gov',
#  'stalbott',
#  'balderstonkm@state.gov',
#  'SteinbergJB@state.gov',
#  'mhcaleja@state.gov',
#  'jpodesta',
#  'sulllivanjj@state.gov',
#  'wsherman',
#  'abendinh@state.gov',
#  'adedinh@state.gov',
#  'Imuscatine',
#  'muscatinel@state.gov',
#  'cholletdh@state.gov',
#  'BStrider',
#  'jfarrow',
#  'Axelrod_D',
#  'SBerger',
#  'wburns66@',
#  'shapiroa@state.gov',
#  'David_Garten@lautenberg.senate.gov',
#  'verveerms@state.gov',
#  'kohhh@state.gov',
#  'lewjj@state.gov',
#  'TFlourno',
#  'jpiercy',
#  'Valmorolj@state.gov',
#  'FuchsMH@state.gov',
#  'cherieblair',
#  'Terry.Duffy',
#  'burnswj@state.gov',
#  'crowleypj@state.gov',
#  'CampbellKM@state.gov',
#  'rooneym@state.gov',
#  'sgration',
#  'doug',
#  'nancy',
#  'KellyC@state.gov',
#  'HolbrookeRC@state.gov',
#  'caputol',
#  'gordonph@state.gov',
#  'sbwhoop',
#  'captuol',
#  'slaughtera@state.gov',
#  'cheryl.mills@',
#  'rodriguezme@state.gov',
#  'mtorrey',
#  'glantz.',
#  'williamsbarrett',
#  'jake.sullivan@',
#  'hillcr@state.gov',
#  'tauschereo@state.gov',
#  'feltmanjd@state.gov',
#  'sbwhoeop@',
#  'baer.daniel',
#  'SteinbertJB@state.gov',
#  'Cue, Lourdes C',
#  'ValmoroLI@state.gov',
#  'vermarr@state.gov',
#  'carsonj@state.gov',
#  'JilotylC@state.gov',
#  'cmarshall',
#  'shannonta@state.gov',
#  'Luzzatto',
#  'daniel.baer',
#  'Department of State',
#  'marshallcp@state.gov',
#  'Eikenberry, Karl W',
#  'Howe, Rosemarie',
#  'hr15@mycingular.blackberry.net',
#  'donald',
#  'Crowley, Phillip J',
#  'rosemarie.howe ;H',
#  'Preval, Rene',
#  'mark',
#  'hormatsrd@state.gov',
#  'cheryl.mills ;H',
#  'Cooper, Justin',
#  'capriciamarshall@',
#  'sterntd@state.gov',
#  'abedin@state.gov',
#  'Williamsbarrett',
#  'PosnerMH@state.gov',
#  'rrh.interiors',
#  'Council on Foreign Relations',
#  'Cheryl.mills',
#  'SchwerinDB@state.gov',
#  'mh.interiors',
#  'Kennedy, Jim',
#  'Sullivan, Jacbo J',
#  'Cheryl Mills, COS',
#  'Kabul LGF Request',
#  'H;preines',
#  'valmoroLJ@state.gov',
#  'Abedin, Huma; H',
#  'Ki-moon, Ban',
#  'Robinson, Peter',
#  'ASUNCION',
#  'WHADP',
#  'Reynolds, Diane',
#  'Edwards, Christopher',
#  'Pally, Maura M',
#  'preines; H',
#  'Sullivan, Jake; H',
#  'Lores, Oscar',
#  'Estados Unidos De NorteAmerica',
#  'United States of America',
#  "Etat-Unis D'Amerique",
#  'Bond, Michele T',
#  'Estados Unidos Da America',
#  'Govenman Etazini',
#  'Hattaway, Doug',
#  'Pascual, Carlos',
#  'Band, Doug',
#  'Obama, Barack',
#  'LGraham',
#  'Olver, John',
#  'Grantham, Suzanne L',
#  'Klehr, Bonnie',
#  'Clinton, William J',
#  'HRC',
#  'Mills,Cheryl D',
#  'Sullivan, Jacob H',
#  'betsyebeling1050',
#  'Duk-soo, Han',
#  'Conrad, Kent',
#  'Slaughter, Anne- Marie',
#  'Robinson, Jennifer',
#  'President',
#  'brimmere@state.gov',
#  'rshah',
#  'oterom2@state.gov',
#  'valenzuelaaa@state.gov',
#  'JjilotyLC@state.gov',
#  'muscantinel@state.gov',
#  'Rice, Susan E.',
#  'mchaleja@state.gov',
#  'toivnf@state.gov',
#  'TillemannTS@state.gov',
#  'markjpenn',
#  'Dad',
#  'bealeca@state.gov',
#  'Jilotylc@state.gov',
#  'ValmmoroLJ@state.gov',
#  'bstrider',
#  'Rooneym@state.gov',
#  'lynn',
#  'Jacobs, Janice L',
#  'Betsy.Ebeling',
#  'sberger',
#  'stallbott']

# %% [markdown]
# Need to group the remain_receiver_name as well, to do!!

# %%
# add new id to each element of remain_receiver_name and attach them to the dic_id_receiver
for i in range(len(remain_receiver_name)):
    dic_id_receiver[remain_receiver_name[i]] = 228+i

# %%
# add a colume of ReceiverPersonId
all_sender_receiver['ReceiverPersonId'] = 0

# %%
for i in all_sender_receiver.index:
    # receiver name
    receiver_name = all_sender_receiver.ix[i,2]
    # give receiver id
    all_sender_receiver.ix[i,3] = dic_id_receiver[receiver_name]

# %%
all_sender_receiver
# Out:
#                MetadataFrom  SenderPersonId            MetadataTo  \
# Id
# 1         Sullivan, Jacob J            87.0                     H
# 3           Mills, Cheryl D            32.0                    ;H
# 4           Mills, Cheryl D            32.0                     H
# 5                         H            80.0          Abedin, Huma
# 6                         H            80.0     Russorv@state.gov
# 7           Mills, Cheryl D            32.0                     H
# 8                         H            80.0          Abedin, Huma
# 9         Sullivan, Jacob J            87.0                     H
# 11        Sullivan, Jacob J            87.0                     H
# 13        Sullivan, Jacob J            87.0                     H
# 14    Slaughter, Anne-Marie            10.0                     H
# 15          Mills, Cheryl D            32.0                     H
# 16       Koh, Harold Hongju            77.0                     H
# 17         Sherman, Wendy R           213.0                     H
# 18         Sherman, Wendy R           213.0                     H
# 19        Sullivan, Jacob J            87.0                     H
# 20        Sullivan, Jacob J            87.0      Sherman, Wendy R
# 21                        H            80.0  sullivanjj@state.gov
# 22                        H            80.0     Russorv@state.gov
# 23                        H            80.0     Russorv@state.gov
# 24                        H            80.0  sullivanjj@state.gov
# 25        Sullivan, Jacob J            87.0                     H
# 26       Blumenthal, Sidney           194.0                     H
# 27        Sullivan, Jacob J            87.0                     H
# 28          Mills, Cheryl D            32.0                     H
# 29           Strider, Burns            21.0                     H
# 30             Abedin, Huma            81.0                     H
# 31        Sullivan, Jacob J            87.0                     H
# 32          Mills, Cheryl D            32.0                     H
# 34                        H            80.0     Russorv@state.gov
# ...                     ...             ...                   ...
# 7916               sbwhoeop           194.0                     H
# 7917      Sullivan, Jacob J            87.0                     H
# 7918    Rodriguez, Miguel E           148.0                     H
# 7919        Mills, Cheryl D            32.0                     H
# 7920     Verveer, Melanne S           143.0                     H
# 7921           Abedin, Huma            81.0                     H
# 7922        Mills, Cheryl D            32.0                     H
# 7923     Schwerin, Daniel B            48.0                     H
# 7924       Daniel, Joshua J           103.0                     H
# 7925  Slaughter, Anne-Marie            10.0                     H
# 7926       Verma, Richard R           180.0                     H
# 7927        Mills, Cheryl D            32.0                     H
# 7928        Mills, Cheryl D            32.0                     H
# 7929         Sullivan, Jake            87.0                     H
# 7930        Mills, Cheryl D            32.0                     H
# 7931        Mills, Cheryl D            32.0                     H
# 7932        Mills, Cheryl D            32.0                     H
# 7933      Sullivan, Jacob J            87.0                     H
# 7934               sbwhoeop           194.0                     H
# 7935           Abedin, Huma            81.0                     H
# 7936           Abedin, Huma            81.0                     H
# 7937        Mills, Cheryl D            32.0                     H
# 7938        Mills, Cheryl D            32.0                     H
# 7939          Stern, Todd D           204.0                     H
# 7940         Sullivan, Jake            87.0                     H
# 7941       Verma, Richard R           180.0                     H
# 7942       Verma, Richard R           180.0                     H
# 7943       Jiloty, Lauren C           116.0                     H
# 7944               PVerveer           143.0                     H
# 7945      Sullivan, Jacob J            87.0                     H
#
#       ReceiverPersonId
# Id
# 1                 80.0
# 3                 80.0
# 4                 80.0
# 5                 81.0
# 6                228.0
# 7                 80.0
# 8                 81.0
# 9                 80.0
# 11                80.0
# 13                80.0
# 14                80.0
# 15                80.0
# 16                80.0
# 17                80.0
# 18                80.0
# 19                80.0
# 20               213.0
# 21               229.0
# 22               228.0
# 23               228.0
# 24               229.0
# 25                80.0
# 26                80.0
# 27                80.0
# 28                80.0
# 29                80.0
# 30                80.0
# 31                80.0
# 32                80.0
# 34               228.0
# ...                ...
# 7916              80.0
# 7917              80.0
# 7918              80.0
# 7919              80.0
# 7920              80.0
# 7921              80.0
# 7922              80.0
# 7923              80.0
# 7924              80.0
# 7925              80.0
# 7926              80.0
# 7927              80.0
# 7928              80.0
# 7929              80.0
# 7930              80.0
# 7931              80.0
# 7932              80.0
# 7933              80.0
# 7934              80.0
# 7935              80.0
# 7936              80.0
# 7937              80.0
# 7938              80.0
# 7939              80.0
# 7940              80.0
# 7941              80.0
# 7942              80.0
# 7943              80.0
# 7944              80.0
# 7945              80.0
#
# [7665 rows x 4 columns]

# %% [markdown]
# ### Build the communication graph

# %%
import networkx as nx

# %%
# node list
node_list = list(set(all_sender_receiver['SenderPersonId'].unique()).union(set(all_sender_receiver['ReceiverPersonId']
                                                                         .unique())))
# edge list
edge_list = []
for i in all_sender_receiver.index:
    sender_id = all_sender_receiver.ix[i, 1]
    receiver_id = all_sender_receiver.ix[i, 3]
    edge_list.append((sender_id,receiver_id))

# %%
# initialize graph
G=nx.Graph()
# add node
G.add_nodes_from(node_list)
# add edge
G.add_edges_from(edge_list)

# %%
# draw graph, we can make it nicer later
nx.draw(G, node_size= 5)
